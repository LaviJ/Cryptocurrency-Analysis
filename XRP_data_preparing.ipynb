# %%
import pandas as pd
import numpy as np

# %%
path ="./archive/coin_XRP.csv"
df = pd.read_csv(path)
df
# Out:
#        SNo Name Symbol                 Date      High       Low      Open  \
# 0        1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613  0.005875
# 1        2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629  0.005637
# 2        3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333  0.004669
# 3        4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175  0.004397
# 4        5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253  0.004257
# ...    ...  ...    ...                  ...       ...       ...       ...
# 2888  2889  XRP    XRP  2021-07-02 23:59:59  0.667287  0.634726  0.659890
# 2889  2890  XRP    XRP  2021-07-03 23:59:59  0.683677  0.644653  0.655639
# 2890  2891  XRP    XRP  2021-07-04 23:59:59  0.707783  0.665802  0.673218
# 2891  2892  XRP    XRP  2021-07-05 23:59:59  0.695653  0.648492  0.695653
# 2892  2893  XRP    XRP  2021-07-06 23:59:59  0.679923  0.652676  0.653055
#
#          Close        Volume     Marketcap
# ...

# %%
df = df.drop(columns=['SNo', 'Name', 'Symbol'])
df.head()
# Out:
#                   Date      High       Low      Open     Close  Volume  \
# 0  2013-08-05 23:59:59  0.005980  0.005613  0.005875  0.005613     0.0
# 1  2013-08-06 23:59:59  0.005661  0.004629  0.005637  0.004680     0.0
# 2  2013-08-07 23:59:59  0.004682  0.004333  0.004669  0.004417     0.0
# 3  2013-08-08 23:59:59  0.004424  0.004175  0.004397  0.004254     0.0
# 4  2013-08-09 23:59:59  0.004367  0.004253  0.004257  0.004291     0.0
#
#       Marketcap
# 0  4.387916e+07
# 1  3.659101e+07
# 2  3.453412e+07
# 3  3.325863e+07
# 4  3.354750e+07

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
start = '2016-07-06'
end = '2021-07-06'

# %%
fiveyears = (df['Date']>start) & (df['Date']<= end)

# %%
bitcoin_df = df.loc[fiveyears]
bitcoin_df
# Out:
#                     Date      High       Low      Open     Close  \
# 1066 2016-07-06 23:59:59  0.006743  0.006687  0.006716  0.006691
# 1067 2016-07-07 23:59:59  0.006699  0.006495  0.006689  0.006598
# 1068 2016-07-08 23:59:59  0.006715  0.006563  0.006609  0.006715
# 1069 2016-07-09 23:59:59  0.006718  0.006624  0.006717  0.006679
# 1070 2016-07-10 23:59:59  0.006676  0.006621  0.006672  0.006674
# ...                  ...       ...       ...       ...       ...
# 2887 2021-07-01 23:59:59  0.704785  0.646796  0.704785  0.661180
# 2888 2021-07-02 23:59:59  0.667287  0.634726  0.659890  0.656763
# 2889 2021-07-03 23:59:59  0.683677  0.644653  0.655639  0.672888
# 2890 2021-07-04 23:59:59  0.707783  0.665802  0.673218  0.694945
# 2891 2021-07-05 23:59:59  0.695653  0.648492  0.695653  0.654300
#
#             Volume     Marketcap
# 1066  6.001950e+05  2.364875e+08
# 1067  7.896930e+05  2.332269e+08
# 1068  6.040760e+05  2.373638e+08
# 1069  5.774470e+05  2.360786e+08
# ...

# %%
bitcoin_df.to_csv('XRP(fiveyears).csv')
