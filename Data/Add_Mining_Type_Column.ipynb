# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\lavin\anaconda3\envs\pythondata\lib\site-packages (4.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\lavin\anaconda3\envs\pythondata\lib\site-packages (from pymongo[srv]) (2.1.0)

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
# Read in mongodb server location as client
client = MongoClient("mongodb+srv://Part2:Grand@cluster0.xqjtt.mongodb.net/test")

# %%
client.list_database_names()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-5-62f658703d98> in <module>
# ----> 1 client.list_database_names()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in list_database_names(self, session)
#    1703         """
#    1704         return [doc["name"]
# -> 1705                 for doc in self.list_databases(session, nameOnly=True)]
#    1706
#    1707     def drop_database(self, name_or_database, session=None):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in list_databases(self, session, **kwargs)
#    1684         cmd.update(kwargs)
#    1685         admin = self._database_default_options("admin")
# -> 1686         res = admin._retryable_read_command(cmd, session=session)
#    1687         # listDatabases doesn't return a cursor (yet). Fake one.
#    1688         cursor = {
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\database.py in _retryable_read_command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     611                                  codec_options, session=session, **kwargs)
#     612
# --> 613         return self.__client._retryable_read(
#     614             _cmd, read_preference, session)
#     615
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1303         while True:
#    1304             try:
# -> 1305                 server = self._select_server(
#    1306                     read_pref, session, address=address)
#    1307                 with self._secondaryok_for_server(read_pref, server, session) as (
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _select_server(self, server_selector, session, address)
#    1135                                         % address)
#    1136             else:
# -> 1137                 server = topology.select_server(server_selector)
#    1138             return server
#    1139         except PyMongoError as exc:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     240                       address=None):
#     241         """Like select_servers, but choose a random server if several match."""
# --> 242         servers = self.select_servers(
#     243             selector, server_selection_timeout, address)
#     244         if len(servers) == 1:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     198
#     199         with self._lock:
# --> 200             server_descriptions = self._select_servers_loop(
#     201                 selector, server_timeout, address)
#     202
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     214             # No suitable servers.
#     215             if timeout == 0 or now > end_time:
# --> 216                 raise ServerSelectionTimeoutError(
#     217                     "%s, Timeout: %ss, Topology Description: %r" %
#     218                     (self._error_message(selector), timeout, self.description))
#
# ServerSelectionTimeoutError: cluster0-shard-00-02.xqjtt.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123),cluster0-shard-00-00.xqjtt.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123),cluster0-shard-00-01.xqjtt.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123), Timeout: 30s, Topology Description: <TopologyDescription id: 61f5d0dc86e58d280193ccd2, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('cluster0-shard-00-00.xqjtt.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('cluster0-shard-00-00.xqjtt.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123)')>, <ServerDescription ('cluster0-shard-00-01.xqjtt.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('cluster0-shard-00-01.xqjtt.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123)')>, <ServerDescription ('cluster0-shard-00-02.xqjtt.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('cluster0-shard-00-02.xqjtt.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1123)')>]>

# %%
db = client["Latest_Cryptodata"]

df = db.Mining_profit_difficulty_coinwarz_data

df = pd.DataFrame(list(df.find()))

# Are these columns confusing the model??
# df = df.drop(columns=["_id","Marketcap", "High", "Low"], axis=1)

df = df.drop(columns=["_id", "index"], axis=1)

df.head(25)

# %%
coins = df["CoinName"]
for coin in coins:
  print(coin)
# Out:
# Peercoin
# Ethereum
# BitcoinCash
# Bitcoin
# Dogecoin
# Ethereum-Classic
# Vertcoin
# Ravencoin
# Horizen
# Litecoin
# Verge
# Florincoin
# Einsteinium
# Feathercoin
# Monero
# Monacoin
# Dash
# Groestlcoin
# DigiByte
# Viacoin
# Syscoin
# LitecoinCash
# Zcash

# %%
# All mining methods for each Coin,  DOGE and ETH, Z Cash planning on making a switch to PoS
mining_methods_column = ["PoW/PoS", "PoW", "PoW", "PoW", "PoW", "PoW", "PoW", "PoW", "PoW/PoS", "PoW", "PoW", "PoS", "PoW", "PoW", "PoW", "PoW", 
                         "PoW/PoS", "PoW/PoS", "PoW", "PoW", "PoW/PoS", "PoW", "PoW"]

# %%
# Add ordered list as column
df["Mining Methods"] = mining_methods_column

# %%
df.head(25)
# Out:
#     level_0          CoinName  ... HealthStatus Mining Methods
# 0         0          Peercoin  ...      Healthy        PoW/PoS
# 1         1          Ethereum  ...      Healthy            PoW
# 2         2       BitcoinCash  ...      Healthy            PoW
# 3         3           Bitcoin  ...      Healthy            PoW
# 4         4          Dogecoin  ...      Healthy            PoW
# 5         5  Ethereum-Classic  ...      Healthy            PoW
# 6         6          Vertcoin  ...      Healthy            PoW
# 7         7         Ravencoin  ...      Healthy            PoW
# 8         8           Horizen  ...      Healthy        PoW/PoS
# 9         9          Litecoin  ...      Healthy            PoW
# 10       10             Verge  ...      Healthy            PoW
# 11       11        Florincoin  ...      Healthy            PoS
# 12       12       Einsteinium  ...      Healthy            PoW
# 13       13       Feathercoin  ...      Healthy            PoW
# 14       14            Monero  ...      Healthy            PoW
# 15       15          Monacoin  ...      Healthy            PoW
# 16       16              Dash  ...      Healthy        PoW/PoS
# 17       17       Groestlcoin  ...      Healthy        PoW/PoS
# 18       18          DigiByte  ...      Healthy            PoW
# 19       19           Viacoin  ...      Healthy            PoW
# 20       20           Syscoin  ...      Healthy        PoW/PoS
# 21       21      LitecoinCash  ...      Healthy            PoW
# 22       22             Zcash  ...    Unhealthy            PoW
#
# [23 rows x 17 columns]

# %%
df.to_csv("Updated_crypto_mining_methods.csv")

# %%
from google.colab import files

# %%
files.download("Updated_crypto_mining_methods.csv")
