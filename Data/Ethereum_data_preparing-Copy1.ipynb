# %% [markdown]
# # Extracting Data from https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory and preprocessing and saving onto a MongoDB database

# %%
# import libraries
import pandas as pd
import numpy as np
import pymongo
from pymongo import MongoClient
import certifi

# %%
# create a dataframe from the csv
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_Kaggle_Historical/coin_Ethereum.csv"
df = pd.read_csv(path)
df
# Out:
#        SNo      Name Symbol                 Date         High          Low  \
# 0        1  Ethereum    ETH  2015-08-08 23:59:59     2.798810     0.714725
# 1        2  Ethereum    ETH  2015-08-09 23:59:59     0.879810     0.629191
# 2        3  Ethereum    ETH  2015-08-10 23:59:59     0.729854     0.636546
# 3        4  Ethereum    ETH  2015-08-11 23:59:59     1.131410     0.663235
# 4        5  Ethereum    ETH  2015-08-12 23:59:59     1.289940     0.883608
# ...    ...       ...    ...                  ...          ...          ...
# 2155  2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496  2021.824808
# 2156  2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155  2117.590013
# 2157  2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857  2190.837703
# 2158  2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836  2163.041394
# 2159  2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874  2197.919385
#
#              Open        Close        Volume     Marketcap
# ...

# %%
# checking for mull values
df.isnull().sum().sum()
df.isna().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
# dropping irrelevant columns
df = df.drop(columns=['SNo', 'Symbol'])
df.head()
# Out:
#        Name                 Date      High       Low      Open     Close  \
# 0  Ethereum  2015-08-08 23:59:59  2.798810  0.714725  2.793760  0.753325
# 1  Ethereum  2015-08-09 23:59:59  0.879810  0.629191  0.706136  0.701897
# 2  Ethereum  2015-08-10 23:59:59  0.729854  0.636546  0.713989  0.708448
# 3  Ethereum  2015-08-11 23:59:59  1.131410  0.663235  0.708087  1.067860
# 4  Ethereum  2015-08-12 23:59:59  1.289940  0.883608  1.058750  1.217440
#
#       Volume     Marketcap
# 0   674188.0  4.548689e+07
# 1   532170.0  4.239957e+07
# 2   405283.0  4.281836e+07
# 3  1463100.0  6.456929e+07
# 4  2150620.0  7.364501e+07

# %%
# converting date to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# data being analyzed for last five years, so filtering data for that date range
start = '2016-07-06'
end = '2021-07-06'

# %%
# creating a variable to store that date range
fiveyears = (df['Date']>start) & (df['Date']<= end)

# %%
# creating a new dataframe after applying the above filters
ethereum_df = df.loc[fiveyears]
ethereum_df
# Out:
#           Name                Date         High          Low         Open  \
# 333   Ethereum 2016-07-06 23:59:59    11.105600    10.280800    10.575800
# 334   Ethereum 2016-07-07 23:59:59    10.565800     9.803210    10.535900
# 335   Ethereum 2016-07-08 23:59:59    11.524800     9.961260    10.115300
# 336   Ethereum 2016-07-09 23:59:59    11.456700    10.729500    11.417700
# 337   Ethereum 2016-07-10 23:59:59    11.013700    10.782200    10.960400
# ...        ...                 ...          ...          ...          ...
# 2154  Ethereum 2021-07-01 23:59:59  2274.397518  2081.080958  2274.397518
# 2155  Ethereum 2021-07-02 23:59:59  2155.596496  2021.824808  2109.892677
# 2156  Ethereum 2021-07-03 23:59:59  2237.567155  2117.590013  2150.835025
# 2157  Ethereum 2021-07-04 23:59:59  2384.286857  2190.837703  2226.550382
# 2158  Ethereum 2021-07-05 23:59:59  2321.922836  2163.041394  2321.922836
#
#             Close        Volume     Marketcap
# ...

# %%
# exporting the dataframe to csv
ethereum_df.to_csv('Ethereum(fiveyears).csv')

# %% [markdown]
# # Storing file in MongoDB (DB name : Finale)

# %%
# Read in mongodb server location as client
client = MongoClient("mongodb+srv://Group7:Finale@finalsegment1.690c0.mongodb.net/bitcoin_db?retryWrites=true&w=majority",tlsCAFile=certifi.where())

# %%
# Find Databases
client.list_database_names()
# Out:
# ['Bitcoin_db',
#  'Cardano_DB',
#  'Ethereum_db',
#  'Finale',
#  'Tether_DB',
#  'XRP_DB',
#  'admin',
#  'local']

# %%
# connecting to the db on MongoDb and creating collection in the db
db = client['Finale']
collection = db['Ethereum']

# %%
# adding dataframe to mongoDb
ethereum_df.reset_index(inplace=True)
ethereum_df_dict = ethereum_df.to_dict("records")

# %%
# Insert collection
collection.insert_many(ethereum_df_dict)
