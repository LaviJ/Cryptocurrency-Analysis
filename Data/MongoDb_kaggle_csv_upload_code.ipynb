# %% [markdown]
# # Moving hourly csv files to MongoDB Atlas Hourly_Cryptocompare DB

# %%
# import libraries
import pandas as pd
import numpy as np
import pymongo
from pymongo import MongoClient
import certifi
from mongo_config import mongo_uri

# %% [markdown]
# # Storing dataframe in MongoDB (DB name : Hourly_Cryptocompare)

# %%
# defining mongodb uri

coins=['binance', 'bitcoin', 'Cardano', 'dodgecoin', 'Ethereum', 'litecoin', 'monero', 'stellar', 'Tether', 'XRP']

client = MongoClient(mongo_uri,tlsCAFile=certifi.where())
db = client['Finale']
print(client.list_database_names())
# Out:
# ['Finale', 'Hourly_Cryptocompare', 'Hourly_Cryptocurrencies', 'admin', 'local']

# %%
# # creating for loop for creating df from csv, adding symbol column and then uploading in mongodb
# for coin in coins:    
#     dataframe = pd.read_csv(coin+"(fiveyears)"+".csv")
#     dataframe["Symbol"] = coin 
#     collection = db[coin]
#     dataframe.reset_index(inplace=True)
#     dataframe_dict = dataframe.to_dict("records")
#     collection.insert_many(dataframe_dict)

# %%
All_coins_kaggle_df = pd.DataFrame()

for coin in coins:
    dataframe = pd.read_csv(coin+"(fiveyears)"+".csv", index_col=False)
    #append the new df
    All_coins_kaggle_df = All_coins_kaggle_df.append(dataframe, ignore_index = True)
    All_coins_kaggle_df.reset_index(drop=True, inplace=True)

print(All_coins_kaggle_df)
All_coins_kaggle_df
# Out:
#        Unnamed: 0  level_0  index          Name                 Date  \
# 0               0      0.0    0.0  Binance Coin  2017-07-26 23:59:59
# 1               1      1.0    1.0  Binance Coin  2017-07-27 23:59:59
# 2               2      2.0    2.0  Binance Coin  2017-07-28 23:59:59
# 3               3      3.0    3.0  Binance Coin  2017-07-29 23:59:59
# 4               4      4.0    4.0  Binance Coin  2017-07-30 23:59:59
# ...           ...      ...    ...           ...                  ...
# 17417        2887      NaN    NaN           XRP  2021-07-01 23:59:59
# 17418        2888      NaN    NaN           XRP  2021-07-02 23:59:59
# 17419        2889      NaN    NaN           XRP  2021-07-03 23:59:59
# 17420        2890      NaN    NaN           XRP  2021-07-04 23:59:59
# 17421        2891      NaN    NaN           XRP  2021-07-05 23:59:59
#
#            High       Low      Open     Close        Volume     Marketcap
# 0      0.109013  0.099266  0.105893  0.105138  2.003950e+05  1.051380e+07
# 1      0.108479  0.100888  0.105108  0.107737  3.444990e+05  1.077370e+07
# 2      0.109019  0.101473  0.107632  0.104067  3.425680e+05  1.040670e+07
# 3      0.111264  0.101108  0.104782  0.107811  3.402180e+05  1.078110e+07
# 4      0.108138  0.103162  0.107935  0.106414  2.242610e+05  1.064140e+07
# ...         ...       ...       ...       ...           ...           ...
# 17417  0.704785  0.646796  0.704785  0.661180  2.553971e+09  3.051144e+10
# 17418  0.667287  0.634726  0.659890  0.656763  2.061607e+09  3.030759e+10
# 17419  0.683677  0.644653  0.655639  0.672888  1.872820e+09  3.105172e+10
# 17420  0.707783  0.665802  0.673218  0.694945  1.885242e+09  3.206960e+10
# 17421  0.695653  0.648492  0.695653  0.654300  2.076373e+09  3.019395e+10
#
# [17422 rows x 11 columns]
#        Unnamed: 0  level_0  index          Name                 Date  \
# 0               0      0.0    0.0  Binance Coin  2017-07-26 23:59:59
# 1               1      1.0    1.0  Binance Coin  2017-07-27 23:59:59
# 2               2      2.0    2.0  Binance Coin  2017-07-28 23:59:59
# 3               3      3.0    3.0  Binance Coin  2017-07-29 23:59:59
# 4               4      4.0    4.0  Binance Coin  2017-07-30 23:59:59
# ...           ...      ...    ...           ...                  ...
# 17417        2887      NaN    NaN           XRP  2021-07-01 23:59:59
# 17418        2888      NaN    NaN           XRP  2021-07-02 23:59:59
# 17419        2889      NaN    NaN           XRP  2021-07-03 23:59:59
# 17420        2890      NaN    NaN           XRP  2021-07-04 23:59:59
# 17421        2891      NaN    NaN           XRP  2021-07-05 23:59:59
#
#            High       Low      Open     Close        Volume     Marketcap
# 0      0.109013  0.099266  0.105893  0.105138  2.003950e+05  1.051380e+07
# 1      0.108479  0.100888  0.105108  0.107737  3.444990e+05  1.077370e+07
# 2      0.109019  0.101473  0.107632  0.104067  3.425680e+05  1.040670e+07
# 3      0.111264  0.101108  0.104782  0.107811  3.402180e+05  1.078110e+07
# 4      0.108138  0.103162  0.107935  0.106414  2.242610e+05  1.064140e+07
# ...         ...       ...       ...       ...           ...           ...
# 17417  0.704785  0.646796  0.704785  0.661180  2.553971e+09  3.051144e+10
# 17418  0.667287  0.634726  0.659890  0.656763  2.061607e+09  3.030759e+10
# 17419  0.683677  0.644653  0.655639  0.672888  1.872820e+09  3.105172e+10
# 17420  0.707783  0.665802  0.673218  0.694945  1.885242e+09  3.206960e+10
# 17421  0.695653  0.648492  0.695653  0.654300  2.076373e+09  3.019395e+10
#
# [17422 rows x 11 columns]

# %%
collection = db['All_coins_kaggle_fiveyears']
# All_coins_kaggle_df.reset_index(inplace=True)
All_coins_kaggle_df_dict = All_coins_kaggle_df.to_dict("records")
collection.insert_many(All_coins_kaggle_df_dict)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18764/3736906648.py in <module>
#       2 # All_coins_kaggle_df.reset_index(inplace=True)
#       3 All_coins_kaggle_df_dict = All_coins_kaggle_df.to_dict("records")
# ----> 4 collection.insert_many(All_coins_kaggle_df_dict)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     587         blk = _Bulk(self, ordered, bypass_document_validation)
#     588         blk.ops = [doc for doc in gen()]
# --> 589         blk.execute(write_concern, session=session)
#     590         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     591
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     446                 self.execute_no_results(sock_info, generator)
#     447         else:
# --> 448             return self.execute_command(generator, write_concern, session)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\bulk.py in execute_command(self, generator, write_concern, session)
#     342         client = self.collection.database.client
#     343         with client._tmp_session(session) as s:
# --> 344             client._retry_with_session(
#     345                 self.is_retryable, retryable_bulk, s, self)
#     346
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1227         retryable = (retryable and self.options.retry_writes
#    1228                      and session and not session.in_transaction)
# -> 1229         return self._retry_internal(retryable, func, session, bulk)
#    1230
#    1231     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1259                             raise last_error
#    1260                         retryable = False
# -> 1261                     return func(session, sock_info, retryable)
#    1262             except ServerSelectionTimeoutError:
#    1263                 if is_retrying():
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\bulk.py in retryable_bulk(session, sock_info, retryable)
#     336
#     337         def retryable_bulk(session, sock_info, retryable):
# --> 338             self._execute_command(
#     339                 generator, write_concern, session, sock_info, op_id,
#     340                 retryable, full_result)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\bulk.py in _execute_command(self, generator, write_concern, session, sock_info, op_id, retryable, full_result)
#     292                 ops = islice(run.ops, run.idx_offset, None)
#     293                 # Run as many ops as possible in one command.
# --> 294                 result, to_send = bwc.execute(cmd, ops, client)
#     295
#     296                 # Retryable writeConcernErrors halt the execution of this run.
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\message.py in execute(self, cmd, docs, client)
#     735     def execute(self, cmd, docs, client):
#     736         request_id, msg, to_send = self._batch_command(cmd, docs)
# --> 737         result = self.write_command(cmd, request_id, msg, to_send)
#     738         client._process_response(result, self.session)
#     739         return result, to_send
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\message.py in write_command(self, cmd, request_id, msg, docs)
#     818             start = datetime.datetime.now()
#     819         try:
# --> 820             reply = self.sock_info.write_command(request_id, msg)
#     821             if self.publish:
#     822                 duration = (datetime.datetime.now() - start) + duration
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\pool.py in write_command(self, request_id, msg)
#     797
#     798         # Raises NotPrimaryError or OperationFailure.
# --> 799         helpers._check_command_response(result, self.max_wire_version)
#     800         return result
#     801
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     168         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     169
# --> 170     raise OperationFailure(errmsg, code, response, max_wire_version)
#     171
#     172
#
# OperationFailure: you are over your space quota, using 514 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 514 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}
