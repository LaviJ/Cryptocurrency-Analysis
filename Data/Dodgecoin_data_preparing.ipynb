# %% [markdown]
# # Extracting Data from https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory and preprocessing and saving onto a MongoDB database

# %%
# import libraries
import pandas as pd
import numpy as np
import pymongo
from pymongo import MongoClient
import certifi

# %%
# create a dataframe from the csv
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_Kaggle_Historical/coin_Dogecoin.csv"
df = pd.read_csv(path)
df
# Out:
#        SNo      Name Symbol                 Date      High       Low  \
# 0        1  Dogecoin   DOGE  2013-12-16 23:59:59  0.000866  0.000150
# 1        2  Dogecoin   DOGE  2013-12-17 23:59:59  0.000289  0.000116
# 2        3  Dogecoin   DOGE  2013-12-18 23:59:59  0.000362  0.000205
# 3        4  Dogecoin   DOGE  2013-12-19 23:59:59  0.001520  0.000328
# 4        5  Dogecoin   DOGE  2013-12-20 23:59:59  0.001143  0.000662
# ...    ...       ...    ...                  ...       ...       ...
# 2755  2756  Dogecoin   DOGE  2021-07-02 23:59:59  0.247997  0.238848
# 2756  2757  Dogecoin   DOGE  2021-07-03 23:59:59  0.250214  0.242454
# 2757  2758  Dogecoin   DOGE  2021-07-04 23:59:59  0.252567  0.243425
# 2758  2759  Dogecoin   DOGE  2021-07-05 23:59:59  0.246419  0.227838
# 2759  2760  Dogecoin   DOGE  2021-07-06 23:59:59  0.241910  0.229842
#
#           Open     Close        Volume     Marketcap
# 0     0.000299  0.000205  0.000000e+00  1.509085e+06
# 1     0.000207  0.000269  0.000000e+00  2.169688e+06
# 2     0.000267  0.000362  0.000000e+00  3.188943e+06
# 3     0.000395  0.001162  0.000000e+00  1.115034e+07
# 4     0.001143  0.000704  0.000000e+00  7.284337e+06
# ...        ...       ...           ...           ...
# 2755  0.243982  0.245264  1.321471e+09  3.194925e+10
# 2756  0.245106  0.246411  9.170158e+08  3.210491e+10
# 2757  0.246425  0.246483  9.735115e+08  3.211767e+10
# 2758  0.246419  0.231614  1.267949e+09  3.018344e+10
# 2759  0.231216  0.234422  1.265920e+09  3.055252e+10
#
# [2760 rows x 10 columns]

# %%
# checking for mull values
df.isnull().sum().sum()
df.isna().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
# dropping irrelevant columns
df = df.drop(columns=['SNo', 'Symbol'])
df.head()
# Out:
#        Name                 Date      High       Low      Open     Close  \
# 0  Dogecoin  2013-12-16 23:59:59  0.000866  0.000150  0.000299  0.000205
# 1  Dogecoin  2013-12-17 23:59:59  0.000289  0.000116  0.000207  0.000269
# 2  Dogecoin  2013-12-18 23:59:59  0.000362  0.000205  0.000267  0.000362
# 3  Dogecoin  2013-12-19 23:59:59  0.001520  0.000328  0.000395  0.001162
# 4  Dogecoin  2013-12-20 23:59:59  0.001143  0.000662  0.001143  0.000704
#
#    Volume     Marketcap
# 0     0.0  1.509085e+06
# 1     0.0  2.169688e+06
# 2     0.0  3.188943e+06
# 3     0.0  1.115034e+07
# 4     0.0  7.284337e+06

# %%
# converting date to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# data being analyzed for last five years, so filtering data for that date range
start = '2016-07-06'
end = '2021-07-06'

# %%
# creating a variable to store that date range
fiveyears = (df['Date']>start) & (df['Date']<= end)

# %%
# creating a new dataframe after applying the above filters
dodgecoin_df = df.loc[fiveyears]
dodgecoin_df
# Out:
#           Name                Date      High       Low      Open     Close  \
# 933   Dogecoin 2016-07-06 23:59:59  0.000290  0.000278  0.000288  0.000284
# 934   Dogecoin 2016-07-07 23:59:59  0.000284  0.000267  0.000284  0.000275
# 935   Dogecoin 2016-07-08 23:59:59  0.000281  0.000272  0.000275  0.000277
# 936   Dogecoin 2016-07-09 23:59:59  0.000279  0.000265  0.000276  0.000270
# 937   Dogecoin 2016-07-10 23:59:59  0.000274  0.000267  0.000270  0.000272
# ...        ...                 ...       ...       ...       ...       ...
# 2754  Dogecoin 2021-07-01 23:59:59  0.260092  0.238677  0.253828  0.244549
# 2755  Dogecoin 2021-07-02 23:59:59  0.247997  0.238848  0.243982  0.245264
# 2756  Dogecoin 2021-07-03 23:59:59  0.250214  0.242454  0.245106  0.246411
# 2757  Dogecoin 2021-07-04 23:59:59  0.252567  0.243425  0.246425  0.246483
# 2758  Dogecoin 2021-07-05 23:59:59  0.246419  0.227838  0.246419  0.231614
#
#             Volume     Marketcap
# 933   1.777410e+06  2.980788e+07
# 934   2.387940e+05  2.885207e+07
# 935   2.474120e+05  2.915545e+07
# 936   1.463280e+05  2.840995e+07
# 937   1.166160e+05  2.860405e+07
# ...            ...           ...
# 2754  2.463947e+09  3.185285e+10
# 2755  1.321471e+09  3.194925e+10
# 2756  9.170158e+08  3.210491e+10
# 2757  9.735115e+08  3.211767e+10
# 2758  1.267949e+09  3.018344e+10
#
# [1826 rows x 8 columns]

# %%
# exporting the dataframe to csv
dodgecoin_df.to_csv('dodgecoin(fiveyears).csv')

# %% [markdown]
# # Storing file in MongoDB (DB name : Finale)

# %%
# Read in mongodb server location as client
client = MongoClient("mongodb+srv://Group7:Finale@finalsegment1.690c0.mongodb.net/bitcoin_db?retryWrites=true&w=majority",tlsCAFile=certifi.where())

# %%
# Find Databases
client.list_database_names()
# Out:
# ['Bitcoin_db',
#  'Cardano_DB',
#  'Ethereum_db',
#  'Finale',
#  'Tether_DB',
#  'XRP_DB',
#  'admin',
#  'local']

# %%
# connecting to the db on MongoDb and creating collection in the db
db = client['Finale']
collection = db['Dodgecoin']

# %%
# adding dataframe to mongoDb
dodgecoin_df.reset_index(inplace=True)
dodgecoin_df_dict = dodgecoin_df.to_dict("records")

# %%
# Insert collection
collection.insert_many(dodgecoin_df_dict)
