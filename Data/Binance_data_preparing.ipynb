# %% [markdown]
# # Extracting Data from https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory and preprocessing and saving onto a MongoDB database

# %%
# import libraries
import pandas as pd
import numpy as np
import pymongo
from pymongo import MongoClient
import certifi

# %%
# create a dataframe from the csv
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_Kaggle_Historical/coin_BinanceCoin.csv"
df = pd.read_csv(path)
df
# Out:
#        SNo          Name Symbol                 Date        High         Low  \
# 0        1  Binance Coin    BNB  2017-07-26 23:59:59    0.109013    0.099266
# 1        2  Binance Coin    BNB  2017-07-27 23:59:59    0.108479    0.100888
# 2        3  Binance Coin    BNB  2017-07-28 23:59:59    0.109019    0.101473
# 3        4  Binance Coin    BNB  2017-07-29 23:59:59    0.111264    0.101108
# 4        5  Binance Coin    BNB  2017-07-30 23:59:59    0.108138    0.103162
# ...    ...           ...    ...                  ...         ...         ...
# 1437  1438  Binance Coin    BNB  2021-07-02 23:59:59  290.621683  277.350302
# 1438  1439  Binance Coin    BNB  2021-07-03 23:59:59  302.605867  283.434010
# 1439  1440  Binance Coin    BNB  2021-07-04 23:59:59  314.713019  292.787370
# 1440  1441  Binance Coin    BNB  2021-07-05 23:59:59  307.684855  293.523465
# 1441  1442  Binance Coin    BNB  2021-07-06 23:59:59  321.520965  302.195584
#
# ...

# %%
# checking for mull values
df.isnull().sum().sum()
df.isna().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
# dropping irrelevant columns
df = df.drop(columns=['SNo', 'Symbol'])
df.head()
# Out:
#            Name                 Date      High       Low      Open     Close  \
# 0  Binance Coin  2017-07-26 23:59:59  0.109013  0.099266  0.105893  0.105138
# 1  Binance Coin  2017-07-27 23:59:59  0.108479  0.100888  0.105108  0.107737
# 2  Binance Coin  2017-07-28 23:59:59  0.109019  0.101473  0.107632  0.104067
# 3  Binance Coin  2017-07-29 23:59:59  0.111264  0.101108  0.104782  0.107811
# 4  Binance Coin  2017-07-30 23:59:59  0.108138  0.103162  0.107935  0.106414
#
#      Volume   Marketcap
# 0  200395.0  10513800.0
# 1  344499.0  10773700.0
# 2  342568.0  10406700.0
# 3  340218.0  10781100.0
# 4  224261.0  10641400.0

# %%
# converting date to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# %%
# data being analyzed for last five years, so filtering data for that date range
start = '2016-07-06'
end = '2021-07-06'

# %%
# creating a variable to store that date range
fiveyears = (df['Date']>start) & (df['Date']<= end)

# %%
# creating a new dataframe after applying the above filters
binance_df = df.loc[fiveyears]
binance_df
# Out:
#               Name                Date        High         Low        Open  \
# 0     Binance Coin 2017-07-26 23:59:59    0.109013    0.099266    0.105893
# 1     Binance Coin 2017-07-27 23:59:59    0.108479    0.100888    0.105108
# 2     Binance Coin 2017-07-28 23:59:59    0.109019    0.101473    0.107632
# 3     Binance Coin 2017-07-29 23:59:59    0.111264    0.101108    0.104782
# 4     Binance Coin 2017-07-30 23:59:59    0.108138    0.103162    0.107935
# ...            ...                 ...         ...         ...         ...
# 1436  Binance Coin 2021-07-01 23:59:59  303.527365  281.579137  303.527365
# 1437  Binance Coin 2021-07-02 23:59:59  290.621683  277.350302  287.754456
# 1438  Binance Coin 2021-07-03 23:59:59  302.605867  283.434010  287.215592
# 1439  Binance Coin 2021-07-04 23:59:59  314.713019  292.787370  298.113557
# 1440  Binance Coin 2021-07-05 23:59:59  307.684855  293.523465  307.684855
#
#            Close        Volume     Marketcap
# ...

# %%
# exporting the dataframe to csv
binance_df.to_csv('binance(fiveyears).csv')

# %% [markdown]
# # Storing file in MongoDB (DB name : Finale)

# %%
# Read in mongodb server location as client
client = MongoClient("mongodb+srv://Group7:Finale@finalsegment1.690c0.mongodb.net/bitcoin_db?retryWrites=true&w=majority",tlsCAFile=certifi.where())

# %%
# Find Databases
client.list_database_names()
# Out:
# ['Bitcoin_db',
#  'Cardano_DB',
#  'Ethereum_db',
#  'Finale',
#  'Tether_DB',
#  'XRP_DB',
#  'admin',
#  'local']

# %%
# connecting to the db on MongoDb and creating collection in the db
db = client['Finale']
collection = db['Binance']

# %%
# adding dataframe to mongoDb
binance_df.reset_index(inplace=True)
binance_df_dict = binance_df.to_dict("records")

# %%
# Insert collection
collection.insert_many(binance_df_dict)
