# %%
import requests
from config import cckey
import pandas as pd
import sys, json
import json
import datetime

# Get hourly market data for the following cryptocurrencies:

#1.	Bitcoin     BTC
#2.	Ethereum    ETH
#3.	XRP         XRP
#4.	Tether      USDT
#5.	Cardano     ADA
#6.	Monero      XMR
#7.	Stellar     XLM
#8.	BinanceUSD  BUSD
#9. Litecoin    LTC
#10.Dogecoin    DOGE

symbols=['BTC','ETH','XRP','USDT','ADA','XMR','XLM','BUSD','LTC','DOGE']
for symbol in symbols:

    df = results = pd.DataFrame()
    url = 'https://min-api.cryptocompare.com/data/v2/histominute?'

    # Initial toTimeStamp is set to -1 (up to the timestamp of the call)
    totime = 0
    while (1):
        params = {'fsym':symbol,'tsym':'USD','limit':'2000','toTs':totime-1,'api_key':cckey}
        response = requests.get(url, params=params).json()
        if response['Response'] != 'Success':
            break

        # Append the 2000 rows of data to the dataframe
        i = len(response['Data']['Data'])-1
        while (i >= 0):
            data = response['Data']['Data'][i]
            results = pd.DataFrame(data=response['Data']['Data'][i],index=['time'])
            df = df.append(results.set_index('time'))
            i -= 1
            
        # Stop when we reach the hour of BTC Genesis
        totime = response['Data']['TimeFrom']
        if totime < 1579564800:
            break
            
        # Report status
        print("Got to timestamp "+str(totime)+' '+str( datetime.datetime.fromtimestamp(totime)))
        
    # Report final status and save csv file
    print("  Got to timestamp "+str(totime)+' '+str( datetime.datetime.fromtimestamp(totime)))
    print("  Done with "+symbol)
    df.to_csv("perminute_"+symbol+".csv")

print("Done with everything.")
# Out:
# Got to timestamp 1642653180 2022-01-19 20:33:00
# Got to timestamp 1642533120 2022-01-18 11:12:00
# Got to timestamp 1642413060 2022-01-17 01:51:00
# Got to timestamp 1642293000 2022-01-15 16:30:00
# Got to timestamp 1642172940 2022-01-14 07:09:00
# Got to timestamp 1642168440 2022-01-14 05:54:00
#   Got to timestamp 1642168440 2022-01-14 05:54:00
#   Done with BTC
# Got to timestamp 1642653240 2022-01-19 20:34:00
# Got to timestamp 1642533180 2022-01-18 11:13:00
# Got to timestamp 1642413120 2022-01-17 01:52:00
# Got to timestamp 1642293060 2022-01-15 16:31:00
# Got to timestamp 1642173000 2022-01-14 07:10:00
# Got to timestamp 1642168440 2022-01-14 05:54:00
#   Got to timestamp 1642168440 2022-01-14 05:54:00
#   Done with ETH
# Got to timestamp 1642653240 2022-01-19 20:34:00
# Got to timestamp 1642533180 2022-01-18 11:13:00
# Got to timestamp 1642413120 2022-01-17 01:52:00
# Got to timestamp 1642293060 2022-01-15 16:31:00
# Got to timestamp 1642173000 2022-01-14 07:10:00
# Got to timestamp 1642168440 2022-01-14 05:54:00
#   Got to timestamp 1642168440 2022-01-14 05:54:00
#   Done with XRP
# Got to timestamp 1642653240 2022-01-19 20:34:00
