# %% [markdown]
# # Running sentiment analysis on extracted news Data from cryptocompare.com and

# %% [markdown]
# # Sentiment Analysis using Crypto News

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\lavin\anaconda3\envs\PythonData\python.exe

# %%
# import libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import pymongo
from pymongo import MongoClient
import certifi
from mongo2_config import mongo_uri
from wordcloud import WordCloud, STOPWORDS
import datetime
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline
plt.style.use('fivethirtyeight')

from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import nltk

# %%
# create a dataframe from the csv
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_News_Cryptocomp\Top_news_2016to2019_08_03(5year).csv"
df1 = pd.read_csv(path)
df1
# Out:
#         Unnamed: 0       id  \
# 0                0       85
# 1                1    14842
# 2                2       85
# 3                3    14842
# 4                4       85
# ...            ...      ...
# 164417      164417  2670546
# 164418      164418  2669812
# 164419      164419  2667921
# 164420      164420  2666316
# 164421      164421  2665626
#
#                                                      guid  published_on  \
# 0       http://coremedia.info/supernet/item/274-supern...    1468195200
# 1       http://www.cryptocoremedia.com/old/supernet/it...    1468195200
# 2       http://coremedia.info/supernet/item/274-supern...    1468195200
# 3       http://www.cryptocoremedia.com/old/supernet/it...    1468195200
# 4       http://coremedia.info/supernet/item/274-supern...    1468195200
# ...                                                   ...           ...
# 164417               https://www.cryptonewsz.com/?p=34644    1564925410
# 164418                       http://coingape.com/?p=38622    1564922749
# 164419                     https://dailyhodl.com/?p=59988    1564916433
# 164420               https://www.cryptonewsz.com/?p=34614    1564911316
# 164421                 https://www.coindesk.com/?p=412915    1564909200
#
#                                                  imageurl  \
# 0       https://images.cryptocompare.com/news/default/...
# 1       https://images.cryptocompare.com/news/coremedi...
# 2       https://images.cryptocompare.com/news/default/...
# 3       https://images.cryptocompare.com/news/coremedi...
# 4       https://images.cryptocompare.com/news/default/...
# ...                                                   ...
# 164417  https://images.cryptocompare.com/news/cryptone...
# 164418  https://images.cryptocompare.com/news/coingape...
# 164419  https://images.cryptocompare.com/news/dailyhod...
# 164420  https://images.cryptocompare.com/news/cryptone...
# 164421  https://images.cryptocompare.com/news/coindesk...
#
#                                                     title  \
# 0                                  SuperNET Weekly No. 18
# 1                                  SuperNET Weekly No. 18
# 2                                  SuperNET Weekly No. 18
# 3                                  SuperNET Weekly No. 18
# 4                                  SuperNET Weekly No. 18
# ...                                                   ...
# 164417  Ethereum Price Analysis: Ethereum (ETH) Price ...
# 164418  Crypto-Market Top Weekly Performers: Bitcoin, ...
# 164419  Microsoft Reveals New Ethereum-Based Project –...
# 164420  Tezos Price Analysis: Tezos Price Trading Belo...
# 164421  From Ghana to the Bronx, Meet the Teen Bitcoin...
#
#                                                       url             source  \
# 0       http://coremedia.info/supernet/item/274-supern...  coremediasupernet
# 1       http://www.cryptocoremedia.com/old/supernet/it...  coremediasupernet
# 2       http://coremedia.info/supernet/item/274-supern...  coremediasupernet
# 3       http://www.cryptocoremedia.com/old/supernet/it...  coremediasupernet
# 4       http://coremedia.info/supernet/item/274-supern...  coremediasupernet
# ...                                                   ...                ...
# 164417  https://www.cryptonewsz.com/ethereum-price-ana...        cryptonewsz
# 164418  https://coingape.com/crypto-market-btc-xmr-xtz...           coingape
# 164419  https://dailyhodl.com/2019/08/04/microsoft-rev...          dailyhodl
# 164420  https://www.cryptonewsz.com/tezos-price-analys...        cryptonewsz
# 164421  https://www.coindesk.com/from-ghana-to-the-bro...           coindesk
#
#                                                      body  \
# 0       CORE and CORE Media were birthed out of the co...
# 1       CORE and CORE Media were birthed out of the co...
# 2       CORE and CORE Media were birthed out of the co...
# 3       CORE and CORE Media were birthed out of the co...
# 4       CORE and CORE Media were birthed out of the co...
# ...                                                   ...
# 164417  Intraday chart embarks downtrend in Ethereum p...
# 164418  Bitcoin [BTC] broke above $10,000 due to risin...
# 164419  The company plans to decentralize AI by allowi...
# 164420  Tim Coulter, Owner, and Founder of Truffle, wh...
# 164421  From experimenting with zcash in the Bronx to ...
#
#                                                      tags  \
# 0                                           SuperNET News
# 1                                           SuperNET News
# 2                                           SuperNET News
# 3                                           SuperNET News
# 4                                           SuperNET News
# ...                                                   ...
# 164417  Price Analysis|Cryptocurrency|Ethereum (ETH)|P...
# 164418  Altcoin News|bitcoin cash|Bitcoin News|Ethereu...
# 164419  Altcoins|Crypto|Cryptocurrency|ETH|Ethereum|Li...
# 164420  Price Analysis|Cryptocurrency|Price Prediction...
# 164421     Features|Bitcoin|Ethereum|Education|zcash|Teen
#
#                              categories  upvotes  downvotes lang  \
# 0       Blockchain|Technology|Sponsored        0          0   EN
# 1       Blockchain|Technology|Sponsored        0          0   EN
# 2       Blockchain|Technology|Sponsored        0          0   EN
# 3       Blockchain|Technology|Sponsored        0          0   EN
# 4       Blockchain|Technology|Sponsored        0          0   EN
# ...                                 ...      ...        ...  ...
# 164417      ETH|Trading|Market|Business        0          0   EN
# 164418              XMR|BCH|ETH|Trading        0          0   EN
# 164419              LTC|XRP|ETH|Altcoin        0          0   EN
# 164420               Trading|Market|ETH        0          0   EN
# 164421                      BTC|ZEC|ETH        0          0   EN
#
#        source_info.name source_info.lang  \
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ...                 ...              ...
# 164417      CryptoNewsZ               EN
# 164418         CoinGape               EN
# 164419   The Daily Hodl               EN
# 164420      CryptoNewsZ               EN
# 164421         CoinDesk               EN
#
#                                           source_info.img Coin_Symbol  \
# 0                                                     NaN         XLM
# 1                                                     NaN         XLM
# 2                                                     NaN        BUSD
# 3                                                     NaN        BUSD
# 4                                                     NaN        DOGE
# ...                                                   ...         ...
# 164417  https://images.cryptocompare.com/news/default/...         ETH
# 164418  https://images.cryptocompare.com/news/default/...         ETH
# 164419  https://images.cryptocompare.com/news/default/...         ETH
# 164420  https://images.cryptocompare.com/news/default/...         ETH
# 164421  https://images.cryptocompare.com/news/default/...         ETH
#
#                    Rev_time Dt_Rev_time
# 0       2016-07-11 00:00:00  2016-07-11
# 1       2016-07-11 00:00:00  2016-07-11
# 2       2016-07-11 00:00:00  2016-07-11
# 3       2016-07-11 00:00:00  2016-07-11
# 4       2016-07-11 00:00:00  2016-07-11
# ...                     ...         ...
# 164417  2019-08-04 13:30:10  2019-08-04
# 164418  2019-08-04 12:45:49  2019-08-04
# 164419  2019-08-04 11:00:33  2019-08-04
# 164420  2019-08-04 09:35:16  2019-08-04
# 164421  2019-08-04 09:00:00  2019-08-04
#
# [164422 rows x 20 columns]

# %%
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_News_Cryptocomp\Top_news_2019to2020_02_28(5year).csv"
df2 = pd.read_csv(path)
df2
# Out:
#        Unnamed: 0       id                                               guid  \
# 0               0  2679165  https://cointelegraph.com/news/why-is-the-us-n...
# 1               1  2678549             https://www.cryptopolitan.com/?p=21780
# 2               2  2678222                      https://www.ccn.com/?p=194647
# 3               3  2678040  https://www.cryptoglobe.com/latest/2019/08/hil...
# 4               4  2677786                  https://www.newsbtc.com/?p=392200
# ...           ...      ...                                                ...
# 54986       54986  9999274                      https://zycrypto.com/?p=39358
# 54987       54987  9990985                     https://dailyhodl.com/?p=88000
# 54988       54988  9977763                       http://coingape.com/?p=64417
# 54989       54989  9974493                   https://bitcoinist.com/?p=129081
# 54990       54990  9969271               https://www.cryptonewsz.com/?p=59921
#
#        published_on                                           imageurl  \
# 0        1564959300  https://images.cryptocompare.com/news/cointele...
# 1        1564957077  https://images.cryptocompare.com/news/cryptopo...
# 2        1564956000  https://images.cryptocompare.com/news/ccn/cqM1...
# 3        1564955287  https://images.cryptocompare.com/news/cryptogl...
# 4        1564954212  https://images.cryptocompare.com/news/newsbtc/...
# ...             ...                                                ...
# 54986    1582999786  https://images.cryptocompare.com/news/zycrypto...
# 54987    1582989303  https://images.cryptocompare.com/news/dailyhod...
# 54988    1582973590  https://images.cryptocompare.com/news/coingape...
# 54989    1582969532  https://images.cryptocompare.com/news/bitcoini...
# 54990    1582963257  https://images.cryptocompare.com/news/cryptone...
#
#                                                    title  \
# 0      Why Is the US Not Yet a Leader in Crypto Regul...
# 1      Bank of China explains Bitcoin position and pr...
# 2      BitMEXodus: Bitcoin Traders Abandon Exchange A...
# 3      Hilarious Collection of Crypto Twitter Predict...
# 4      Max Keiser Claims Bitcoin May Target $15,000 T...
# ...                                                  ...
# 54986  Ripple’s Untapped Potential – XRP Ledger As A ...
# 54987  3 Million Traders Reveal Most Popular Crypto A...
# 54988  XRP Rebounds from .886 Fib Retracement – Will ...
# 54989  Here’s How Ripple Will Power Remittances to th...
# 54990   XRP Resumes its Rebound Today; May Reclaim $0.24
#
#                                                      url         source  \
# 0      https://cointelegraph.com/news/why-is-the-us-n...  cointelegraph
# 1      https://www.cryptopolitan.com/bank-of-china-ex...  cryptopolitan
# 2      https://www.ccn.com/crypto/bitcoin-traders-fle...            ccn
# 3      https://www.cryptoglobe.com/latest/2019/08/hil...    cryptoglobe
# 4      https://www.newsbtc.com/2019/08/04/max-keiser-...        newsbtc
# ...                                                  ...            ...
# 54986  https://zycrypto.com/ripples-untapped-potentia...       zycrypto
# 54987  https://dailyhodl.com/2020/02/29/3-million-tra...      dailyhodl
# 54988  https://coingape.com/xrp-rebounds-from-886-fib...       coingape
# 54989  https://bitcoinist.com/ripple-dubai-bank-remit...     bitcoinist
# 54990  https://www.cryptonewsz.com/xrp-resumes-its-re...    cryptonewsz
#
#                                                     body  \
# 0      Experts in crypto and blockchain take on the q...
# 1      What might have been thought to be happening i...
# 2      July wasn't exactly a banner month for crypto ...
# 3      Crypto users took to Twitter to give their pre...
# 4      Bitcoin and the aggregated crypto markets have...
# ...                                                  ...
# 54986  Since its inception back in 2012, Ripple has b...
# 54987  A year-long poll at a London-based crypto exch...
# 54988  XRP dropped by 13% over the past 7-days of tra...
# 54989  The Dubai-based RAKBANK and BDO Unibank (a ful...
# 54990  XRP aims to remain stable above $0.24 though b...
#
#                                                     tags  \
# 0      Bitcoin|Cryptocurrencies|Blockchain|USA|regula...
# 1      Bitcoin News|bank of china bitcoin|bank of chi...
# 2      Bitcoin Analysis|Bitcoin Exchange|Cryptocurren...
# 3                              Bitcoin|Ethereum|Altcoins
# 4                      Bitcoin|Crypto|bitcoin|btc|crypto
# ...                                                  ...
# 54986                           News|XRP|Ripple|XRP News
# 54987  Altcoins|Ripple and XRP|Bitcoin|BTC|Crypto|New...
# 54988    Price Analysis|Ripple Price Analysis|xrp|xrpusd
# 54989  Altcoins|News|News teaser|Ripple|ripple|Ripple...
# 54990                                                NaN
#
#                                       categories  upvotes  downvotes lang  \
# 0                      Regulation|Blockchain|BTC        0          0   EN
# 1                       BTC|Fiat|Asia|Regulation        0          0   EN
# 2           BTC|Exchange|Market|Trading|Business        0          0   EN
# 3          BTC|ETH|Blockchain|Technology|Altcoin        0          0   EN
# 4                             BTC|Market|Trading        0          0   EN
# ...                                          ...      ...        ...  ...
# 54986  XRP|Exchange|Blockchain|Technology|Wallet        0          0   EN
# 54987                BTC|ETH|XRP|Exchange|Market        0          0   EN
# 54988                         XRP|Market|Trading        0          0   EN
# 54989                           XRP|Fiat|Altcoin        0          0   EN
# 54990                                        XRP        0          0   EN
#
#       source_info.name source_info.lang  \
# 0        CoinTelegraph               EN
# 1        Cryptopolitan               EN
# 2                  CCN               EN
# 3          CryptoGlobe               EN
# 4              NewsBTC               EN
# ...                ...              ...
# 54986         ZyCrypto               EN
# 54987   The Daily Hodl               EN
# 54988         CoinGape               EN
# 54989       Bitcoinist               EN
# 54990      CryptoNewsZ               EN
#
#                                          source_info.img Coin_Symbol  \
# 0      https://images.cryptocompare.com/news/default/...         BTC
# 1      https://images.cryptocompare.com/news/default/...         BTC
# 2      https://images.cryptocompare.com/news/default/...         BTC
# 3      https://images.cryptocompare.com/news/default/...         BTC
# 4      https://images.cryptocompare.com/news/default/...         BTC
# ...                                                  ...         ...
# 54986  https://images.cryptocompare.com/news/default/...         XRP
# 54987  https://images.cryptocompare.com/news/default/...         XRP
# 54988  https://images.cryptocompare.com/news/default/...         XRP
# 54989  https://images.cryptocompare.com/news/default/...         XRP
# 54990  https://images.cryptocompare.com/news/default/...         XRP
#
#                   Rev_time Dt_Rev_time
# 0      2019-08-04 22:55:00  2019-08-04
# 1      2019-08-04 22:17:57  2019-08-04
# 2      2019-08-04 22:00:00  2019-08-04
# 3      2019-08-04 21:48:07  2019-08-04
# 4      2019-08-04 21:30:12  2019-08-04
# ...                    ...         ...
# 54986  2020-02-29 18:09:46  2020-02-29
# 54987  2020-02-29 15:15:03  2020-02-29
# 54988  2020-02-29 10:53:10  2020-02-29
# 54989  2020-02-29 09:45:32  2020-02-29
# 54990  2020-02-29 08:00:57  2020-02-29
#
# [54991 rows x 20 columns]

# %%
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_News_Cryptocomp\Top_news_2020to2020_03_03(5year).csv"
df3 = pd.read_csv(path)
df3
# Out:
#       Unnamed: 0        id                                               guid  \
# 0              0  10019143                        https://nulltx.com/?p=98360
# 1              1  10013325                  https://www.newsbtc.com/?p=416461
# 2              2  10011232                     https://dailyhodl.com/?p=88056
# 3              3  10010416           https://www.livebitcoinnews.com/?p=58155
# 4              4  10010417                  https://www.newsbtc.com/?p=416462
# ...          ...       ...                                                ...
# 1136        1136  10281802                 https://eng.ambcrypto.com/?p=35212
# 1137        1137  10281734      https://www.theblockcrypto.com/genesis/57794/
# 1138        1138  12279902        https://btcmagwpstage.wpengine.com/?p=39076
# 1139        1139  10281516               https://bitcoinmagazine.com/?p=39076
# 1140        1140  10281679  https://cointelegraph.com/news/crypto-taxes-a-...
#
#       published_on                                           imageurl  \
# 0       1583017232  https://images.cryptocompare.com/news/themerkl...
# 1       1583017222  https://images.cryptocompare.com/news/newsbtc/...
# 2       1583014539  https://images.cryptocompare.com/news/dailyhod...
# 3       1583013629  https://images.cryptocompare.com/news/livebitc...
# 4       1583013622  https://images.cryptocompare.com/news/newsbtc/...
# ...            ...                                                ...
# 1136    1583350258  https://images.cryptocompare.com/news/ambcrypt...
# 1137    1583350158  https://images.cryptocompare.com/news/theblock...
# 1138    1583349968  https://images.cryptocompare.com/news/bitcoinm...
# 1139    1583349968  https://images.cryptocompare.com/news/bitcoinm...
# 1140    1583349540  https://images.cryptocompare.com/news/cointele...
#
#                                                   title  \
# 0     Texas Becomes an Increasingly Popular Region f...
# 1     Crypto Tidbits: Bitcoin Plunges Under $9,000, ...
# 2     Veteran Trader Who Predicted Bitcoin (BTC) Ris...
# 3       The U.S. Says “No” to Any and All Petro Trading
# 4     This Crypto Just Set All-Time Highs, and Analy...
# ...                                                 ...
# 1136  Bitcoin's OI and volume put/call ratio close t...
# 1137  Lightning in a bottle: liquidity on the Lightn...
# 1138  Amir Taaki on Bitcoin and Building Dissident T...
# 1139  Amir Taaki on Bitcoin and Building Dissident T...
# 1140  Crypto Taxes a ‘Nightmare' — Congress Hears th...
#
#                                                     url           source  \
# 0     https://nulltx.com/texas-becomes-an-increasing...        themerkle
# 1     https://www.newsbtc.com/2020/02/29/crypto-tidb...          newsbtc
# 2     https://dailyhodl.com/2020/02/29/veteran-trade...        dailyhodl
# 3     https://www.livebitcoinnews.com/the-u-s-says-n...  livebitcoinnews
# 4     https://www.newsbtc.com/2020/02/29/this-crypto...          newsbtc
# ...                                                 ...              ...
# 1136  https://eng.ambcrypto.com/bitcoins-oi-and-volu...        ambcrypto
# 1137  https://www.theblockcrypto.com/genesis/57794/l...         theblock
# 1138  https://btcmagwpstage.wpengine.com/articles/am...  bitcoinmagazine
# 1139  https://bitcoinmagazine.com/articles/amir-taak...  bitcoinmagazine
# 1140  https://cointelegraph.com/news/crypto-taxes-a-...    cointelegraph
#
#                                                    body  \
# 0     Setting up a reliable and profitable Bitcoin m...
# 1     Another week, another round of Crypto Tidbits....
# 2     A veteran technical trader who was immortalize...
# 3     The U.S. government is being very strict when ...
# 4     Chainlink’s price action throughout 2019 and 2...
# ...                                                 ...
# 1136  As Bitcoin struggled to recover from its radic...
# 1137  Quick TakeBecause Lightning is structured arou...
# 1138  Amir Taaki was one of Bitcoin’s first-ever ded...
# 1139  Amir Taaki was one of Bitcoin’s first-ever ded...
# 1140  One of the witnesses at a recent government bl...
#
#                                                    tags  \
# 0          Crypto|bitcoin mining|Renewable Energy|Texas
# 1          Bitcoin|Crypto|bitcoin|Crypto Tidbits|market
# 2                              Bitcoin|BTC|Markets|News
# 3     Altcoin News|News|Donald Trump|Nicolás Maduro|...
# 4                          Crypto|chainlink|crypto|Link
# ...                                                 ...
# 1136                   Bitcoin|News|Social|Trading View
# 1137                  Bitcoin|bitcoin|lightning network
# 1138    Privacy & Security|amir taaki|dark wallet|syria
# 1139    Privacy & Security|amir taaki|dark wallet|syria
# 1140  Blockchain|Congress|Cryptocurrencies|Governmen...
#
#                           categories  upvotes  downvotes lang  \
# 0                         BTC|Mining        0          0   EN
# 1                BTC|Market|Exchange        0          0   EN
# 2        BTC|Business|Market|Trading        0          0   EN
# 3                        Trading|BTC        0          0   EN
# 4                 Trading|BTC|Market        0          0   EN
# ...                              ...      ...        ...  ...
# 1136                      BTC|Market        0          0   EN
# 1137                             BTC        0          0   EN
# 1138                  BTC|Technology        0          0   EN
# 1139                  BTC|Technology        0          0   EN
# 1140  Regulation|Blockchain|Business        0          0   EN
#
#        source_info.name source_info.lang  \
# 0                NullTx               EN
# 1               NewsBTC               EN
# 2        The Daily Hodl               EN
# 3     Live Bitcoin News               EN
# 4               NewsBTC               EN
# ...                 ...              ...
# 1136         AMB Crypto               EN
# 1137           TheBlock               EN
# 1138   Bitcoin Magazine               EN
# 1139   Bitcoin Magazine               EN
# 1140      CoinTelegraph               EN
#
#                                         source_info.img Coin_Symbol  \
# 0     https://images.cryptocompare.com/news/default/...         BTC
# 1     https://images.cryptocompare.com/news/default/...         BTC
# 2     https://images.cryptocompare.com/news/default/...         BTC
# 3     https://images.cryptocompare.com/news/default/...         BTC
# 4     https://images.cryptocompare.com/news/default/...         BTC
# ...                                                 ...         ...
# 1136  https://images.cryptocompare.com/news/default/...        BUSD
# 1137  https://images.cryptocompare.com/news/default/...        BUSD
# 1138  https://images.cryptocompare.com/news/default/...        BUSD
# 1139  https://images.cryptocompare.com/news/default/...        BUSD
# 1140  https://images.cryptocompare.com/news/default/...        BUSD
#
#                  Rev_time Dt_Rev_time
# 0     2020-02-29 23:00:32  2020-02-29
# 1     2020-02-29 23:00:22  2020-02-29
# 2     2020-02-29 22:15:39  2020-02-29
# 3     2020-02-29 22:00:29  2020-02-29
# 4     2020-02-29 22:00:22  2020-02-29
# ...                   ...         ...
# 1136  2020-03-04 19:30:58  2020-03-04
# 1137  2020-03-04 19:29:18  2020-03-04
# 1138  2020-03-04 19:26:08  2020-03-04
# 1139  2020-03-04 19:26:08  2020-03-04
# 1140  2020-03-04 19:19:00  2020-03-04
#
# [1141 rows x 20 columns]

# %%
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_News_Cryptocomp\Top_news_2020to2020_04_10(5year).csv"
df4 = pd.read_csv(path)
df4
# Out:
#       Unnamed: 0        id                                               guid  \
# 0              0  10224634                  https://www.newsbtc.com/?p=416806
# 1              1  10226419                        https://decrypt.co/?p=21222
# 2              2  10223176                 https://eng.ambcrypto.com/?p=35089
# 3              3  10221720           https://www.livebitcoinnews.com/?p=58186
# 4              4  10221721                  https://www.newsbtc.com/?p=416801
# ...          ...       ...                                                ...
# 9650        9650  12399067                     https://dailyhodl.com/?p=92846
# 9651        9651  12398599                  https://www.newsbtc.com/?p=420419
# 9652        9652  12404908  https://cointelegraph.com/news/price-analysis-...
# 9653        9653  12396838  https://cointelegraph.com/news/ledger-expands-...
# 9654        9654  12378972                   https://bitcoinist.com/?p=132012
#
#       published_on                                           imageurl  \
# 0       1583276402  https://images.cryptocompare.com/news/newsbtc/...
# 1       1583275536  https://images.cryptocompare.com/news/decrypt/...
# 2       1583274630  https://images.cryptocompare.com/news/ambcrypt...
# 3       1583272836  https://images.cryptocompare.com/news/livebitc...
# 4       1583272822  https://images.cryptocompare.com/news/newsbtc/...
# ...            ...                                                ...
# 9650    1586540308  https://images.cryptocompare.com/news/dailyhod...
# 9651    1586539850  https://images.cryptocompare.com/news/newsbtc/...
# 9652    1586546280  https://images.cryptocompare.com/news/cointele...
# 9653    1586537640  https://images.cryptocompare.com/news/cointele...
# 9654    1586517620  https://images.cryptocompare.com/news/bitcoini...
#
#                                                   title  \
# 0     Crypto Will Thrive in 2020 as Governments Stru...
# 1     Cosmos price fails to recover from project in-...
# 2     Chainlink, Algorand, Dogecoin rally as Bitcoin...
# 3            Australia Receives “Test” Version of Libra
# 4     Bitcoin CME Futures Volume is Collapsing Amids...
# ...                                                 ...
# 9650  Consumer Electronics Giant HTC Bringing Crypto...
# 9651  Gold Records Strongest Weekly Close Since Rece...
# 9652  Price Analysis April 10: BTC, ETH, XRP, BCH, B...
# 9653  Ledger Expands Crypto Payment Options with Cry...
# 9654  Bitcoin Cash 51% Attack Cost Is Crazy Cheap Ri...
#
#                                                     url           source  \
# 0     https://www.newsbtc.com/2020/03/03/crypto-will...          newsbtc
# 1     https://decrypt.co/21222/cosmos-price-project-...          decrypt
# 2     https://eng.ambcrypto.com/chainlink-algorand-d...        ambcrypto
# 3     https://www.livebitcoinnews.com/australia-rece...  livebitcoinnews
# 4     https://www.newsbtc.com/2020/03/03/bitcoin-cme...          newsbtc
# ...                                                 ...              ...
# 9650  https://dailyhodl.com/2020/04/10/consumer-elec...        dailyhodl
# 9651  https://www.newsbtc.com/2020/04/10/gold-record...          newsbtc
# 9652  https://cointelegraph.com/news/price-analysis-...    cointelegraph
# 9653  https://cointelegraph.com/news/ledger-expands-...    cointelegraph
# 9654  https://bitcoinist.com/the-cost-of-51-attackin...       bitcoinist
#
#                                                    body  \
# 0     Global efforts to stimulate markets look likel...
# 1     Problems at Cosmos are proving too much for it...
# 2     While Bitcoin regained its dominance of 63.7% ...
# 3     The Reserve Bank of Australia (RBA) says its r...
# 4     The global markets are currently caught within...
# ...                                                 ...
# 9650  Taiwanese consumer electronics giant HTC is br...
# 9651  The original ultra-scarce asset used for trade...
# 9652  Bitcoin needs to stay above $6,500 to maintain...
# 9653  Wallet producer Ledger allows its customers to...
# 9654  According to a site called Crypto 51, the cost...
#
#                                                    tags  \
# 0         Bitcoin|Crypto|bitcoin|bullish|cryptocurrency
# 1     Markets|Atom|bitcoin|Cosmos|cryptocurrency|fin...
# 2     Altcoins|News|Social|Trading View|Hide Cryptop...
# 3       Altcoin News|News|australia|Libra|Tony Richards
# 4                     Bitcoin|Crypto|bitcoin|btc|crypto
# ...                                                 ...
# 9650  Altcoins|crypto mining|htc exodus|monero|News|...
# 9651  Uncategorized|dollar|economy|gold|inflation|re...
# 9652  Bitcoin|Markets|Ethereum|Ripple|Bitcoin Cash|B...
# 9653  Altcoin|hardware wallet|cryptocurrencies|walle...
# 9654  Altcoin News|Bitcoin Cash|News|News teaser|51%...
#
#                          categories  upvotes  downvotes lang  \
# 0                BTC|Market|Trading        0          0   EN
# 1            Trading|BTC|Market|ICO        0          0   EN
# 2        BTC|Market|Trading|Altcoin        0          0   EN
# 3                          Fiat|BTC        0          1   EN
# 4          BTC|Market|Fiat|Business        0          0   EN
# ...                             ...      ...        ...  ...
# 9650  XMR|Mining|BTC|Wallet|Altcoin        0          0   EN
# 9651                   Fiat|Trading        0          0   EN
# 9652         BCH|ETH|LTC|XRP|Market        0          0   EN
# 9653     Wallet|BTC|LTC|XRP|Altcoin        0          0   EN
# 9654                    BCH|ETH|LTC        0          1   EN
#
#        source_info.name source_info.lang  \
# 0               NewsBTC               EN
# 1               Decrypt               EN
# 2            AMB Crypto               EN
# 3     Live Bitcoin News               EN
# 4               NewsBTC               EN
# ...                 ...              ...
# 9650     The Daily Hodl               EN
# 9651            NewsBTC               EN
# 9652      CoinTelegraph               EN
# 9653      CoinTelegraph               EN
# 9654         Bitcoinist               EN
#
#                                         source_info.img Coin_Symbol  \
# 0     https://images.cryptocompare.com/news/default/...         BTC
# 1     https://images.cryptocompare.com/news/default/...         BTC
# 2     https://images.cryptocompare.com/news/default/...         BTC
# 3     https://images.cryptocompare.com/news/default/...         BTC
# 4     https://images.cryptocompare.com/news/default/...         BTC
# ...                                                 ...         ...
# 9650  https://images.cryptocompare.com/news/default/...        BUSD
# 9651  https://images.cryptocompare.com/news/default/...        BUSD
# 9652  https://images.cryptocompare.com/news/default/...         LTC
# 9653  https://images.cryptocompare.com/news/default/...         LTC
# 9654  https://images.cryptocompare.com/news/default/...         LTC
#
#                  Rev_time Dt_Rev_time
# 0     2020-03-03 23:00:02  2020-03-03
# 1     2020-03-03 22:45:36  2020-03-03
# 2     2020-03-03 22:30:30  2020-03-03
# 3     2020-03-03 22:00:36  2020-03-03
# 4     2020-03-03 22:00:22  2020-03-03
# ...                   ...         ...
# 9650  2020-04-10 17:38:28  2020-04-10
# 9651  2020-04-10 17:30:50  2020-04-10
# 9652  2020-04-10 19:18:00  2020-04-10
# 9653  2020-04-10 16:54:00  2020-04-10
# 9654  2020-04-10 11:20:20  2020-04-10
#
# [9655 rows x 20 columns]

# %%
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_News_Cryptocomp\Top_news_2020to2020_06_28(5year).csv"
df5 = pd.read_csv(path)
df5
# Out:
#        Unnamed: 0        id                                          guid  \
# 0               0  12417653                   https://nulltx.com/?p=98731
# 1               1  12411370            https://eng.ambcrypto.com/?p=42198
# 2               2  12409898             https://www.newsbtc.com/?p=420470
# 3               3  12409778             https://cryptoslate.com/?p=130346
# 4               4  12408503                   https://decrypt.co/?p=25225
# ...           ...       ...                                           ...
# 20383       20383  17069790          https://www.cryptonewsz.com/?p=64636
# 20384       20384  17069475  https://www.theblockcrypto.com/linked/69785/
# 20385       20385  17068193             https://www.newsbtc.com/?p=428856
# 20386       20386  17051328             https://www.newsbtc.com/?p=428843
# 20387       20387  17048050             https://www.newsbtc.com/?p=428816
#
#        published_on                                           imageurl  \
# 0        1586556017  https://images.cryptocompare.com/news/themerkl...
# 1        1586554244  https://images.cryptocompare.com/news/ambcrypt...
# 2        1586552459  https://images.cryptocompare.com/news/newsbtc/...
# 3        1586552432  https://images.cryptocompare.com/news/cryptosl...
# 4        1586550908  https://images.cryptocompare.com/news/decrypt/...
# ...             ...                                                ...
# 20383    1593415642  https://images.cryptocompare.com/news/cryptone...
# 20384    1593415305  https://images.cryptocompare.com/news/theblock...
# 20385    1593413925  https://images.cryptocompare.com/news/newsbtc/...
# 20386    1593396052  https://images.cryptocompare.com/news/newsbtc/...
# 20387    1593392423  https://images.cryptocompare.com/news/newsbtc/...
#
#                                                    title  \
# 0      Bitcoin Might not Turn Bullish until After the...
# 1      Bitcoin likely to cross $8000 mark before its ...
# 2      This Crypto Could Explode Over 100% If It Buil...
# 3      Bitcoin’s open interest skyrocketing indicates...
# 4      Venezuelans have a new way to send crypto with...
# ...                                                  ...
# 20383  Are virtual events the new norm? The Story of ...
# 20384  Balancer pools drained of more than $450,000 d...
# 20385  Ethereum Facing Uphill Task Near $228: Here’s ...
# 20386  A Hacker Just Drained $500k in Ethereum & Altc...
# 20387  Here’s Why Ethereum Could Start Nosediving to ...
#
#                                                      url       source  \
# 0      https://nulltx.com/bitcoin-might-not-turn-bull...    themerkle
# 1      https://eng.ambcrypto.com/bitcoin-likely-to-cr...    ambcrypto
# 2      https://www.newsbtc.com/2020/04/10/this-crypto...      newsbtc
# 3      https://cryptoslate.com/bitcoins-open-interest...  cryptoslate
# 4      https://decrypt.co/25225/venezuelans-have-new-...      decrypt
# ...                                                  ...          ...
# 20383  https://www.cryptonewsz.com/are-virtual-events...  cryptonewsz
# 20384  https://www.theblockcrypto.com/linked/69785/ba...     theblock
# 20385  https://www.newsbtc.com/2020/06/29/ethereum-fa...      newsbtc
# 20386  https://www.newsbtc.com/2020/06/29/428843/?utm...      newsbtc
# 20387  https://www.newsbtc.com/2020/06/29/ethereum-co...      newsbtc
#
#                                                     body  \
# 0      There are still many questions regarding the f...
# 1      Fours day after finally breaching the $7000 ma...
# 2      It has been an incredibly volatile year for Ch...
# 3      Bitcoin has seen some notable overnight volati...
# 4      A Venezuelan crypto exchange has developed a s...
# ...                                                  ...
# 20383  Webit Virtual, the first fully transformed vir...
# 20384  Two multi-token pools on Balancer, an automate...
# 20385  Ethereum is currently recovering from the $216...
# 20386  Ethereum&#8217;s budding decentralized finance...
# 20387  Ethereum’s weakness as of late has primarily b...
#
#                                                     tags  \
# 0             Crypto|bitcoin|Coronavirus|Economic Policy
# 1                           Bitcoin|News|Social|Analysis
# 2                       Crypto|chainlink|LINKBTC|LINKUSD
# 3                            Analysis|Price Watch|BTCUSD
# 4                                    Technology|BTC|DASH
# ...                                                  ...
# 20383                                                NaN
# 20384  Crime|DeFi|Ethereum|attacker|balancer|defi exp...
# 20385          Ethereum|Analysis|ethereum|ethusd|ETHUSDT
# 20386   Ethereum|Crypto|Balancer Labs|DeFi|ethereum|hack
# 20387                     Ethereum|ethbtc|ethusd|ETHUSDT
#
#                              categories  upvotes  downvotes lang  \
# 0                    BTC|Trading|Market        0          0   EN
# 1                    BTC|Market|Trading        0          0   EN
# 2                           Trading|BTC        0          0   EN
# 3                    Trading|BTC|Market        0          0   EN
# 4          BTC|DASH|Exchange|Technology        0          0   EN
# ...                                 ...      ...        ...  ...
# 20383                               ETH        0          1   EN
# 20384  Mining|ICO|ETH|Market|Blockchain        0          1   EN
# 20385           ETH|Trading|Market|Fiat        0          1   EN
# 20386                       ETH|Altcoin        0          1   EN
# 20387                   ETH|BTC|Trading        0          1   EN
#
#       source_info.name source_info.lang  \
# 0               NullTx               EN
# 1           AMB Crypto               EN
# 2              NewsBTC               EN
# 3          CryptoSlate               EN
# 4              Decrypt               EN
# ...                ...              ...
# 20383      CryptoNewsZ               EN
# 20384         TheBlock               EN
# 20385          NewsBTC               EN
# 20386          NewsBTC               EN
# 20387          NewsBTC               EN
#
#                                          source_info.img Coin_Symbol  \
# 0      https://images.cryptocompare.com/news/default/...         BTC
# 1      https://images.cryptocompare.com/news/default/...         BTC
# 2      https://images.cryptocompare.com/news/default/...         BTC
# 3      https://images.cryptocompare.com/news/default/...         BTC
# 4      https://images.cryptocompare.com/news/default/...         BTC
# ...                                                  ...         ...
# 20383  https://images.cryptocompare.com/news/default/...         ETH
# 20384  https://images.cryptocompare.com/news/default/...         ETH
# 20385  https://images.cryptocompare.com/news/default/...         ETH
# 20386  https://images.cryptocompare.com/news/default/...         ETH
# 20387  https://images.cryptocompare.com/news/default/...         ETH
#
#                   Rev_time Dt_Rev_time
# 0      2020-04-10 22:00:17  2020-04-10
# 1      2020-04-10 21:30:44  2020-04-10
# 2      2020-04-10 21:00:59  2020-04-10
# 3      2020-04-10 21:00:32  2020-04-10
# 4      2020-04-10 20:35:08  2020-04-10
# ...                    ...         ...
# 20383  2020-06-29 07:27:22  2020-06-29
# 20384  2020-06-29 07:21:45  2020-06-29
# 20385  2020-06-29 06:58:45  2020-06-29
# 20386  2020-06-29 02:00:52  2020-06-29
# 20387  2020-06-29 01:00:23  2020-06-29
#
# [20388 rows x 20 columns]

# %%
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_News_Cryptocomp\Top_news_2020to2021_07_06(5year).csv"
df6 = pd.read_csv(path)
df6
# Out:
#        Unnamed: 0        id  \
# 0               0  17115701
# 1               1  17114683
# 2               2  17113721
# 3               3  17113573
# 4               4  17112472
# ...           ...       ...
# 95831       95831  27010028
# 95832       95832  27010026
# 95833       95833  27010027
# 95834       95834  27010025
# 95835       95835  27010035
#
#                                                     guid  published_on  \
# 0            https://www.coindesk.com/index.php?p=489795    1593469399
# 1                        https://dailyhodl.com/?p=102645    1593468320
# 2                            https://decrypt.co/?p=34011    1593467166
# 3      https://cointelegraph.com/news/researchers-say...    1593466680
# 4      https://cointelegraph.com/news/bitcoin-as-a-to...    1593465480
# ...                                                  ...           ...
# 95831         https://www.theblockcrypto.com/post/110591    1625598316
# 95832                    https://ambcrypto.com/?p=169149    1625598037
# 95833                  https://cryptoslate.com/?p=194428    1625598021
# 95834           https://www.livebitcoinnews.com/?p=65282    1625598011
# 95835                    https://dailyhodl.com/?p=152401    1625597837
#
#                                                 imageurl  \
# 0      https://images.cryptocompare.com/news/coindesk...
# 1      https://images.cryptocompare.com/news/dailyhod...
# 2      https://images.cryptocompare.com/news/decrypt/...
# 3      https://images.cryptocompare.com/news/cointele...
# 4      https://images.cryptocompare.com/news/cointele...
# ...                                                  ...
# 95831  https://images.cryptocompare.com/news/default/...
# 95832  https://images.cryptocompare.com/news/default/...
# 95833  https://images.cryptocompare.com/news/default/...
# 95834  https://images.cryptocompare.com/news/default/...
# 95835  https://images.cryptocompare.com/news/default/...
#
#                                                    title  \
# 0      Digital Currency Guru of $568M Cyber Fraud For...
# 1      XRP Architect David Schwartz Denies Being Bitc...
# 2      How to use DeFi to earn passive income with yo...
# 3      Researchers Say New Lightning Network Attack C...
# 4      Bitcoin as a tool to fight authoritarian regim...
# ...                                                  ...
# 95831  Fintechs are hungry for DeFi yields, says Comp...
# 95832  Why this is crucial to XRP’s trajectory over t...
# 95833  Ripple CTO slams regulators as Barclays blocks...
# 95834  Crypto Head: The U.S. Is the “Most-Ready” Nati...
# 95835  Crypto Exchange Employee Siphons Bitcoin, Admi...
#
#                                                      url           source  \
# 0      https://www.coindesk.com/digital-currency-guru...         coindesk
# 1      https://dailyhodl.com/2020/06/29/xrp-architect...        dailyhodl
# 2      https://decrypt.co/34011/how-defi-earn-passive...          decrypt
# 3      https://cointelegraph.com/news/researchers-say...    cointelegraph
# 4      https://cointelegraph.com/news/bitcoin-as-a-to...    cointelegraph
# ...                                                  ...              ...
# 95831  https://www.theblockcrypto.com/post/110591/fin...         theblock
# 95832  https://ambcrypto.com/why-this-is-crucial-to-x...        ambcrypto
# 95833  https://cryptoslate.com/ripple-cto-slams-regul...      cryptoslate
# 95834  https://www.livebitcoinnews.com/crypto-head-th...  livebitcoinnews
# 95835  https://dailyhodl.com/2021/07/06/crypto-exchan...        dailyhodl
#
#                                                     body  \
# 0      Sergey Medvedev pleaded guilty to racketeering...
# 1      Ripple&#8217;s chief technology officer David ...
# 2      It’s risky—but it can be done: Andreas Antonop...
# 3      The Lightning Network is susceptible to attack...
# 4      Professor of Economics, Sergei Guriev, told Co...
# ...                                                  ...
# 95831  DeFi and traditional finance are converging, s...
# 95832  The global cryptocurrency market noted a bit o...
# 95833  Barclays UK customers have been blocked from t...
# 95834  According to a new report issued by cryptocurr...
# 95835  An ex-employee of the collapsed New Zealand-ba...
#
#                                                     tags  \
# 0            News|Fraud|Escrow|Lawsuit|Credit Card Fraud
# 1           Bitcoin|BTC|News|Ripple|Satoshi Nakamoto|XRP
# 2                                          Coins|BTC|ETH
# 3      Blockchain|Lightning Network|Cybersecurity|Hac...
# 4         Bitcoin|Blockchain|Russia|Economy|Central Bank
# ...                                                  ...
# 95831         The Block|blockchain|DeFi|Ethereum|fintech
# 95832  Altcoins|Analysis|HideCryptopanic|News|News 1|...
# 95833                   Banking|Exchanges|Regulation|xrp
# 95834  Bitcoin News|News|canada|Crypto Head|Cyprus|Un...
# 95835                                   Bitcoin|BTC|News
#
#                          categories  upvotes  downvotes lang  \
# 0                          BTC|Fiat        0          0   EN
# 1                BTC|XRP|Technology        0          0   EN
# 2                           BTC|ETH        0          0   EN
# 3                    BTC|Blockchain        0          0   EN
# 4                    BTC|Blockchain        0          0   EN
# ...                             ...      ...        ...  ...
# 95831                ETH|Blockchain        0          0   EN
# 95832    XRP|Market|Trading|Altcoin        0          0   EN
# 95833  Exchange|XRP|Regulation|Fiat        0          0   EN
# 95834                           BTC        1          0   EN
# 95835                  BTC|Exchange        0          0   EN
#
#         source_info.name source_info.lang  \
# 0               CoinDesk               EN
# 1         The Daily Hodl               EN
# 2                Decrypt               EN
# 3          CoinTelegraph               EN
# 4          CoinTelegraph               EN
# ...                  ...              ...
# 95831           TheBlock               EN
# 95832         AMB Crypto               EN
# 95833        CryptoSlate               EN
# 95834  Live Bitcoin News               EN
# 95835     The Daily Hodl               EN
#
#                                          source_info.img Coin_Symbol  \
# 0      https://images.cryptocompare.com/news/default/...         BTC
# 1      https://images.cryptocompare.com/news/default/...         BTC
# 2      https://images.cryptocompare.com/news/default/...         BTC
# 3      https://images.cryptocompare.com/news/default/...         BTC
# 4      https://images.cryptocompare.com/news/default/...         BTC
# ...                                                  ...         ...
# 95831  https://images.cryptocompare.com/news/default/...        DOGE
# 95832  https://images.cryptocompare.com/news/default/...        DOGE
# 95833  https://images.cryptocompare.com/news/default/...        DOGE
# 95834  https://images.cryptocompare.com/news/default/...        DOGE
# 95835  https://images.cryptocompare.com/news/default/...        DOGE
#
#                   Rev_time Dt_Rev_time
# 0      2020-06-29 22:23:19  2020-06-29
# 1      2020-06-29 22:05:20  2020-06-29
# 2      2020-06-29 21:46:06  2020-06-29
# 3      2020-06-29 21:38:00  2020-06-29
# 4      2020-06-29 21:18:00  2020-06-29
# ...                    ...         ...
# 95831  2021-07-06 19:05:16  2021-07-06
# 95832  2021-07-06 19:00:37  2021-07-06
# 95833  2021-07-06 19:00:21  2021-07-06
# 95834  2021-07-06 19:00:11  2021-07-06
# 95835  2021-07-06 18:57:17  2021-07-06
#
# [95836 rows x 20 columns]

# %%
# checking for mull values
df1.isnull().sum().sum()
df1.isna().sum()
# Out:
# Unnamed: 0             0
# id                     0
# guid                   0
# published_on           0
# imageurl               0
# title                 10
# url                    0
# source                 0
# body                  27
# tags                8988
# categories             0
# upvotes                0
# downvotes              0
# lang                   0
# source_info.name     410
# source_info.lang     410
# source_info.img      410
# Coin_Symbol            0
# Rev_time               0
# Dt_Rev_time            0
# dtype: int64

# %%
# checking for mull values
df2.isnull().sum().sum()
df2.isna().sum()
# Out:
# Unnamed: 0            0
# id                    0
# guid                  0
# published_on          0
# imageurl              0
# title                 0
# url                   0
# source                0
# body                  9
# tags                178
# categories            0
# upvotes               0
# downvotes             0
# lang                  0
# source_info.name      0
# source_info.lang      0
# source_info.img       0
# Coin_Symbol           0
# Rev_time              0
# Dt_Rev_time           0
# dtype: int64

# %%
print(df2.dtypes)
# Out:
# Unnamed: 0           int64
# id                   int64
# guid                object
# published_on         int64
# imageurl            object
# title               object
# url                 object
# source              object
# body                object
# tags                object
# categories          object
# upvotes              int64
# downvotes            int64
# lang                object
# source_info.name    object
# source_info.lang    object
# source_info.img     object
# Coin_Symbol         object
# Rev_time            object
# Dt_Rev_time         object
# dtype: object

# %%
df1.drop(columns=['Unnamed: 0','id', 'guid', 'published_on', 'imageurl', 'url', 'source_info.lang','tags','source_info.img','upvotes','downvotes','lang','source_info.img'],axis=1, inplace=True)
df1
# Out:
#                                                     title             source  \
# 0                                  SuperNET Weekly No. 18  coremediasupernet
# 1                                  SuperNET Weekly No. 18  coremediasupernet
# 2                                  SuperNET Weekly No. 18  coremediasupernet
# 3                                  SuperNET Weekly No. 18  coremediasupernet
# 4                                  SuperNET Weekly No. 18  coremediasupernet
# ...                                                   ...                ...
# 164417  Ethereum Price Analysis: Ethereum (ETH) Price ...        cryptonewsz
# 164418  Crypto-Market Top Weekly Performers: Bitcoin, ...           coingape
# 164419  Microsoft Reveals New Ethereum-Based Project –...          dailyhodl
# 164420  Tezos Price Analysis: Tezos Price Trading Belo...        cryptonewsz
# 164421  From Ghana to the Bronx, Meet the Teen Bitcoin...           coindesk
#
#                                                      body  \
# 0       CORE and CORE Media were birthed out of the co...
# 1       CORE and CORE Media were birthed out of the co...
# 2       CORE and CORE Media were birthed out of the co...
# 3       CORE and CORE Media were birthed out of the co...
# 4       CORE and CORE Media were birthed out of the co...
# ...                                                   ...
# 164417  Intraday chart embarks downtrend in Ethereum p...
# 164418  Bitcoin [BTC] broke above $10,000 due to risin...
# 164419  The company plans to decentralize AI by allowi...
# 164420  Tim Coulter, Owner, and Founder of Truffle, wh...
# 164421  From experimenting with zcash in the Bronx to ...
#
#                              categories source_info.name Coin_Symbol  \
# 0       Blockchain|Technology|Sponsored              NaN         XLM
# 1       Blockchain|Technology|Sponsored              NaN         XLM
# 2       Blockchain|Technology|Sponsored              NaN        BUSD
# 3       Blockchain|Technology|Sponsored              NaN        BUSD
# 4       Blockchain|Technology|Sponsored              NaN        DOGE
# ...                                 ...              ...         ...
# 164417      ETH|Trading|Market|Business      CryptoNewsZ         ETH
# 164418              XMR|BCH|ETH|Trading         CoinGape         ETH
# 164419              LTC|XRP|ETH|Altcoin   The Daily Hodl         ETH
# 164420               Trading|Market|ETH      CryptoNewsZ         ETH
# 164421                      BTC|ZEC|ETH         CoinDesk         ETH
#
#                    Rev_time Dt_Rev_time
# 0       2016-07-11 00:00:00  2016-07-11
# 1       2016-07-11 00:00:00  2016-07-11
# 2       2016-07-11 00:00:00  2016-07-11
# 3       2016-07-11 00:00:00  2016-07-11
# 4       2016-07-11 00:00:00  2016-07-11
# ...                     ...         ...
# 164417  2019-08-04 13:30:10  2019-08-04
# 164418  2019-08-04 12:45:49  2019-08-04
# 164419  2019-08-04 11:00:33  2019-08-04
# 164420  2019-08-04 09:35:16  2019-08-04
# 164421  2019-08-04 09:00:00  2019-08-04
#
# [164422 rows x 8 columns]

# %%
df1 = df1[df1['body'].notna()]
df1
# Out:
#                                                     title             source  \
# 0                                  SuperNET Weekly No. 18  coremediasupernet
# 1                                  SuperNET Weekly No. 18  coremediasupernet
# 2                                  SuperNET Weekly No. 18  coremediasupernet
# 3                                  SuperNET Weekly No. 18  coremediasupernet
# 4                                  SuperNET Weekly No. 18  coremediasupernet
# ...                                                   ...                ...
# 164417  Ethereum Price Analysis: Ethereum (ETH) Price ...        cryptonewsz
# 164418  Crypto-Market Top Weekly Performers: Bitcoin, ...           coingape
# 164419  Microsoft Reveals New Ethereum-Based Project –...          dailyhodl
# 164420  Tezos Price Analysis: Tezos Price Trading Belo...        cryptonewsz
# 164421  From Ghana to the Bronx, Meet the Teen Bitcoin...           coindesk
#
#                                                      body  \
# 0       CORE and CORE Media were birthed out of the co...
# 1       CORE and CORE Media were birthed out of the co...
# 2       CORE and CORE Media were birthed out of the co...
# 3       CORE and CORE Media were birthed out of the co...
# 4       CORE and CORE Media were birthed out of the co...
# ...                                                   ...
# 164417  Intraday chart embarks downtrend in Ethereum p...
# 164418  Bitcoin [BTC] broke above $10,000 due to risin...
# 164419  The company plans to decentralize AI by allowi...
# 164420  Tim Coulter, Owner, and Founder of Truffle, wh...
# 164421  From experimenting with zcash in the Bronx to ...
#
#                              categories source_info.name Coin_Symbol  \
# 0       Blockchain|Technology|Sponsored              NaN         XLM
# 1       Blockchain|Technology|Sponsored              NaN         XLM
# 2       Blockchain|Technology|Sponsored              NaN        BUSD
# 3       Blockchain|Technology|Sponsored              NaN        BUSD
# 4       Blockchain|Technology|Sponsored              NaN        DOGE
# ...                                 ...              ...         ...
# 164417      ETH|Trading|Market|Business      CryptoNewsZ         ETH
# 164418              XMR|BCH|ETH|Trading         CoinGape         ETH
# 164419              LTC|XRP|ETH|Altcoin   The Daily Hodl         ETH
# 164420               Trading|Market|ETH      CryptoNewsZ         ETH
# 164421                      BTC|ZEC|ETH         CoinDesk         ETH
#
#                    Rev_time Dt_Rev_time
# 0       2016-07-11 00:00:00  2016-07-11
# 1       2016-07-11 00:00:00  2016-07-11
# 2       2016-07-11 00:00:00  2016-07-11
# 3       2016-07-11 00:00:00  2016-07-11
# 4       2016-07-11 00:00:00  2016-07-11
# ...                     ...         ...
# 164417  2019-08-04 13:30:10  2019-08-04
# 164418  2019-08-04 12:45:49  2019-08-04
# 164419  2019-08-04 11:00:33  2019-08-04
# 164420  2019-08-04 09:35:16  2019-08-04
# 164421  2019-08-04 09:00:00  2019-08-04
#
# [164395 rows x 8 columns]

# %%
df1['body'] = df1['body'].astype('str')
df1['title'] = df1['title'].astype('str')
print(df1.dtypes)
# Out:
# title               object
# source              object
# body                object
# categories          object
# source_info.name    object
# Coin_Symbol         object
# Rev_time            object
# Dt_Rev_time         object
# dtype: object
# <ipython-input-14-aa9b812e8717>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['body'] = df1['body'].astype('str')
# <ipython-input-14-aa9b812e8717>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['title'] = df1['title'].astype('str')

# %%
df2.drop(columns=['Unnamed: 0','id', 'guid', 'published_on', 'imageurl', 'url', 'source_info.lang','tags','source_info.img','upvotes','downvotes','lang','source_info.img'],axis=1, inplace=True)
df2 = df2[df2['body'].notna()]
df2['body'] = df2['body'].astype('str')
df2['title'] = df2['title'].astype('str')
df2
# Out:
# <ipython-input-15-b46147405290>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['body'] = df2['body'].astype('str')
# <ipython-input-15-b46147405290>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['title'] = df2['title'].astype('str')
#                                                    title         source  \
# 0      Why Is the US Not Yet a Leader in Crypto Regul...  cointelegraph
# 1      Bank of China explains Bitcoin position and pr...  cryptopolitan
# 2      BitMEXodus: Bitcoin Traders Abandon Exchange A...            ccn
# 3      Hilarious Collection of Crypto Twitter Predict...    cryptoglobe
# 4      Max Keiser Claims Bitcoin May Target $15,000 T...        newsbtc
# ...                                                  ...            ...
# 54986  Ripple’s Untapped Potential – XRP Ledger As A ...       zycrypto
# 54987  3 Million Traders Reveal Most Popular Crypto A...      dailyhodl
# 54988  XRP Rebounds from .886 Fib Retracement – Will ...       coingape
# 54989  Here’s How Ripple Will Power Remittances to th...     bitcoinist
# 54990   XRP Resumes its Rebound Today; May Reclaim $0.24    cryptonewsz
#
#                                                     body  \
# 0      Experts in crypto and blockchain take on the q...
# 1      What might have been thought to be happening i...
# 2      July wasn't exactly a banner month for crypto ...
# 3      Crypto users took to Twitter to give their pre...
# 4      Bitcoin and the aggregated crypto markets have...
# ...                                                  ...
# 54986  Since its inception back in 2012, Ripple has b...
# 54987  A year-long poll at a London-based crypto exch...
# 54988  XRP dropped by 13% over the past 7-days of tra...
# 54989  The Dubai-based RAKBANK and BDO Unibank (a ful...
# 54990  XRP aims to remain stable above $0.24 though b...
#
#                                       categories source_info.name Coin_Symbol  \
# 0                      Regulation|Blockchain|BTC    CoinTelegraph         BTC
# 1                       BTC|Fiat|Asia|Regulation    Cryptopolitan         BTC
# 2           BTC|Exchange|Market|Trading|Business              CCN         BTC
# 3          BTC|ETH|Blockchain|Technology|Altcoin      CryptoGlobe         BTC
# 4                             BTC|Market|Trading          NewsBTC         BTC
# ...                                          ...              ...         ...
# 54986  XRP|Exchange|Blockchain|Technology|Wallet         ZyCrypto         XRP
# 54987                BTC|ETH|XRP|Exchange|Market   The Daily Hodl         XRP
# 54988                         XRP|Market|Trading         CoinGape         XRP
# 54989                           XRP|Fiat|Altcoin       Bitcoinist         XRP
# 54990                                        XRP      CryptoNewsZ         XRP
#
#                   Rev_time Dt_Rev_time
# 0      2019-08-04 22:55:00  2019-08-04
# 1      2019-08-04 22:17:57  2019-08-04
# 2      2019-08-04 22:00:00  2019-08-04
# 3      2019-08-04 21:48:07  2019-08-04
# 4      2019-08-04 21:30:12  2019-08-04
# ...                    ...         ...
# 54986  2020-02-29 18:09:46  2020-02-29
# 54987  2020-02-29 15:15:03  2020-02-29
# 54988  2020-02-29 10:53:10  2020-02-29
# 54989  2020-02-29 09:45:32  2020-02-29
# 54990  2020-02-29 08:00:57  2020-02-29
#
# [54982 rows x 8 columns]

# %%
print(df2.dtypes)
# Out:
# title               object
# source              object
# body                object
# categories          object
# source_info.name    object
# Coin_Symbol         object
# Rev_time            object
# Dt_Rev_time         object
# dtype: object

# %%
df3.drop(columns=['Unnamed: 0','id', 'guid', 'published_on', 'imageurl', 'url', 'source_info.lang','tags','source_info.img','upvotes','downvotes','lang','source_info.img'],axis=1, inplace=True)
df3 = df3[df3['body'].notna()]
df3['body'] = df3['body'].astype('str')
df3['title'] = df3['title'].astype('str')
df3
# Out:
#                                                   title           source  \
# 0     Texas Becomes an Increasingly Popular Region f...        themerkle
# 1     Crypto Tidbits: Bitcoin Plunges Under $9,000, ...          newsbtc
# 2     Veteran Trader Who Predicted Bitcoin (BTC) Ris...        dailyhodl
# 3       The U.S. Says “No” to Any and All Petro Trading  livebitcoinnews
# 4     This Crypto Just Set All-Time Highs, and Analy...          newsbtc
# ...                                                 ...              ...
# 1136  Bitcoin's OI and volume put/call ratio close t...        ambcrypto
# 1137  Lightning in a bottle: liquidity on the Lightn...         theblock
# 1138  Amir Taaki on Bitcoin and Building Dissident T...  bitcoinmagazine
# 1139  Amir Taaki on Bitcoin and Building Dissident T...  bitcoinmagazine
# 1140  Crypto Taxes a ‘Nightmare' — Congress Hears th...    cointelegraph
#
#                                                    body  \
# 0     Setting up a reliable and profitable Bitcoin m...
# 1     Another week, another round of Crypto Tidbits....
# 2     A veteran technical trader who was immortalize...
# 3     The U.S. government is being very strict when ...
# 4     Chainlink’s price action throughout 2019 and 2...
# ...                                                 ...
# 1136  As Bitcoin struggled to recover from its radic...
# 1137  Quick TakeBecause Lightning is structured arou...
# 1138  Amir Taaki was one of Bitcoin’s first-ever ded...
# 1139  Amir Taaki was one of Bitcoin’s first-ever ded...
# 1140  One of the witnesses at a recent government bl...
#
#                           categories   source_info.name Coin_Symbol  \
# 0                         BTC|Mining             NullTx         BTC
# 1                BTC|Market|Exchange            NewsBTC         BTC
# 2        BTC|Business|Market|Trading     The Daily Hodl         BTC
# 3                        Trading|BTC  Live Bitcoin News         BTC
# 4                 Trading|BTC|Market            NewsBTC         BTC
# ...                              ...                ...         ...
# 1136                      BTC|Market         AMB Crypto        BUSD
# 1137                             BTC           TheBlock        BUSD
# 1138                  BTC|Technology   Bitcoin Magazine        BUSD
# 1139                  BTC|Technology   Bitcoin Magazine        BUSD
# 1140  Regulation|Blockchain|Business      CoinTelegraph        BUSD
#
#                  Rev_time Dt_Rev_time
# 0     2020-02-29 23:00:32  2020-02-29
# 1     2020-02-29 23:00:22  2020-02-29
# 2     2020-02-29 22:15:39  2020-02-29
# 3     2020-02-29 22:00:29  2020-02-29
# 4     2020-02-29 22:00:22  2020-02-29
# ...                   ...         ...
# 1136  2020-03-04 19:30:58  2020-03-04
# 1137  2020-03-04 19:29:18  2020-03-04
# 1138  2020-03-04 19:26:08  2020-03-04
# 1139  2020-03-04 19:26:08  2020-03-04
# 1140  2020-03-04 19:19:00  2020-03-04
#
# [1141 rows x 8 columns]

# %%
df4.drop(columns=['Unnamed: 0','id', 'guid', 'published_on', 'imageurl', 'url', 'source_info.lang','tags','source_info.img','upvotes','downvotes','lang','source_info.img'],axis=1, inplace=True)
df4 = df4[df4['body'].notna()]
df4['body'] = df4['body'].astype('str')
df4['title'] = df4['title'].astype('str')
df4
# Out:
#                                                   title           source  \
# 0     Crypto Will Thrive in 2020 as Governments Stru...          newsbtc
# 1     Cosmos price fails to recover from project in-...          decrypt
# 2     Chainlink, Algorand, Dogecoin rally as Bitcoin...        ambcrypto
# 3            Australia Receives “Test” Version of Libra  livebitcoinnews
# 4     Bitcoin CME Futures Volume is Collapsing Amids...          newsbtc
# ...                                                 ...              ...
# 9650  Consumer Electronics Giant HTC Bringing Crypto...        dailyhodl
# 9651  Gold Records Strongest Weekly Close Since Rece...          newsbtc
# 9652  Price Analysis April 10: BTC, ETH, XRP, BCH, B...    cointelegraph
# 9653  Ledger Expands Crypto Payment Options with Cry...    cointelegraph
# 9654  Bitcoin Cash 51% Attack Cost Is Crazy Cheap Ri...       bitcoinist
#
#                                                    body  \
# 0     Global efforts to stimulate markets look likel...
# 1     Problems at Cosmos are proving too much for it...
# 2     While Bitcoin regained its dominance of 63.7% ...
# 3     The Reserve Bank of Australia (RBA) says its r...
# 4     The global markets are currently caught within...
# ...                                                 ...
# 9650  Taiwanese consumer electronics giant HTC is br...
# 9651  The original ultra-scarce asset used for trade...
# 9652  Bitcoin needs to stay above $6,500 to maintain...
# 9653  Wallet producer Ledger allows its customers to...
# 9654  According to a site called Crypto 51, the cost...
#
#                          categories   source_info.name Coin_Symbol  \
# 0                BTC|Market|Trading            NewsBTC         BTC
# 1            Trading|BTC|Market|ICO            Decrypt         BTC
# 2        BTC|Market|Trading|Altcoin         AMB Crypto         BTC
# 3                          Fiat|BTC  Live Bitcoin News         BTC
# 4          BTC|Market|Fiat|Business            NewsBTC         BTC
# ...                             ...                ...         ...
# 9650  XMR|Mining|BTC|Wallet|Altcoin     The Daily Hodl        BUSD
# 9651                   Fiat|Trading            NewsBTC        BUSD
# 9652         BCH|ETH|LTC|XRP|Market      CoinTelegraph         LTC
# 9653     Wallet|BTC|LTC|XRP|Altcoin      CoinTelegraph         LTC
# 9654                    BCH|ETH|LTC         Bitcoinist         LTC
#
#                  Rev_time Dt_Rev_time
# 0     2020-03-03 23:00:02  2020-03-03
# 1     2020-03-03 22:45:36  2020-03-03
# 2     2020-03-03 22:30:30  2020-03-03
# 3     2020-03-03 22:00:36  2020-03-03
# 4     2020-03-03 22:00:22  2020-03-03
# ...                   ...         ...
# 9650  2020-04-10 17:38:28  2020-04-10
# 9651  2020-04-10 17:30:50  2020-04-10
# 9652  2020-04-10 19:18:00  2020-04-10
# 9653  2020-04-10 16:54:00  2020-04-10
# 9654  2020-04-10 11:20:20  2020-04-10
#
# [9655 rows x 8 columns]

# %%
df5.drop(columns=['Unnamed: 0','id', 'guid', 'published_on', 'imageurl', 'url', 'source_info.lang','tags','source_info.img','upvotes','downvotes','lang','source_info.img'],axis=1, inplace=True)
df5 = df5[df5['body'].notna()]
df5['body'] = df5['body'].astype('str')
df5['title'] = df5['title'].astype('str')
df5
# Out:
#                                                    title       source  \
# 0      Bitcoin Might not Turn Bullish until After the...    themerkle
# 1      Bitcoin likely to cross $8000 mark before its ...    ambcrypto
# 2      This Crypto Could Explode Over 100% If It Buil...      newsbtc
# 3      Bitcoin’s open interest skyrocketing indicates...  cryptoslate
# 4      Venezuelans have a new way to send crypto with...      decrypt
# ...                                                  ...          ...
# 20383  Are virtual events the new norm? The Story of ...  cryptonewsz
# 20384  Balancer pools drained of more than $450,000 d...     theblock
# 20385  Ethereum Facing Uphill Task Near $228: Here’s ...      newsbtc
# 20386  A Hacker Just Drained $500k in Ethereum & Altc...      newsbtc
# 20387  Here’s Why Ethereum Could Start Nosediving to ...      newsbtc
#
#                                                     body  \
# 0      There are still many questions regarding the f...
# 1      Fours day after finally breaching the $7000 ma...
# 2      It has been an incredibly volatile year for Ch...
# 3      Bitcoin has seen some notable overnight volati...
# 4      A Venezuelan crypto exchange has developed a s...
# ...                                                  ...
# 20383  Webit Virtual, the first fully transformed vir...
# 20384  Two multi-token pools on Balancer, an automate...
# 20385  Ethereum is currently recovering from the $216...
# 20386  Ethereum&#8217;s budding decentralized finance...
# 20387  Ethereum’s weakness as of late has primarily b...
#
#                              categories source_info.name Coin_Symbol  \
# 0                    BTC|Trading|Market           NullTx         BTC
# 1                    BTC|Market|Trading       AMB Crypto         BTC
# 2                           Trading|BTC          NewsBTC         BTC
# 3                    Trading|BTC|Market      CryptoSlate         BTC
# 4          BTC|DASH|Exchange|Technology          Decrypt         BTC
# ...                                 ...              ...         ...
# 20383                               ETH      CryptoNewsZ         ETH
# 20384  Mining|ICO|ETH|Market|Blockchain         TheBlock         ETH
# 20385           ETH|Trading|Market|Fiat          NewsBTC         ETH
# 20386                       ETH|Altcoin          NewsBTC         ETH
# 20387                   ETH|BTC|Trading          NewsBTC         ETH
#
#                   Rev_time Dt_Rev_time
# 0      2020-04-10 22:00:17  2020-04-10
# 1      2020-04-10 21:30:44  2020-04-10
# 2      2020-04-10 21:00:59  2020-04-10
# 3      2020-04-10 21:00:32  2020-04-10
# 4      2020-04-10 20:35:08  2020-04-10
# ...                    ...         ...
# 20383  2020-06-29 07:27:22  2020-06-29
# 20384  2020-06-29 07:21:45  2020-06-29
# 20385  2020-06-29 06:58:45  2020-06-29
# 20386  2020-06-29 02:00:52  2020-06-29
# 20387  2020-06-29 01:00:23  2020-06-29
#
# [20388 rows x 8 columns]

# %%
df6.drop(columns=['Unnamed: 0','id', 'guid', 'published_on', 'imageurl', 'url', 'source_info.lang','tags','source_info.img','upvotes','downvotes','lang','source_info.img'],axis=1, inplace=True)
df6 = df6[df6['body'].notna()]
df6['body'] = df6['body'].astype('str')
df6['title'] = df6['title'].astype('str')
df6
# Out:
# <ipython-input-20-79bff6f4c8a3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['body'] = df6['body'].astype('str')
# <ipython-input-20-79bff6f4c8a3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['title'] = df6['title'].astype('str')
#                                                    title           source  \
# 0      Digital Currency Guru of $568M Cyber Fraud For...         coindesk
# 1      XRP Architect David Schwartz Denies Being Bitc...        dailyhodl
# 2      How to use DeFi to earn passive income with yo...          decrypt
# 3      Researchers Say New Lightning Network Attack C...    cointelegraph
# 4      Bitcoin as a tool to fight authoritarian regim...    cointelegraph
# ...                                                  ...              ...
# 95831  Fintechs are hungry for DeFi yields, says Comp...         theblock
# 95832  Why this is crucial to XRP’s trajectory over t...        ambcrypto
# 95833  Ripple CTO slams regulators as Barclays blocks...      cryptoslate
# 95834  Crypto Head: The U.S. Is the “Most-Ready” Nati...  livebitcoinnews
# 95835  Crypto Exchange Employee Siphons Bitcoin, Admi...        dailyhodl
#
#                                                     body  \
# 0      Sergey Medvedev pleaded guilty to racketeering...
# 1      Ripple&#8217;s chief technology officer David ...
# 2      It’s risky—but it can be done: Andreas Antonop...
# 3      The Lightning Network is susceptible to attack...
# 4      Professor of Economics, Sergei Guriev, told Co...
# ...                                                  ...
# 95831  DeFi and traditional finance are converging, s...
# 95832  The global cryptocurrency market noted a bit o...
# 95833  Barclays UK customers have been blocked from t...
# 95834  According to a new report issued by cryptocurr...
# 95835  An ex-employee of the collapsed New Zealand-ba...
#
#                          categories   source_info.name Coin_Symbol  \
# 0                          BTC|Fiat           CoinDesk         BTC
# 1                BTC|XRP|Technology     The Daily Hodl         BTC
# 2                           BTC|ETH            Decrypt         BTC
# 3                    BTC|Blockchain      CoinTelegraph         BTC
# 4                    BTC|Blockchain      CoinTelegraph         BTC
# ...                             ...                ...         ...
# 95831                ETH|Blockchain           TheBlock        DOGE
# 95832    XRP|Market|Trading|Altcoin         AMB Crypto        DOGE
# 95833  Exchange|XRP|Regulation|Fiat        CryptoSlate        DOGE
# 95834                           BTC  Live Bitcoin News        DOGE
# 95835                  BTC|Exchange     The Daily Hodl        DOGE
#
#                   Rev_time Dt_Rev_time
# 0      2020-06-29 22:23:19  2020-06-29
# 1      2020-06-29 22:05:20  2020-06-29
# 2      2020-06-29 21:46:06  2020-06-29
# 3      2020-06-29 21:38:00  2020-06-29
# 4      2020-06-29 21:18:00  2020-06-29
# ...                    ...         ...
# 95831  2021-07-06 19:05:16  2021-07-06
# 95832  2021-07-06 19:00:37  2021-07-06
# 95833  2021-07-06 19:00:21  2021-07-06
# 95834  2021-07-06 19:00:11  2021-07-06
# 95835  2021-07-06 18:57:17  2021-07-06
#
# [93497 rows x 8 columns]

# %%
frames = [df1, df2, df3, df4, df5, df6]
Final_News_df = pd.concat(frames, axis=0)
Final_News_df
# Out:
#                                                    title             source  \
# 0                                 SuperNET Weekly No. 18  coremediasupernet
# 1                                 SuperNET Weekly No. 18  coremediasupernet
# 2                                 SuperNET Weekly No. 18  coremediasupernet
# 3                                 SuperNET Weekly No. 18  coremediasupernet
# 4                                 SuperNET Weekly No. 18  coremediasupernet
# ...                                                  ...                ...
# 95831  Fintechs are hungry for DeFi yields, says Comp...           theblock
# 95832  Why this is crucial to XRP’s trajectory over t...          ambcrypto
# 95833  Ripple CTO slams regulators as Barclays blocks...        cryptoslate
# 95834  Crypto Head: The U.S. Is the “Most-Ready” Nati...    livebitcoinnews
# 95835  Crypto Exchange Employee Siphons Bitcoin, Admi...          dailyhodl
#
#                                                     body  \
# 0      CORE and CORE Media were birthed out of the co...
# 1      CORE and CORE Media were birthed out of the co...
# 2      CORE and CORE Media were birthed out of the co...
# 3      CORE and CORE Media were birthed out of the co...
# 4      CORE and CORE Media were birthed out of the co...
# ...                                                  ...
# 95831  DeFi and traditional finance are converging, s...
# 95832  The global cryptocurrency market noted a bit o...
# 95833  Barclays UK customers have been blocked from t...
# 95834  According to a new report issued by cryptocurr...
# 95835  An ex-employee of the collapsed New Zealand-ba...
#
#                             categories   source_info.name Coin_Symbol  \
# 0      Blockchain|Technology|Sponsored                NaN         XLM
# 1      Blockchain|Technology|Sponsored                NaN         XLM
# 2      Blockchain|Technology|Sponsored                NaN        BUSD
# 3      Blockchain|Technology|Sponsored                NaN        BUSD
# 4      Blockchain|Technology|Sponsored                NaN        DOGE
# ...                                ...                ...         ...
# 95831                   ETH|Blockchain           TheBlock        DOGE
# 95832       XRP|Market|Trading|Altcoin         AMB Crypto        DOGE
# 95833     Exchange|XRP|Regulation|Fiat        CryptoSlate        DOGE
# 95834                              BTC  Live Bitcoin News        DOGE
# 95835                     BTC|Exchange     The Daily Hodl        DOGE
#
#                   Rev_time Dt_Rev_time
# 0      2016-07-11 00:00:00  2016-07-11
# 1      2016-07-11 00:00:00  2016-07-11
# 2      2016-07-11 00:00:00  2016-07-11
# 3      2016-07-11 00:00:00  2016-07-11
# 4      2016-07-11 00:00:00  2016-07-11
# ...                    ...         ...
# 95831  2021-07-06 19:05:16  2021-07-06
# 95832  2021-07-06 19:00:37  2021-07-06
# 95833  2021-07-06 19:00:21  2021-07-06
# 95834  2021-07-06 19:00:11  2021-07-06
# 95835  2021-07-06 18:57:17  2021-07-06
#
# [344058 rows x 8 columns]

# %%
# frames = [df1, df2, df3, df4, df5, df6]
# Final_News_df = pd.DataFrame()
# for df in frames:
#     Final_News_df.append(df, ignore_index=True)

# %%
Final_News_df.shape[0]
# Out:
# 344058

# %%
Total_len = (len(df1.index)+len(df2.index)+len(df3.index)+len(df4.index)+len(df5.index)+len(df6.index))
Total_len
# Out:
# 344058

# %%
print(df1.shape[0])
print(df2.shape[0])
print(df3.shape[0])
print(df4.shape[0])
print(df5.shape[0])
print(df6.shape[0])
# Out:
# 164395
# 54982
# 1141
# 9655
# 20388
# 93497

# %%
# # exporting the dataframe to csv
# Final_News_df.to_csv('Final_News_df(5year_2016_2021).csv')

# %%
#Create function to get the polarity
def getPolarity(body):
    return TextBlob(body).sentiment.polarity

#Create one new column called 'Polarity'
Final_News_df['Polarity'] = Final_News_df['body'].apply(getPolarity)

# show df with new column
Final_News_df
# Out:
#                                                    title             source  \
# 0                                 SuperNET Weekly No. 18  coremediasupernet
# 1                                 SuperNET Weekly No. 18  coremediasupernet
# 2                                 SuperNET Weekly No. 18  coremediasupernet
# 3                                 SuperNET Weekly No. 18  coremediasupernet
# 4                                 SuperNET Weekly No. 18  coremediasupernet
# ...                                                  ...                ...
# 95831  Fintechs are hungry for DeFi yields, says Comp...           theblock
# 95832  Why this is crucial to XRP’s trajectory over t...          ambcrypto
# 95833  Ripple CTO slams regulators as Barclays blocks...        cryptoslate
# 95834  Crypto Head: The U.S. Is the “Most-Ready” Nati...    livebitcoinnews
# 95835  Crypto Exchange Employee Siphons Bitcoin, Admi...          dailyhodl
#
#                                                     body  \
# 0      CORE and CORE Media were birthed out of the co...
# 1      CORE and CORE Media were birthed out of the co...
# 2      CORE and CORE Media were birthed out of the co...
# 3      CORE and CORE Media were birthed out of the co...
# 4      CORE and CORE Media were birthed out of the co...
# ...                                                  ...
# 95831  DeFi and traditional finance are converging, s...
# 95832  The global cryptocurrency market noted a bit o...
# 95833  Barclays UK customers have been blocked from t...
# 95834  According to a new report issued by cryptocurr...
# 95835  An ex-employee of the collapsed New Zealand-ba...
#
#                             categories   source_info.name Coin_Symbol  \
# 0      Blockchain|Technology|Sponsored                NaN         XLM
# 1      Blockchain|Technology|Sponsored                NaN         XLM
# 2      Blockchain|Technology|Sponsored                NaN        BUSD
# 3      Blockchain|Technology|Sponsored                NaN        BUSD
# 4      Blockchain|Technology|Sponsored                NaN        DOGE
# ...                                ...                ...         ...
# 95831                   ETH|Blockchain           TheBlock        DOGE
# 95832       XRP|Market|Trading|Altcoin         AMB Crypto        DOGE
# 95833     Exchange|XRP|Regulation|Fiat        CryptoSlate        DOGE
# 95834                              BTC  Live Bitcoin News        DOGE
# 95835                     BTC|Exchange     The Daily Hodl        DOGE
#
#                   Rev_time Dt_Rev_time  Polarity
# 0      2016-07-11 00:00:00  2016-07-11  0.331579
# 1      2016-07-11 00:00:00  2016-07-11  0.331579
# 2      2016-07-11 00:00:00  2016-07-11  0.331579
# 3      2016-07-11 00:00:00  2016-07-11  0.331579
# 4      2016-07-11 00:00:00  2016-07-11  0.331579
# ...                    ...         ...       ...
# 95831  2021-07-06 19:05:16  2021-07-06  0.125000
# 95832  2021-07-06 19:00:37  2021-07-06  0.130000
# 95833  2021-07-06 19:00:21  2021-07-06  0.250000
# 95834  2021-07-06 19:00:11  2021-07-06  0.127841
# 95835  2021-07-06 18:57:17  2021-07-06  0.077273
#
# [344058 rows x 9 columns]

# %%
# Create a function to compute negative, neutral and positive sentiments
def getSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
# Create a new column to store the sentiment
Final_News_df['Sentiment'] = Final_News_df['Polarity'].apply(getSentiment)

#show the df
Final_News_df
# Out:
#                                                    title             source  \
# 0                                 SuperNET Weekly No. 18  coremediasupernet
# 1                                 SuperNET Weekly No. 18  coremediasupernet
# 2                                 SuperNET Weekly No. 18  coremediasupernet
# 3                                 SuperNET Weekly No. 18  coremediasupernet
# 4                                 SuperNET Weekly No. 18  coremediasupernet
# ...                                                  ...                ...
# 95831  Fintechs are hungry for DeFi yields, says Comp...           theblock
# 95832  Why this is crucial to XRP’s trajectory over t...          ambcrypto
# 95833  Ripple CTO slams regulators as Barclays blocks...        cryptoslate
# 95834  Crypto Head: The U.S. Is the “Most-Ready” Nati...    livebitcoinnews
# 95835  Crypto Exchange Employee Siphons Bitcoin, Admi...          dailyhodl
#
#                                                     body  \
# 0      CORE and CORE Media were birthed out of the co...
# 1      CORE and CORE Media were birthed out of the co...
# 2      CORE and CORE Media were birthed out of the co...
# 3      CORE and CORE Media were birthed out of the co...
# 4      CORE and CORE Media were birthed out of the co...
# ...                                                  ...
# 95831  DeFi and traditional finance are converging, s...
# 95832  The global cryptocurrency market noted a bit o...
# 95833  Barclays UK customers have been blocked from t...
# 95834  According to a new report issued by cryptocurr...
# 95835  An ex-employee of the collapsed New Zealand-ba...
#
#                             categories   source_info.name Coin_Symbol  \
# 0      Blockchain|Technology|Sponsored                NaN         XLM
# 1      Blockchain|Technology|Sponsored                NaN         XLM
# 2      Blockchain|Technology|Sponsored                NaN        BUSD
# 3      Blockchain|Technology|Sponsored                NaN        BUSD
# 4      Blockchain|Technology|Sponsored                NaN        DOGE
# ...                                ...                ...         ...
# 95831                   ETH|Blockchain           TheBlock        DOGE
# 95832       XRP|Market|Trading|Altcoin         AMB Crypto        DOGE
# 95833     Exchange|XRP|Regulation|Fiat        CryptoSlate        DOGE
# 95834                              BTC  Live Bitcoin News        DOGE
# 95835                     BTC|Exchange     The Daily Hodl        DOGE
#
#                   Rev_time Dt_Rev_time  Polarity Sentiment
# 0      2016-07-11 00:00:00  2016-07-11  0.331579  Positive
# 1      2016-07-11 00:00:00  2016-07-11  0.331579  Positive
# 2      2016-07-11 00:00:00  2016-07-11  0.331579  Positive
# 3      2016-07-11 00:00:00  2016-07-11  0.331579  Positive
# 4      2016-07-11 00:00:00  2016-07-11  0.331579  Positive
# ...                    ...         ...       ...       ...
# 95831  2021-07-06 19:05:16  2021-07-06  0.125000  Positive
# 95832  2021-07-06 19:00:37  2021-07-06  0.130000  Positive
# 95833  2021-07-06 19:00:21  2021-07-06  0.250000  Positive
# 95834  2021-07-06 19:00:11  2021-07-06  0.127841  Positive
# 95835  2021-07-06 18:57:17  2021-07-06  0.077273  Positive
#
# [344058 rows x 10 columns]

# %%
# Plot and visualize sentiment count
plt.title('Sentiment Analysis - 10coins (Based on News (2016 to 2021))')
Final_News_df["Sentiment"].value_counts().plot(kind='bar')
plt.xlabel('Sentiments')
plt.ylabel('Counts- 2016 to 2021')
plt.savefig('Analysis/Sentiment Analysis(Based on News (2016 to 2021))')
plt.show()

# %%
# converting date to datetime format
Final_News_df['Dt_Rev_time'] = pd.to_datetime(Final_News_df['Dt_Rev_time'])

# %%
Final_News_df['Year'] = pd.to_datetime(Final_News_df['Dt_Rev_time']).dt.year
Final_News_df
# Out:
#                                                    title             source  \
# 0                                 SuperNET Weekly No. 18  coremediasupernet
# 1                                 SuperNET Weekly No. 18  coremediasupernet
# 2                                 SuperNET Weekly No. 18  coremediasupernet
# 3                                 SuperNET Weekly No. 18  coremediasupernet
# 4                                 SuperNET Weekly No. 18  coremediasupernet
# ...                                                  ...                ...
# 95831  Fintechs are hungry for DeFi yields, says Comp...           theblock
# 95832  Why this is crucial to XRP’s trajectory over t...          ambcrypto
# 95833  Ripple CTO slams regulators as Barclays blocks...        cryptoslate
# 95834  Crypto Head: The U.S. Is the “Most-Ready” Nati...    livebitcoinnews
# 95835  Crypto Exchange Employee Siphons Bitcoin, Admi...          dailyhodl
#
#                                                     body  \
# 0      CORE and CORE Media were birthed out of the co...
# 1      CORE and CORE Media were birthed out of the co...
# 2      CORE and CORE Media were birthed out of the co...
# 3      CORE and CORE Media were birthed out of the co...
# 4      CORE and CORE Media were birthed out of the co...
# ...                                                  ...
# 95831  DeFi and traditional finance are converging, s...
# 95832  The global cryptocurrency market noted a bit o...
# 95833  Barclays UK customers have been blocked from t...
# 95834  According to a new report issued by cryptocurr...
# 95835  An ex-employee of the collapsed New Zealand-ba...
#
#                             categories   source_info.name Coin_Symbol  \
# 0      Blockchain|Technology|Sponsored                NaN         XLM
# 1      Blockchain|Technology|Sponsored                NaN         XLM
# 2      Blockchain|Technology|Sponsored                NaN        BUSD
# 3      Blockchain|Technology|Sponsored                NaN        BUSD
# 4      Blockchain|Technology|Sponsored                NaN        DOGE
# ...                                ...                ...         ...
# 95831                   ETH|Blockchain           TheBlock        DOGE
# 95832       XRP|Market|Trading|Altcoin         AMB Crypto        DOGE
# 95833     Exchange|XRP|Regulation|Fiat        CryptoSlate        DOGE
# 95834                              BTC  Live Bitcoin News        DOGE
# 95835                     BTC|Exchange     The Daily Hodl        DOGE
#
#                   Rev_time Dt_Rev_time  Polarity Sentiment  Year
# 0      2016-07-11 00:00:00  2016-07-11  0.331579  Positive  2016
# 1      2016-07-11 00:00:00  2016-07-11  0.331579  Positive  2016
# 2      2016-07-11 00:00:00  2016-07-11  0.331579  Positive  2016
# 3      2016-07-11 00:00:00  2016-07-11  0.331579  Positive  2016
# 4      2016-07-11 00:00:00  2016-07-11  0.331579  Positive  2016
# ...                    ...         ...       ...       ...   ...
# 95831  2021-07-06 19:05:16  2021-07-06  0.125000  Positive  2021
# 95832  2021-07-06 19:00:37  2021-07-06  0.130000  Positive  2021
# 95833  2021-07-06 19:00:21  2021-07-06  0.250000  Positive  2021
# 95834  2021-07-06 19:00:11  2021-07-06  0.127841  Positive  2021
# 95835  2021-07-06 18:57:17  2021-07-06  0.077273  Positive  2021
#
# [344058 rows x 11 columns]

# %%
Yearly_df = Final_News_df[['Coin_Symbol', 'Year', 'Polarity']].groupby(['Year','Coin_Symbol']).mean()
Yearly_df
# Out:
#                   Polarity
# Year Coin_Symbol
# 2016 BUSD         0.258251
#      DOGE         0.258251
#      XLM          0.258251
# 2017 ADA          0.161495
#      BTC          0.112062
#      BUSD         0.125083
#      DOGE         0.125083
#      ETH          0.120241
#      LTC          0.129613
#      USDT         0.080577
#      XLM          0.125083
#      XMR          0.098919
#      XRP          0.127040
# 2018 ADA          0.110639
#      BTC          0.106269
#      BUSD         0.104588
#      DOGE         0.104588
#      ETH          0.111435
#      LTC          0.111863
#      USDT         0.117283
#      XLM          0.104588
#      XMR          0.103818
#      XRP          0.101482
# 2019 ADA          0.107554
#      BTC          0.103718
#      BUSD         0.098234
#      DOGE         0.098234
#      ETH          0.110919
#      LTC          0.111633
#      USDT         0.110746
#      XLM          0.098234
#      XMR          0.100957
#      XRP          0.106172
# 2020 ADA          0.113584
#      BTC          0.097280
#      BUSD         0.096351
#      DOGE         0.096276
#      ETH          0.107587
#      LTC          0.106728
#      USDT         0.107424
#      XLM          0.096344
#      XMR          0.085477
#      XRP          0.088514
# 2021 ADA          0.113016
#      BTC          0.099899
#      BUSD         0.100909
#      DOGE         0.100957
#      ETH          0.103946
#      LTC          0.101209
#      USDT         0.129439
#      XLM          0.100957
#      XMR          0.101647
#      XRP          0.081923

# %%
Yearly_df = Yearly_df.reset_index()
Yearly_df
# Out:
#     Year Coin_Symbol  Polarity
# 0   2016        BUSD  0.258251
# 1   2016        DOGE  0.258251
# 2   2016         XLM  0.258251
# 3   2017         ADA  0.161495
# 4   2017         BTC  0.112062
# 5   2017        BUSD  0.125083
# 6   2017        DOGE  0.125083
# 7   2017         ETH  0.120241
# 8   2017         LTC  0.129613
# 9   2017        USDT  0.080577
# 10  2017         XLM  0.125083
# 11  2017         XMR  0.098919
# 12  2017         XRP  0.127040
# 13  2018         ADA  0.110639
# 14  2018         BTC  0.106269
# 15  2018        BUSD  0.104588
# 16  2018        DOGE  0.104588
# 17  2018         ETH  0.111435
# 18  2018         LTC  0.111863
# 19  2018        USDT  0.117283
# 20  2018         XLM  0.104588
# 21  2018         XMR  0.103818
# 22  2018         XRP  0.101482
# 23  2019         ADA  0.107554
# 24  2019         BTC  0.103718
# 25  2019        BUSD  0.098234
# 26  2019        DOGE  0.098234
# 27  2019         ETH  0.110919
# 28  2019         LTC  0.111633
# 29  2019        USDT  0.110746
# 30  2019         XLM  0.098234
# 31  2019         XMR  0.100957
# 32  2019         XRP  0.106172
# 33  2020         ADA  0.113584
# 34  2020         BTC  0.097280
# 35  2020        BUSD  0.096351
# 36  2020        DOGE  0.096276
# 37  2020         ETH  0.107587
# 38  2020         LTC  0.106728
# 39  2020        USDT  0.107424
# 40  2020         XLM  0.096344
# 41  2020         XMR  0.085477
# 42  2020         XRP  0.088514
# 43  2021         ADA  0.113016
# 44  2021         BTC  0.099899
# 45  2021        BUSD  0.100909
# 46  2021        DOGE  0.100957
# 47  2021         ETH  0.103946
# 48  2021         LTC  0.101209
# 49  2021        USDT  0.129439
# 50  2021         XLM  0.100957
# 51  2021         XMR  0.101647
# 52  2021         XRP  0.081923

# %%
Yearly_df = Yearly_df.set_index(['Year','Coin_Symbol'],drop=True).unstack('Coin_Symbol')
Yearly_df
# Out:
#              Polarity                                                    \
# Coin_Symbol       ADA       BTC      BUSD      DOGE       ETH       LTC
# Year
# 2016              NaN       NaN  0.258251  0.258251       NaN       NaN
# 2017         0.161495  0.112062  0.125083  0.125083  0.120241  0.129613
# 2018         0.110639  0.106269  0.104588  0.104588  0.111435  0.111863
# 2019         0.107554  0.103718  0.098234  0.098234  0.110919  0.111633
# 2020         0.113584  0.097280  0.096351  0.096276  0.107587  0.106728
# 2021         0.113016  0.099899  0.100909  0.100957  0.103946  0.101209
#
#
# Coin_Symbol      USDT       XLM       XMR       XRP
# Year
# 2016              NaN  0.258251       NaN       NaN
# 2017         0.080577  0.125083  0.098919  0.127040
# 2018         0.117283  0.104588  0.103818  0.101482
# 2019         0.110746  0.098234  0.100957  0.106172
# 2020         0.107424  0.096344  0.085477  0.088514
# 2021         0.129439  0.100957  0.101647  0.081923

# %%
flattened = pd.DataFrame(Yearly_df.to_records())
flattened
# Out:
#    Year  ('Polarity', 'ADA')  ('Polarity', 'BTC')  ('Polarity', 'BUSD')  \
# 0  2016                  NaN                  NaN              0.258251
# 1  2017             0.161495             0.112062              0.125083
# 2  2018             0.110639             0.106269              0.104588
# 3  2019             0.107554             0.103718              0.098234
# 4  2020             0.113584             0.097280              0.096351
# 5  2021             0.113016             0.099899              0.100909
#
#    ('Polarity', 'DOGE')  ('Polarity', 'ETH')  ('Polarity', 'LTC')  \
# 0              0.258251                  NaN                  NaN
# 1              0.125083             0.120241             0.129613
# 2              0.104588             0.111435             0.111863
# 3              0.098234             0.110919             0.111633
# 4              0.096276             0.107587             0.106728
# 5              0.100957             0.103946             0.101209
#
#    ('Polarity', 'USDT')  ('Polarity', 'XLM')  ('Polarity', 'XMR')  \
# 0                   NaN             0.258251                  NaN
# 1              0.080577             0.125083             0.098919
# 2              0.117283             0.104588             0.103818
# 3              0.110746             0.098234             0.100957
# 4              0.107424             0.096344             0.085477
# 5              0.129439             0.100957             0.101647
#
#    ('Polarity', 'XRP')
# 0                  NaN
# 1             0.127040
# 2             0.101482
# 3             0.106172
# 4             0.088514
# 5             0.081923

# %%
flattened.columns = [hdr.replace("('Polarity', ", " ").replace(")", "") \
                     for hdr in flattened.columns]
flattened.columns = [hdr.replace("('', ", " ").replace(")", "") \
                     for hdr in flattened.columns]

# %%
flattened.columns = [hdr.replace("'", "") \
                     for hdr in flattened.columns]

# %%
New_yearly = flattened.iloc[1:6]
New_yearly
# Out:
#    Year       ADA       BTC      BUSD      DOGE       ETH       LTC      USDT  \
# 1  2017  0.161495  0.112062  0.125083  0.125083  0.120241  0.129613  0.080577
# 2  2018  0.110639  0.106269  0.104588  0.104588  0.111435  0.111863  0.117283
# 3  2019  0.107554  0.103718  0.098234  0.098234  0.110919  0.111633  0.110746
# 4  2020  0.113584  0.097280  0.096351  0.096276  0.107587  0.106728  0.107424
# 5  2021  0.113016  0.099899  0.100909  0.100957  0.103946  0.101209  0.129439
#
#         XLM       XMR       XRP
# 1  0.125083  0.098919  0.127040
# 2  0.104588  0.103818  0.101482
# 3  0.098234  0.100957  0.106172
# 4  0.096344  0.085477  0.088514
# 5  0.100957  0.101647  0.081923

# %%
New_yearly = New_yearly.set_index('Year')
New_yearly
# Out:
#            ADA       BTC      BUSD      DOGE       ETH       LTC      USDT  \
# Year
# 2017  0.161495  0.112062  0.125083  0.125083  0.120241  0.129613  0.080577
# 2018  0.110639  0.106269  0.104588  0.104588  0.111435  0.111863  0.117283
# 2019  0.107554  0.103718  0.098234  0.098234  0.110919  0.111633  0.110746
# 2020  0.113584  0.097280  0.096351  0.096276  0.107587  0.106728  0.107424
# 2021  0.113016  0.099899  0.100909  0.100957  0.103946  0.101209  0.129439
#
#            XLM       XMR       XRP
# Year
# 2017  0.125083  0.098919  0.127040
# 2018  0.104588  0.103818  0.101482
# 2019  0.098234  0.100957  0.106172
# 2020  0.096344  0.085477  0.088514
# 2021  0.100957  0.101647  0.081923

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 
# Import the style from Matplotlib.
from matplotlib import style
import matplotlib.pyplot as plt

# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

import numpy as np
ax = New_yearly.plot(xticks=New_yearly.index, figsize=(12,4))

# Set the x and y label
ylab = ax.set_ylabel('Sentiment Score')
ax.set_xlabel('Year')
ax.legend(bbox_to_anchor=(1.0, 1.05))
# Create a title. 
ax.set_title("Yearly Sentiment Score")

# Save Figure
# plt.savefig("Analysis/Yearly Sentiment Score(2017-2021.png")

plt.show()

# %% [markdown]
# # Grouping by Dates for ML

# %%
Final_News_daily_df = Final_News_df[['Coin_Symbol', 'Dt_Rev_time', 'Polarity']].groupby(['Dt_Rev_time','Coin_Symbol']).mean()
Final_News_daily_df
# Out:
#                          Polarity
# Dt_Rev_time Coin_Symbol
# 2016-07-11  BUSD         0.331579
#             DOGE         0.331579
#             XLM          0.331579
# 2016-07-23  BUSD         0.285714
#             DOGE         0.285714
# ...                           ...
# 2021-07-06  ETH          0.064185
#             LTC          0.136327
#             USDT         0.081108
#             XLM          0.095572
#             XRP          0.184418
#
# [12904 rows x 1 columns]

# %%
Daily_coinwise_senti_df = pd.DataFrame(Final_News_daily_df.to_records())
Daily_coinwise_senti_df
# Out:
#       Dt_Rev_time Coin_Symbol  Polarity
# 0      2016-07-11        BUSD  0.331579
# 1      2016-07-11        DOGE  0.331579
# 2      2016-07-11         XLM  0.331579
# 3      2016-07-23        BUSD  0.285714
# 4      2016-07-23        DOGE  0.285714
# ...           ...         ...       ...
# 12899  2021-07-06         ETH  0.064185
# 12900  2021-07-06         LTC  0.136327
# 12901  2021-07-06        USDT  0.081108
# 12902  2021-07-06         XLM  0.095572
# 12903  2021-07-06         XRP  0.184418
#
# [12904 rows x 3 columns]

# %%
#expoting csv
Daily_coinwise_senti_df.to_csv('Daily_Coinwise_Senti_score(2016to2021).csv')
