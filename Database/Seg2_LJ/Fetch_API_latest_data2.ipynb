# %% [markdown]
# # Fetching Data from Coin Market Cap webpage for latest data updated every 30 seconds (https://pro.coinmarketcap.com/account/)
#
# market_cap: CoinMarketCap's market cap rank as outlined in our methodology.
# market_cap_strict: A strict market cap sort (latest trade price x circulating supply).
# name: The cryptocurrency name.
# symbol: The cryptocurrency symbol.
# date_added: Date cryptocurrency was added to the system.
# price: latest average trade price across markets.
# circulating_supply: approximate number of coins currently in circulation.
# total_supply: approximate total amount of coins in existence right now (minus any coins that have been verifiably burned).
# max_supply: our best approximation of the maximum amount of coins that will ever exist in the lifetime of the currency.
# num_market_pairs: number of market pairs across all exchanges trading each currency.
# market_cap_by_total_supply_strict: market cap by total supply.
# volume_24h: rolling 24 hour adjusted trading volume.
# volume_7d: rolling 24 hour adjusted trading volume.
# volume_30d: rolling 24 hour adjusted trading volume.
# percent_change_1h: 1 hour trading price percentage change for each currency.
# percent_change_24h: 24 hour trading price percentage change for each currency.
# percent_change_7d: 7 day trading price percentage change for each currency.

# %%
# import libraries
import requests
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
from coinmarket_config import API_Key

# %%
api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += API_Key
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=6197187e-68ff-4f11-88b7-0535e66df2e7'

# %%
requests.get(api_endpoint).json()
# Out:
# {'status': {'timestamp': '2022-01-14T00:28:11.300Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 26,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 9055},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 9035,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 18928468,
#    'total_supply': 18928468,
#    'platform': None,
#    'cmc_rank': 1,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 42626.79624953153,
#      'volume_24h': 47438485012.929756,
#      'volume_change_24h': 30.5631,
#      'percent_change_1h': -0.14520685,
#      'percent_change_24h': -2.87714894,
#      'percent_change_7d': -0.75550566,
#      'percent_change_30d': -12.29577946,
#      'percent_change_60d': -35.42143291,
#      'percent_change_90d': -30.78929348,
#      'market_cap': 806859948751.7776,
#      'market_cap_dominance': 39.791,
#      'fully_diluted_market_cap': 895162721240.16,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 5408,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 119149215.0615,
#    'total_supply': 119149215.0615,
#    'platform': None,
#    'cmc_rank': 2,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 3248.279973225764,
#      'volume_24h': 15344356934.90106,
#      'volume_change_24h': -7.8008,
#      'percent_change_1h': -0.34621863,
#      'percent_change_24h': -3.73433427,
#      'percent_change_7d': -4.52623157,
#      'percent_change_30d': -16.52782971,
#      'percent_change_60d': -30.46993757,
#      'percent_change_90d': -15.82272023,
#      'market_cap': 387030009109.84,
#      'market_cap_dominance': 19.0867,
#      'fully_diluted_market_cap': 387030009109.84,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1839,
#    'name': 'BNB',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'num_market_pairs': 620,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'binance-smart-chain',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'moonriver-ecosystem'],
#    'max_supply': 166801148,
#    'circulating_supply': 166801148,
#    'total_supply': 166801148,
#    'platform': None,
#    'cmc_rank': 3,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 476.37190328721164,
#      'volume_24h': 4158155454.9011,
#      'volume_change_24h': 0.2961,
#      'percent_change_1h': -0.17177635,
#      'percent_change_24h': -2.24996642,
#      'percent_change_7d': 1.16071968,
#      'percent_change_30d': -10.36076125,
#      'percent_change_60d': -27.34234774,
#      'percent_change_90d': 0.05591968,
#      'market_cap': 79459380343.25188,
#      'market_cap_dominance': 3.9185,
#      'fully_diluted_market_cap': 79459380343.25,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 25905,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['payments',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 78394369307.4411,
#    'total_supply': 82008978873.83017,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'cmc_rank': 4,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.0003414199151444,
#      'volume_24h': 63519454907.42146,
#      'volume_change_24h': 1.8562,
#      'percent_change_1h': -0.00400463,
#      'percent_change_24h': 0.00648299,
#      'percent_change_7d': 0.02503164,
#      'percent_change_30d': -0.03937018,
#      'percent_change_60d': 0.01166612,
#      'percent_change_90d': 0.12022868,
#      'market_cap': 78421134706.35785,
#      'market_cap_dominance': 3.8673,
#      'fully_diluted_market_cap': 82036978372.44,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 230,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'k300-ventures-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 313379591.06839514,
#    'total_supply': 511616946.142289,
#    'platform': None,
#    'cmc_rank': 5,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 146.92870891275413,
#      'volume_24h': 2195552644.256326,
#      'volume_change_24h': -2.2777,
#      'percent_change_1h': -0.11359136,
#      'percent_change_24h': -3.28385825,
#      'percent_change_7d': -1.70750349,
#      'percent_change_30d': -9.56942879,
#      'percent_change_60d': -39.02934469,
#      'percent_change_90d': -8.58367003,
#      'market_cap': 46044458715.286156,
#      'market_cap_dominance': 2.2707,
#      'fully_diluted_market_cap': 75171217354.57,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3408,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 2712,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain',
#     'fantom-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 44990134364.3109,
#    'total_supply': 44990134364.3109,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'cmc_rank': 6,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.9993521643143158,
#      'volume_24h': 3524932103.9169087,
#      'volume_change_24h': 2.3463,
#      'percent_change_1h': 0.00101539,
#      'percent_change_24h': -0.08442648,
#      'percent_change_7d': -0.02537614,
#      'percent_change_30d': -0.06747519,
#      'percent_change_60d': 0.03354794,
#      'percent_change_90d': 0.00273095,
#      'market_cap': 44960988149.76597,
#      'market_cap_dominance': 2.2172,
#      'fully_diluted_market_cap': 44960988149.77,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 354,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['mineable',
#     'dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'binance-smart-chain',
#     'cardano-ecosystem'],
#    'max_supply': 45000000000,
#    'circulating_supply': 33513219990.714,
#    'total_supply': 33968614580.749,
#    'platform': None,
#    'cmc_rank': 7,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.2371048886462936,
#      'volume_24h': 1988036726.179527,
#      'volume_change_24h': 18.3465,
#      'percent_change_1h': -0.29442449,
#      'percent_change_24h': -6.24124148,
#      'percent_change_7d': -2.92862416,
#      'percent_change_30d': -2.53173745,
#      'percent_change_60d': -39.98514192,
#      'percent_change_90d': -44.52880638,
#      'market_cap': 41459368284.790985,
#      'market_cap_dominance': 2.0446,
#      'fully_diluted_market_cap': 55669719989.08,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 673,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'binance-chain',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 100000000000,
#    'circulating_supply': 47615126275,
#    'total_supply': 99989829709,
#    'platform': None,
#    'cmc_rank': 8,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.7697948322777478,
#      'volume_24h': 1582038995.5631213,
#      'volume_change_24h': -19.098,
#      'percent_change_1h': -0.05414415,
#      'percent_change_24h': -3.57506776,
#      'percent_change_7d': -0.87332321,
#      'percent_change_30d': -5.07917226,
#      'percent_change_60d': -35.75605659,
#      'percent_change_90d': -32.66197679,
#      'market_cap': 36653878144.747406,
#      'market_cap_dominance': 1.8076,
#      'fully_diluted_market_cap': 76979483227.77,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4172,
#    'name': 'Terra',
#    'symbol': 'LUNA',
#    'slug': 'terra-luna',
#    'num_market_pairs': 128,
#    'date_added': '2019-07-26T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'store-of-value',
#     'defi',
#     'payments',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'pantera-capital-portfolio',
#     'terra-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 356591830.0904593,
#    'total_supply': 828014972.214518,
#    'platform': None,
#    'cmc_rank': 9,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 78.74770886630616,
#      'volume_24h': 2467842133.3792186,
#      'volume_change_24h': -3.1039,
#      'percent_change_1h': 0.24938852,
#      'percent_change_24h': -3.54915295,
#      'percent_change_7d': 0.98726737,
#      'percent_change_30d': 29.95173627,
#      'percent_change_60d': 53.04673975,
#      'percent_change_90d': 112.71839899,
#      'market_cap': 28080789620.0668,
#      'market_cap_dominance': 1.3848,
#      'fully_diluted_market_cap': 65204281968.89,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 294,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'binance-chain',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group'],
#    'max_supply': None,
#    'circulating_supply': 987579314.957085,
#    'total_supply': 1103303471.382273,
#    'platform': None,
#    'cmc_rank': 10,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 25.867541858775024,
#      'volume_24h': 1401115132.6774719,
#      'volume_change_24h': -1.3844,
#      'percent_change_1h': -0.60643081,
#      'percent_change_24h': -6.04318854,
#      'percent_change_7d': -2.55300601,
#      'percent_change_30d': -1.62469404,
#      'percent_change_60d': -45.03381851,
#      'percent_change_90d': -41.13685197,
#      'market_cap': 25546249268.51276,
#      'market_cap_dominance': 1.2598,
#      'fully_diluted_market_cap': 28539748728.91,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 442,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'binance-smart-chain',
#     'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 132670764299.89409,
#    'total_supply': 132670764299.89409,
#    'platform': None,
#    'cmc_rank': 11,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.17527139928031182,
#      'volume_24h': 2396862639.757897,
#      'volume_change_24h': 168.9414,
#      'percent_change_1h': 0.9287015,
#      'percent_change_24h': 8.42465797,
#      'percent_change_7d': 10.10445991,
#      'percent_change_30d': -6.27363493,
#      'percent_change_60d': -33.68618142,
#      'percent_change_90d': -27.85069644,
#      'market_cap': 23253390502.430878,
#      'market_cap_dominance': 1.1467,
#      'fully_diluted_market_cap': 23253390502.43,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 156,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'smart-contracts',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 244354897.0677541,
#    'total_supply': 395891289.9134107,
#    'platform': None,
#    'cmc_rank': 12,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 89.72376718394646,
#      'volume_24h': 759176851.0687491,
#      'volume_change_24h': -21.0083,
#      'percent_change_1h': -0.41359083,
#      'percent_change_24h': -6.40060453,
#      'percent_change_7d': -5.44252368,
#      'percent_change_30d': 1.26365667,
#      'percent_change_60d': -6.6040213,
#      'percent_change_90d': 59.02330823,
#      'market_cap': 21924441894.76437,
#      'market_cap_dominance': 1.0812,
#      'fully_diluted_market_cap': 35520857926.34,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'num_market_pairs': 310,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'state-channel',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 7312892503.27,
#    'total_supply': 10000000000,
#    'platform': None,
#    'cmc_rank': 13,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.2646686461466525,
#      'volume_24h': 1511108875.1445932,
#      'volume_change_24h': -20.9508,
#      'percent_change_1h': -1.01234359,
#      'percent_change_24h': -6.57935758,
#      'percent_change_7d': 1.76579479,
#      'percent_change_30d': 14.68545852,
#      'percent_change_60d': 30.44124454,
#      'percent_change_90d': 47.60952954,
#      'market_cap': 16561278364.796476,
#      'market_cap_dominance': 0.8167,
#      'fully_diluted_market_cap': 22646686461.47,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 5994,
#    'name': 'Shiba Inu',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 294,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes', 'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 549063278876301.94,
#    'total_supply': 589735030408322.8,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'cmc_rank': 14,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.9654450730502256e-05,
#      'volume_24h': 1430558309.1456907,
#      'volume_change_24h': -8.9226,
#      'percent_change_1h': -0.75662944,
#      'percent_change_24h': -7.12088834,
#      'percent_change_7d': -3.67135383,
#      'percent_change_30d': -13.04367387,
#      'percent_change_60d': -43.80208329,
#      'percent_change_90d': 15.22331155,
#      'market_cap': 16282169951.365316,
#      'market_cap_dominance': 0.8029,
#      'fully_diluted_market_cap': 17488268403.29,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4687,
#    'name': 'Binance USD',
#    'symbol': 'BUSD',
#    'slug': 'binance-usd',
#    'num_market_pairs': 2690,
#    'date_added': '2019-09-20T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'binance-chain',
#     'binance-smart-chain',
#     'harmony-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 14248528863.969255,
#    'total_supply': 14248528863.969255,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'BUSD-BD1'},
#    'cmc_rank': 15,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.000240340199687,
#      'volume_24h': 4206980283.9682164,
#      'volume_change_24h': -1.5029,
#      'percent_change_1h': -0.04205364,
#      'percent_change_24h': -0.03365262,
#      'percent_change_7d': 0.05804525,
#      'percent_change_30d': 0.023187,
#      'percent_change_60d': 0.00186139,
#      'percent_change_90d': 0.09115075,
#      'market_cap': 14251953358.241669,
#      'market_cap_dominance': 0.7028,
#      'fully_diluted_market_cap': 14251953358.24,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6535,
#    'name': 'NEAR Protocol',
#    'symbol': 'NEAR',
#    'slug': 'near-protocol',
#    'num_market_pairs': 87,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['platform',
#     'staking',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'k300-ventures-portfolio'],
#    'max_supply': 1000000000,
#    'circulating_supply': 608389619,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 16,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 20.176374909686,
#      'volume_24h': 1744082123.2758503,
#      'volume_change_24h': 47.0942,
#      'percent_change_1h': 3.3841326,
#      'percent_change_24h': 16.36324071,
#      'percent_change_7d': 27.67895509,
#      'percent_change_30d': 115.40665254,
#      'percent_change_60d': 71.89305271,
#      'percent_change_90d': 154.42485409,
#      'market_cap': 12275097044.105024,
#      'market_cap_dominance': 0.6053,
#      'fully_diluted_market_cap': 20176374909.69,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 568,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 467009550.4397637,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'cmc_rank': 17,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 25.067837953645714,
#      'volume_24h': 1556184963.534812,
#      'volume_change_24h': -21.144,
#      'percent_change_1h': 0.07347712,
#      'percent_change_24h': -5.27295472,
#      'percent_change_7d': 1.24230407,
#      'percent_change_30d': 35.21823883,
#      'percent_change_60d': -27.03512867,
#      'percent_change_90d': -8.34210891,
#      'market_cap': 11706919733.228931,
#      'market_cap_dominance': 0.5773,
#      'fully_diluted_market_cap': 25067837953.65,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3635,
#    'name': 'Crypto.com Coin',
#    'symbol': 'CRO',
#    'slug': 'crypto-com-coin',
#    'num_market_pairs': 123,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments'],
#    'max_supply': 30263013692,
#    'circulating_supply': 25263013692,
#    'total_supply': 30263013692,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'cmc_rank': 18,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.4564769912754534,
#      'volume_24h': 151174465.9211202,
#      'volume_change_24h': -15.2413,
#      'percent_change_1h': -0.4344321,
#      'percent_change_24h': -6.18902706,
#      'percent_change_7d': -8.60155648,
#      'percent_change_30d': -16.66177514,
#      'percent_change_60d': 0.45305521,
#      'percent_change_90d': 139.5112659,
#      'market_cap': 11531984480.674744,
#      'market_cap_dominance': 0.5687,
#      'fully_diluted_market_cap': 13814369437.05,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3717,
#    'name': 'Wrapped Bitcoin',
#    'symbol': 'WBTC',
#    'slug': 'wrapped-bitcoin',
#    'num_market_pairs': 314,
#    'date_added': '2019-01-30T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'defi',
#     'wrapped-tokens',
#     'fantom-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 266880.73402772,
#    'total_supply': 266880.73402772,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#    'cmc_rank': 19,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 42652.47937423112,
#      'volume_24h': 190388057.94342092,
#      'volume_change_24h': -5.0516,
#      'percent_change_1h': -0.1343726,
#      'percent_change_24h': -2.75664734,
#      'percent_change_7d': -0.70227153,
#      'percent_change_30d': -11.12724491,
#      'percent_change_60d': -34.46022929,
#      'percent_change_90d': -30.67345012,
#      'market_cap': 11383125003.49699,
#      'market_cap_dominance': 0.5614,
#      'fully_diluted_market_cap': 11383125003.5,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 7129,
#    'name': 'TerraUSD',
#    'symbol': 'UST',
#    'slug': 'terrausd',
#    'num_market_pairs': 246,
#    'date_added': '2020-09-21T00:00:00.000Z',
#    'tags': ['stablecoin', 'binance-smart-chain', 'terra-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 10592707055.583405,
#    'total_supply': 10592707055.583405,
#    'platform': None,
#    'cmc_rank': 20,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.0010663970177425,
#      'volume_24h': 219239584.5546335,
#      'volume_change_24h': -1.5318,
#      'percent_change_1h': 0.21736712,
#      'percent_change_24h': 0.34587711,
#      'percent_change_7d': 0.20565136,
#      'percent_change_30d': -0.02088591,
#      'percent_change_60d': -0.59066041,
#      'percent_change_90d': -0.00921431,
#      'market_cap': 10604003086.797298,
#      'market_cap_dominance': 0.5229,
#      'fully_diluted_market_cap': 10604003086.8,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 326,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 627292763.9836428,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'cmc_rank': 21,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 15.499867875419488,
#      'volume_24h': 236773012.54270607,
#      'volume_change_24h': 8.7191,
#      'percent_change_1h': -0.31232355,
#      'percent_change_24h': -4.56890854,
#      'percent_change_7d': -8.62395738,
#      'percent_change_30d': 2.90753334,
#      'percent_change_60d': -37.52380518,
#      'percent_change_90d': -40.4269377,
#      'market_cap': 9722954960.953165,
#      'market_cap_dominance': 0.4795,
#      'fully_diluted_market_cap': 15499867875.42,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 724,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': 84000000,
#    'circulating_supply': 69407894.4948378,
#    'total_supply': 84000000,
#    'platform': None,
#    'cmc_rank': 22,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 137.10229187663754,
#      'volume_24h': 892800738.0694944,
#      'volume_change_24h': 1.2144,
#      'percent_change_1h': 0.00598389,
#      'percent_change_24h': -2.92080819,
#      'percent_change_7d': 0.74515289,
#      'percent_change_30d': -9.42521307,
#      'percent_change_60d': -50.32960174,
#      'percent_change_90d': -28.04193346,
#      'market_cap': 9515981409.574116,
#      'market_cap_dominance': 0.4693,
#      'fully_diluted_market_cap': 11516592517.64,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 700,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi',
#     'stablecoin',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'avalanche-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 9475025853.622076,
#    'total_supply': 9475025853.622076,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'cmc_rank': 23,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.9990888045409372,
#      'volume_24h': 461322483.1333583,
#      'volume_change_24h': 17.2858,
#      'percent_change_1h': -0.05449006,
#      'percent_change_24h': -0.16129342,
#      'percent_change_7d': -0.00959075,
#      'percent_change_30d': -0.3009631,
#      'percent_change_60d': -0.30417158,
#      'percent_change_90d': -0.07916133,
#      'market_cap': 9466392253.089752,
#      'market_cap_dominance': 0.4668,
#      'fully_diluted_market_cap': 9466392253.09,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4030,
#    'name': 'Algorand',
#    'symbol': 'ALGO',
#    'slug': 'algorand',
#    'num_market_pairs': 172,
#    'date_added': '2019-06-20T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'arrington-xrp-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 10000000000,
#    'circulating_supply': 6464479852.867192,
#    'total_supply': 6908302131.039248,
#    'platform': None,
#    'cmc_rank': 24,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.3615032872514103,
#      'volume_24h': 557578525.2308326,
#      'volume_change_24h': 24.7772,
#      'percent_change_1h': -0.1461109,
#      'percent_change_24h': -8.45725173,
#      'percent_change_7d': -11.64065286,
#      'percent_change_30d': -1.57383217,
#      'percent_change_60d': -31.91782835,
#      'percent_change_90d': -22.72272762,
#      'market_cap': 8801410570.049196,
#      'market_cap_dominance': 0.434,
#      'fully_diluted_market_cap': 13615032872.51,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 221,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 226226027.647699,
#    'total_supply': 284010630.647699,
#    'platform': None,
#    'cmc_rank': 25,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 37.41934119527285,
#      'volume_24h': 1768594256.8875446,
#      'volume_change_24h': -19.2611,
#      'percent_change_1h': -2.66724368,
#      'percent_change_24h': -7.86337603,
#      'percent_change_7d': -6.04810524,
#      'percent_change_30d': 69.76560532,
#      'percent_change_60d': 14.3550647,
#      'percent_change_90d': 12.00470625,
#      'market_cap': 8465228915.800478,
#      'market_cap_dominance': 0.4175,
#      'fully_diluted_market_cap': 10627490691.29,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3513,
#    'name': 'Fantom',
#    'symbol': 'FTM',
#    'slug': 'fantom',
#    'num_market_pairs': 207,
#    'date_added': '2018-10-29T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'defi',
#     'research',
#     'scaling',
#     'smart-contracts',
#     'binance-smart-chain',
#     'fantom-ecosystem'],
#    'max_supply': 3175000000,
#    'circulating_supply': 2545006273,
#    'total_supply': 2545006273,
#    'platform': None,
#    'cmc_rank': 26,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.9836316748756886,
#      'volume_24h': 3033215058.8580527,
#      'volume_change_24h': 25.1027,
#      'percent_change_1h': -1.87328465,
#      'percent_change_24h': 2.72179608,
#      'percent_change_7d': 5.49028591,
#      'percent_change_30d': 126.1431418,
#      'percent_change_60d': 14.33352873,
#      'percent_change_90d': 53.52481073,
#      'market_cap': 7593361328.880124,
#      'market_cap_dominance': 0.3745,
#      'fully_diluted_market_cap': 9473030567.73,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 564,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': 21000000,
#    'circulating_supply': 18954656.25,
#    'total_supply': 18954656.25,
#    'platform': None,
#    'cmc_rank': 27,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 378.0950444134853,
#      'volume_24h': 4809956365.002938,
#      'volume_change_24h': -0.984,
#      'percent_change_1h': -0.16600079,
#      'percent_change_24h': -1.56764284,
#      'percent_change_7d': -5.52125426,
#      'percent_change_30d': -13.65829527,
#      'percent_change_60d': -44.69368796,
#      'percent_change_90d': -40.14023694,
#      'market_cap': 7166661596.686097,
#      'market_cap_dominance': 0.3534,
#      'fully_diluted_market_cap': 7939995932.68,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 558,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media', 'payments', 'tron-ecosystem', 'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 101833925429.87419,
#    'total_supply': 101833916884.59915,
#    'platform': None,
#    'cmc_rank': 28,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.06629577308213107,
#      'volume_24h': 1084047494.1086102,
#      'volume_change_24h': 36.3326,
#      'percent_change_1h': -0.36395166,
#      'percent_change_24h': -2.86836823,
#      'percent_change_7d': -6.57007903,
#      'percent_change_30d': -24.12818561,
#      'percent_change_60d': -43.51640773,
#      'percent_change_90d': -33.21534948,
#      'market_cap': 6751158812.361596,
#      'market_cap_dominance': 0.3329,
#      'fully_diluted_market_cap': 6751158245.85,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 395,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange',
#     'smart-contracts',
#     'hashkey-capital-portfolio'],
#    'max_supply': 50001806812,
#    'circulating_supply': 24775907928.27119,
#    'total_supply': 50001802340.071266,
#    'platform': None,
#    'cmc_rank': 29,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.2692606822219346,
#      'volume_24h': 474355454.65212154,
#      'volume_change_24h': -19.6089,
#      'percent_change_1h': -0.89733477,
#      'percent_change_24h': -5.76007976,
#      'percent_change_7d': 1.18075933,
#      'percent_change_30d': 0.40668659,
#      'percent_change_60d': -29.52513231,
#      'percent_change_90d': -26.38513486,
#      'market_cap': 6671177871.434139,
#      'market_cap_dominance': 0.329,
#      'fully_diluted_market_cap': 13463520614.53,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 8916,
#    'name': 'Internet Computer',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'num_market_pairs': 93,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'tags': ['platform',
#     'distributed-computing',
#     'polychain-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 198389896.57,
#    'total_supply': 476220780.90761125,
#    'platform': None,
#    'cmc_rank': 30,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 31.692705481085955,
#      'volume_24h': 440146223.30864817,
#      'volume_change_24h': -22.3988,
#      'percent_change_1h': 0.3293114,
#      'percent_change_24h': -8.60376456,
#      'percent_change_7d': 5.69805616,
#      'percent_change_30d': 22.97414077,
#      'percent_change_60d': -34.76138566,
#      'percent_change_90d': -27.76351215,
#      'market_cap': 6287512562.416115,
#      'market_cap_dominance': 0.3101,
#      'fully_diluted_market_cap': 15092724953.28,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4195,
#    'name': 'FTX Token',
#    'symbol': 'FTT',
#    'slug': 'ftx-token',
#    'num_market_pairs': 107,
#    'date_added': '2019-07-31T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'derivatives',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 352170015,
#    'circulating_supply': 138569137.91874373,
#    'total_supply': 334438473.9859715,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'FTT-F11'},
#    'cmc_rank': 31,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 41.00476704653611,
#      'volume_24h': 159127182.132871,
#      'volume_change_24h': 3.4746,
#      'percent_change_1h': -0.22198138,
#      'percent_change_24h': -1.08980335,
#      'percent_change_7d': 6.8832193,
#      'percent_change_30d': 5.0613853,
#      'percent_change_60d': -27.2272373,
#      'percent_change_90d': -28.1549329,
#      'market_cap': 5681995220.19742,
#      'market_cap_dominance': 0.2802,
#      'fully_diluted_market_cap': 14440649425.85,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1966,
#    'name': 'Decentraland',
#    'symbol': 'MANA',
#    'slug': 'decentraland',
#    'num_market_pairs': 225,
#    'date_added': '2017-09-17T00:00:00.000Z',
#    'tags': ['platform',
#     'collectibles-nfts',
#     'gaming',
#     'payments',
#     'metaverse',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'polygon-ecosystem',
#     'play-to-earn'],
#    'max_supply': None,
#    'circulating_supply': 1824524634.8740842,
#    'total_supply': 2193889627.320146,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#    'cmc_rank': 32,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.9031761438094676,
#      'volume_24h': 505198499.145862,
#      'volume_change_24h': -11.5523,
#      'percent_change_1h': -0.36082623,
#      'percent_change_24h': -5.84803803,
#      'percent_change_7d': -12.12744733,
#      'percent_change_30d': -9.40953515,
#      'percent_change_60d': -9.10719793,
#      'percent_change_90d': 280.39784133,
#      'market_cap': 5296916393.759121,
#      'market_cap_dominance': 0.2612,
#      'fully_diluted_market_cap': 6369248028.19,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4642,
#    'name': 'Hedera',
#    'symbol': 'HBAR',
#    'slug': 'hedera',
#    'num_market_pairs': 81,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'payments',
#     'dcg-portfolio'],
#    'max_supply': 50000000000,
#    'circulating_supply': 18092792421.137627,
#    'total_supply': 50000000000,
#    'platform': None,
#    'cmc_rank': 33,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.27883140164465203,
#      'volume_24h': 108099113.10629706,
#      'volume_change_24h': -5.5235,
#      'percent_change_1h': -0.37445472,
#      'percent_change_24h': -5.40360737,
#      'percent_change_7d': -4.11037052,
#      'percent_change_30d': 18.76081761,
#      'percent_change_60d': -36.02922834,
#      'percent_change_90d': -24.05373188,
#      'market_cap': 5044838670.451542,
#      'market_cap_dominance': 0.2488,
#      'fully_diluted_market_cap': 13941570082.23,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3077,
#    'name': 'VeChain',
#    'symbol': 'VET',
#    'slug': 'vechain',
#    'num_market_pairs': 161,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'tags': ['logistics',
#     'data-provenance',
#     'iot',
#     'smart-contracts',
#     'fenbushi-capital-portfolio'],
#    'max_supply': 86712634466,
#    'circulating_supply': 64315576989,
#    'total_supply': 86712634466,
#    'platform': None,
#    'cmc_rank': 34,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.07778174933213128,
#      'volume_24h': 314144146.65775836,
#      'volume_change_24h': 10.2758,
#      'percent_change_1h': -0.95305222,
#      'percent_change_24h': -5.4449934,
#      'percent_change_7d': -4.78103034,
#      'percent_change_30d': -2.92855185,
#      'percent_change_60d': -52.81780108,
#      'percent_change_90d': -35.42433201,
#      'market_cap': 5002578087.5097885,
#      'market_cap_dominance': 0.2467,
#      'fully_diluted_market_cap': 6744660397.96,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6783,
#    'name': 'Axie Infinity',
#    'symbol': 'AXS',
#    'slug': 'axie-infinity',
#    'num_market_pairs': 177,
#    'date_added': '2020-08-31T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'gaming',
#     'binance-launchpad',
#     'metaverse',
#     'defiance-capital-portfolio',
#     'play-to-earn',
#     'animoca-brands-portfolio'],
#    'max_supply': 270000000,
#    'circulating_supply': 60907500,
#    'total_supply': 270000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#    'cmc_rank': 35,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 73.24785201222336,
#      'volume_24h': 225329534.8504949,
#      'volume_change_24h': -16.9985,
#      'percent_change_1h': -0.47796824,
#      'percent_change_24h': -6.42251808,
#      'percent_change_7d': -6.12749991,
#      'percent_change_30d': -24.30925309,
#      'percent_change_60d': -49.09464808,
#      'percent_change_90d': -42.51545913,
#      'market_cap': 4461343546.434494,
#      'market_cap_dominance': 0.22,
#      'fully_diluted_market_cap': 19776920043.3,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4023,
#    'name': 'Bitcoin BEP2',
#    'symbol': 'BTCB',
#    'slug': 'bitcoin-bep2',
#    'num_market_pairs': 99,
#    'date_added': '2019-06-18T00:00:00.000Z',
#    'tags': ['binance-chain', 'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 105113.59183121,
#    'total_supply': 112501,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'BTCB-1DE'},
#    'cmc_rank': 36,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 42425.587069124624,
#      'volume_24h': 32161625.00353852,
#      'volume_change_24h': 2.7277,
#      'percent_change_1h': -0.37567231,
#      'percent_change_24h': -3.25314942,
#      'percent_change_7d': -1.18284411,
#      'percent_change_30d': -12.52168364,
#      'percent_change_60d': -35.81774787,
#      'percent_change_90d': -31.0267832,
#      'market_cap': 4459505842.383427,
#      'market_cap_dominance': 0.2199,
#      'fully_diluted_market_cap': 4772920970.86,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6210,
#    'name': 'The Sandbox',
#    'symbol': 'SAND',
#    'slug': 'the-sandbox',
#    'num_market_pairs': 177,
#    'date_added': '2020-08-05T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'content-creation',
#     'gaming',
#     'ethereum-ecosystem',
#     'binance-launchpad',
#     'metaverse',
#     'play-to-earn',
#     'animoca-brands-portfolio'],
#    'max_supply': 3000000000,
#    'circulating_supply': 920948319.2233225,
#    'total_supply': 3000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#    'cmc_rank': 37,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 4.834903141730544,
#      'volume_24h': 995916037.7571236,
#      'volume_change_24h': -10.5637,
#      'percent_change_1h': -0.2951861,
#      'percent_change_24h': -6.05732772,
#      'percent_change_7d': -5.30457899,
#      'percent_change_30d': 0.00491827,
#      'percent_change_60d': 70.98304585,
#      'percent_change_90d': 544.12097763,
#      'market_cap': 4452695921.984306,
#      'market_cap_dominance': 0.2196,
#      'fully_diluted_market_cap': 14504709425.19,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2280,
#    'name': 'Filecoin',
#    'symbol': 'FIL',
#    'slug': 'filecoin',
#    'num_market_pairs': 166,
#    'date_added': '2017-12-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'distributed-computing',
#     'filesharing',
#     'storage',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital-portfolio',
#     'pantera-capital-portfolio',
#     'web3'],
#    'max_supply': None,
#    'circulating_supply': 147799573,
#    'total_supply': 147799573,
#    'platform': None,
#    'cmc_rank': 38,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 28.63957957474591,
#      'volume_24h': 457161217.30846506,
#      'volume_change_24h': 3.1678,
#      'percent_change_1h': -0.40803432,
#      'percent_change_24h': -6.32870583,
#      'percent_change_7d': -12.7851547,
#      'percent_change_30d': -22.47047622,
#      'percent_change_60d': -54.60608117,
#      'percent_change_90d': -57.86016633,
#      'market_cap': 4232917632.046967,
#      'market_cap_dominance': 0.2087,
#      'fully_diluted_market_cap': 4232917632.05,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3945,
#    'name': 'Harmony',
#    'symbol': 'ONE',
#    'slug': 'harmony',
#    'num_market_pairs': 76,
#    'date_added': '2019-06-01T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'smart-contracts',
#     'binance-smart-chain',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'hashkey-capital-portfolio',
#     'harmony-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 11586369910.10067,
#    'total_supply': 13315002910.10068,
#    'platform': None,
#    'cmc_rank': 39,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.35336160062149546,
#      'volume_24h': 616139433.4442235,
#      'volume_change_24h': 19.5173,
#      'percent_change_1h': 0.81498859,
#      'percent_change_24h': 1.53180644,
#      'percent_change_7d': 17.22190596,
#      'percent_change_30d': 103.89172659,
#      'percent_change_60d': 27.9654194,
#      'percent_change_90d': 61.89997233,
#      'market_cap': 4094178216.8259053,
#      'market_cap_dominance': 0.2019,
#      'fully_diluted_market_cap': 4705010740.59,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'num_market_pairs': 166,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'medium-of-exchange',
#     'privacy',
#     'ringct',
#     'boostvc-portfolio',
#     'electric-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 18062446.62571494,
#    'total_supply': 18062446.62571494,
#    'platform': None,
#    'cmc_rank': 40,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 222.75830696227243,
#      'volume_24h': 394553707.21976465,
#      'volume_change_24h': 204.7036,
#      'percent_change_1h': -0.6473911,
#      'percent_change_24h': 11.40617926,
#      'percent_change_7d': 9.52406247,
#      'percent_change_30d': 17.6723373,
#      'percent_change_60d': -19.40037726,
#      'percent_change_90d': -18.31412713,
#      'market_cap': 4023560029.94067,
#      'market_cap_dominance': 0.1984,
#      'fully_diluted_market_cap': 4023560029.94,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 283,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'binance-smart-chain',
#     'dcg-portfolio'],
#    'max_supply': 210700000,
#    'circulating_supply': 132269082.19909954,
#    'total_supply': 210700000,
#    'platform': None,
#    'cmc_rank': 41,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 30.345142485868596,
#      'volume_24h': 348228859.98802197,
#      'volume_change_24h': 3.9027,
#      'percent_change_1h': -0.27108916,
#      'percent_change_24h': -2.54988769,
#      'percent_change_7d': -4.01416941,
#      'percent_change_30d': -14.80374463,
#      'percent_change_60d': -46.38271136,
#      'percent_change_90d': -44.54411538,
# ...
#    'total_supply': 37705012698.75,
#    'platform': None,
#    'cmc_rank': 86,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.09071986600122918,
#      'volume_24h': 9850518.47989556,
#      'volume_change_24h': 37.2832,
#      'percent_change_1h': 0.04071028,
#      'percent_change_24h': -0.57137243,
#      'percent_change_7d': -1.68086942,
#      'percent_change_30d': 29.62949366,
#      'percent_change_60d': -5.74432879,
#      'percent_change_90d': -19.79029063,
#      'market_cap': 1116309103.1740234,
#      'market_cap_dominance': 0.0551,
#      'fully_diluted_market_cap': 3420593699.61,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2682,
#    'name': 'Holo',
#    'symbol': 'HOT',
#    'slug': 'holo',
#    'num_market_pairs': 99,
#    'date_added': '2018-04-29T00:00:00.000Z',
#    'tags': ['platform', 'distributed-computing', 'filesharing', 'storage'],
#    'max_supply': None,
#    'circulating_supply': 173113683516.86862,
#    'total_supply': 177619433541.14133,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#    'cmc_rank': 87,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.006129023008042921,
#      'volume_24h': 77221172.6010041,
#      'volume_change_24h': -7.3809,
#      'percent_change_1h': -0.24752471,
#      'percent_change_24h': -5.90804904,
#      'percent_change_7d': -7.45808633,
#      'percent_change_30d': -23.89435979,
#      'percent_change_60d': -54.54577758,
#      'percent_change_90d': -33.3418639,
#      'market_cap': 1061017749.2819484,
#      'market_cap_dominance': 0.0523,
#      'fully_diluted_market_cap': 1088633594.85,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 873,
#    'name': 'NEM',
#    'symbol': 'XEM',
#    'slug': 'nem',
#    'num_market_pairs': 118,
#    'date_added': '2015-04-01T00:00:00.000Z',
#    'tags': ['poi',
#     'medium-of-exchange',
#     'payments',
#     'smart-contracts',
#     'fantom-ecosystem'],
#    'max_supply': 8999999999,
#    'circulating_supply': 8999999999,
#    'total_supply': 8999999999,
#    'platform': None,
#    'cmc_rank': 88,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.11492627021057997,
#      'volume_24h': 19530245.65651531,
#      'volume_change_24h': 5.1262,
#      'percent_change_1h': -0.27321088,
#      'percent_change_24h': -3.24638843,
#      'percent_change_7d': -6.2325839,
#      'percent_change_30d': -10.48409544,
#      'percent_change_60d': -40.43215145,
#      'percent_change_90d': -33.59083013,
#      'market_cap': 1034336431.7802935,
#      'market_cap_dominance': 0.051,
#      'fully_diluted_market_cap': 1034336431.78,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 8104,
#    'name': '1inch Network',
#    'symbol': '1INCH',
#    'slug': '1inch',
#    'num_market_pairs': 199,
#    'date_added': '2020-12-25T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'amm',
#     'binance-smart-chain',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'alameda-research-portfolio',
#     'parafi-capital',
#     'spartan-group'],
#    'max_supply': None,
#    'circulating_supply': 441305330.4348687,
#    'total_supply': 1500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x111111111117dc0aa78b770fa6a738034120c302'},
#    'cmc_rank': 89,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.340546474160036,
#      'volume_24h': 415754488.41769093,
#      'volume_change_24h': 469.4218,
#      'percent_change_1h': -1.42233307,
#      'percent_change_24h': 4.39892444,
#      'percent_change_7d': 0.30284712,
#      'percent_change_30d': -8.07279896,
#      'percent_change_60d': -45.51063394,
#      'percent_change_90d': -28.05590022,
#      'market_cap': 1032895635.1773615,
#      'market_cap_dominance': 0.0509,
#      'fully_diluted_market_cap': 3510819711.24,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2577,
#    'name': 'Ravencoin',
#    'symbol': 'RVN',
#    'slug': 'ravencoin',
#    'num_market_pairs': 91,
#    'date_added': '2018-03-10T00:00:00.000Z',
#    'tags': ['mineable', 'pow', 'platform', 'crowdfunding'],
#    'max_supply': 21000000000,
#    'circulating_supply': 10473290000,
#    'total_supply': 10473290000,
#    'platform': None,
#    'cmc_rank': 90,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.0950870692964907,
#      'volume_24h': 80919039.14817274,
#      'volume_change_24h': -24.067,
#      'percent_change_1h': -0.62176462,
#      'percent_change_24h': -6.83754757,
#      'percent_change_7d': -22.15061839,
#      'percent_change_30d': 12.41065813,
#      'percent_change_60d': -26.9536072,
#      'percent_change_90d': -12.95375899,
#      'market_cap': 995874451.9922432,
#      'market_cap_dominance': 0.0491,
#      'fully_diluted_market_cap': 1996828455.23,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2777,
#    'name': 'IoTeX',
#    'symbol': 'IOTX',
#    'slug': 'iotex',
#    'num_market_pairs': 68,
#    'date_added': '2018-05-25T00:00:00.000Z',
#    'tags': ['platform',
#     'iot',
#     'binance-smart-chain',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'iotex-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 9540779324.30788,
#    'total_supply': 9626124332.32,
#    'platform': None,
#    'cmc_rank': 91,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.1001943631520893,
#      'volume_24h': 26157183.35535938,
#      'volume_change_24h': -24.6293,
#      'percent_change_1h': -0.48458946,
#      'percent_change_24h': -5.61487983,
#      'percent_change_7d': -8.77192163,
#      'percent_change_30d': -10.99879162,
#      'percent_change_60d': -55.75372929,
#      'percent_change_90d': 45.41065429,
#      'market_cap': 955932308.3736489,
#      'market_cap_dominance': 0.0471,
#      'fully_diluted_market_cap': 1001943631.52,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3330,
#    'name': 'Pax Dollar',
#    'symbol': 'USDP',
#    'slug': 'paxos-standard',
#    'num_market_pairs': 34,
#    'date_added': '2018-09-27T00:00:00.000Z',
#    'tags': ['store-of-value',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 945642940.11,
#    'total_supply': 945642940.11,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#    'cmc_rank': 92,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.999759519500035,
#      'volume_24h': 7298785.06454039,
#      'volume_change_24h': -42.9506,
#      'percent_change_1h': -0.00724199,
#      'percent_change_24h': 0.00366916,
#      'percent_change_7d': -0.09532239,
#      'percent_change_30d': -0.03958014,
#      'percent_change_60d': -0.02111768,
#      'percent_change_90d': 0.01808586,
#      'market_cap': 945415531.422974,
#      'market_cap_dominance': 0.0466,
#      'fully_diluted_market_cap': 945415531.42,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3822,
#    'name': 'Theta Fuel',
#    'symbol': 'TFUEL',
#    'slug': 'theta-fuel',
#    'num_market_pairs': 26,
#    'date_added': '2019-03-28T00:00:00.000Z',
#    'tags': ['media', 'content-creation', 'payments'],
#    'max_supply': None,
#    'circulating_supply': 5301214400,
#    'total_supply': 5301214400,
#    'platform': None,
#    'cmc_rank': 93,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.16912381599779372,
#      'volume_24h': 34205979.40703573,
#      'volume_change_24h': 40.5583,
#      'percent_change_1h': -0.65201495,
#      'percent_change_24h': -4.6849018,
#      'percent_change_7d': -4.45713416,
#      'percent_change_30d': -15.69439097,
#      'percent_change_60d': -49.71648587,
#      'percent_change_90d': -41.14286723,
#      'market_cap': 896561608.7504544,
#      'market_cap_dominance': 0.0442,
#      'fully_diluted_market_cap': 896561608.75,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6758,
#    'name': 'SushiSwap',
#    'symbol': 'SUSHI',
#    'slug': 'sushiswap',
#    'num_market_pairs': 282,
#    'date_added': '2020-08-28T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'yearn-partnerships',
#     'governance',
#     'avalanche-ecosystem',
#     'metaverse',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'harmony-ecosystem'],
#    'max_supply': 250000000,
#    'circulating_supply': 127244443,
#    'total_supply': 239449799.99188623,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b3595068778dd592e39a122f4f5a5cf09c90fe2'},
#    'cmc_rank': 94,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 7.02741784148334,
#      'volume_24h': 391078299.8722022,
#      'volume_change_24h': 21.2648,
#      'percent_change_1h': -0.40902872,
#      'percent_change_24h': -0.81052943,
#      'percent_change_7d': -4.17960321,
#      'percent_change_30d': 20.71502558,
#      'percent_change_60d': -36.84213531,
#      'percent_change_90d': -36.71654419,
#      'market_cap': 894199868.9678098,
#      'market_cap_dominance': 0.0441,
#      'fully_diluted_market_cap': 1756854460.37,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 7501,
#    'name': 'WOO Network',
#    'symbol': 'WOO',
#    'slug': 'wootrade',
#    'num_market_pairs': 79,
#    'date_added': '2020-10-23T00:00:00.000Z',
#    'tags': ['centralized-exchange',
#     'binance-smart-chain',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'mvb',
#     'vbc-ventures-portfolio'],
#    'max_supply': 3000000000,
#    'circulating_supply': 884078589.0001837,
#    'total_supply': 2990413143.711403,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#    'cmc_rank': 95,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.9547432536876855,
#      'volume_24h': 31274916.09095238,
#      'volume_change_24h': -3.2877,
#      'percent_change_1h': -1.30727185,
#      'percent_change_24h': -7.8411418,
#      'percent_change_7d': -6.04405781,
#      'percent_change_30d': 23.3561151,
#      'percent_change_60d': -38.92798069,
#      'percent_change_90d': -7.28121129,
#      'market_cap': 844068068.5776534,
#      'market_cap_dominance': 0.0416,
#      'fully_diluted_market_cap': 2864229761.06,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1808,
#    'name': 'OMG Network',
#    'symbol': 'OMG',
#    'slug': 'omg',
#    'num_market_pairs': 256,
#    'date_added': '2017-07-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'payments',
#     'scaling',
#     'state-channel',
#     'pantera-capital-portfolio'],
#    'max_supply': 140245399,
#    'circulating_supply': 140245398.24513277,
#    'total_supply': 140245398.24513277,
#    'platform': None,
#    'cmc_rank': 96,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 5.914466275775133,
#      'volume_24h': 551981525.5416362,
#      'volume_change_24h': 32.0811,
#      'percent_change_1h': -1.56565492,
#      'percent_change_24h': 0.48351625,
#      'percent_change_7d': 5.18515463,
#      'percent_change_30d': -1.37312707,
#      'percent_change_60d': -49.46936283,
#      'percent_change_90d': -58.06085889,
#      'market_cap': 829476678.2534909,
#      'market_cap_dominance': 0.0409,
#      'fully_diluted_market_cap': 829476682.72,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4747,
#    'name': 'Velas',
#    'symbol': 'VLX',
#    'slug': 'velas',
#    'num_market_pairs': 46,
#    'date_added': '2019-10-03T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 2248438277.883389,
#    'total_supply': 2248438277.883389,
#    'platform': None,
#    'cmc_rank': 97,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.3686915688490903,
#      'volume_24h': 24120276.18111217,
#      'volume_change_24h': 4.602,
#      'percent_change_1h': 0.25433908,
#      'percent_change_24h': -0.31594174,
#      'percent_change_7d': -14.96354795,
#      'percent_change_30d': 20.66326467,
#      'percent_change_60d': -6.40962111,
#      'percent_change_90d': 145.84507672,
#      'market_cap': 828980236.1331736,
#      'market_cap_dominance': 0.0409,
#      'fully_diluted_market_cap': 828980236.13,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1727,
#    'name': 'Bancor',
#    'symbol': 'BNT',
#    'slug': 'bancor',
#    'num_market_pairs': 250,
#    'date_added': '2017-06-18T00:00:00.000Z',
#    'tags': ['marketplace',
#     'decentralized-exchange',
#     'defi',
#     'payments',
#     'scaling',
#     'amm',
#     'kenetic-capital-portfolio',
#     'arbitrum-ecosytem'],
#    'max_supply': None,
#    'circulating_supply': 258480308.70921257,
#    'total_supply': 258480308.70921257,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c'},
#    'cmc_rank': 98,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 3.142925071061962,
#      'volume_24h': 24906585.05195478,
#      'volume_change_24h': -6.4209,
#      'percent_change_1h': -0.53514322,
#      'percent_change_24h': -4.04635747,
#      'percent_change_7d': -1.80776081,
#      'percent_change_30d': -2.72398285,
#      'percent_change_60d': -31.07260216,
#      'percent_change_90d': -23.83916531,
#      'market_cap': 812384242.6180198,
#      'market_cap_dominance': 0.0401,
#      'fully_diluted_market_cap': 812384242.62,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2700,
#    'name': 'Celsius',
#    'symbol': 'CEL',
#    'slug': 'celsius',
#    'num_market_pairs': 54,
#    'date_added': '2018-05-18T00:00:00.000Z',
#    'tags': ['lending-borowing', 'exnetwork-capital-portfolio'],
#    'max_supply': 695658160,
#    'circulating_supply': 238863519.826,
#    'total_supply': 695658160,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xaaaebe6fe48e54f431b0c390cfaf0b017d09d42d'},
#    'cmc_rank': 99,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 3.3717748811107153,
#      'volume_24h': 5762877.51652774,
#      'volume_change_24h': 47.6601,
#      'percent_change_1h': -0.51813083,
#      'percent_change_24h': 2.48898,
#      'percent_change_7d': -3.41387601,
#      'percent_change_30d': -11.56064215,
#      'percent_change_60d': -29.02788706,
#      'percent_change_90d': -41.84775771,
#      'market_cap': 805394016.1629982,
#      'market_cap_dominance': 0.0397,
#      'fully_diluted_market_cap': 2345602709.73,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1168,
#    'name': 'Decred',
#    'symbol': 'DCR',
#    'slug': 'decred',
#    'num_market_pairs': 56,
#    'date_added': '2016-02-10T00:00:00.000Z',
#    'tags': ['mineable',
#     'hybrid-pow-pos',
#     'blake256',
#     'medium-of-exchange',
#     'store-of-value',
#     'privacy',
#     'dao',
#     'placeholder-ventures-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 13674348.15535159,
#    'total_supply': 13674348.15535159,
#    'platform': None,
#    'cmc_rank': 100,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 58.11658650412743,
#      'volume_24h': 3282529.29305708,
#      'volume_change_24h': 1.5871,
#      'percent_change_1h': -0.37173323,
#      'percent_change_24h': -6.65886148,
#      'percent_change_7d': -8.37118937,
#      'percent_change_30d': -8.72130027,
#      'percent_change_60d': -51.57046478,
#      'percent_change_90d': -51.97521554,
#      'market_cap': 794706437.4580461,
#      'market_cap_dominance': 0.0392,
#      'fully_diluted_market_cap': 1220448316.59,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}}]}

# %%
data_retrieved = requests.get(api_endpoint).json()
data_retrieved
# Out:
# {'status': {'timestamp': '2022-01-14T00:28:12.949Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 27,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 9055},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 9035,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 18928468,
#    'total_supply': 18928468,
#    'platform': None,
#    'cmc_rank': 1,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 42626.79624953153,
#      'volume_24h': 47438485012.929756,
#      'volume_change_24h': 30.5631,
#      'percent_change_1h': -0.14520685,
#      'percent_change_24h': -2.87714894,
#      'percent_change_7d': -0.75550566,
#      'percent_change_30d': -12.29577946,
#      'percent_change_60d': -35.42143291,
#      'percent_change_90d': -30.78929348,
#      'market_cap': 806859948751.7776,
#      'market_cap_dominance': 39.791,
#      'fully_diluted_market_cap': 895162721240.16,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 5408,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 119149215.0615,
#    'total_supply': 119149215.0615,
#    'platform': None,
#    'cmc_rank': 2,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 3248.279973225764,
#      'volume_24h': 15344356934.90106,
#      'volume_change_24h': -7.8008,
#      'percent_change_1h': -0.34621863,
#      'percent_change_24h': -3.73433427,
#      'percent_change_7d': -4.52623157,
#      'percent_change_30d': -16.52782971,
#      'percent_change_60d': -30.46993757,
#      'percent_change_90d': -15.82272023,
#      'market_cap': 387030009109.84,
#      'market_cap_dominance': 19.0867,
#      'fully_diluted_market_cap': 387030009109.84,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1839,
#    'name': 'BNB',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'num_market_pairs': 620,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'binance-smart-chain',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'moonriver-ecosystem'],
#    'max_supply': 166801148,
#    'circulating_supply': 166801148,
#    'total_supply': 166801148,
#    'platform': None,
#    'cmc_rank': 3,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 476.37190328721164,
#      'volume_24h': 4158155454.9011,
#      'volume_change_24h': 0.2961,
#      'percent_change_1h': -0.17177635,
#      'percent_change_24h': -2.24996642,
#      'percent_change_7d': 1.16071968,
#      'percent_change_30d': -10.36076125,
#      'percent_change_60d': -27.34234774,
#      'percent_change_90d': 0.05591968,
#      'market_cap': 79459380343.25188,
#      'market_cap_dominance': 3.9185,
#      'fully_diluted_market_cap': 79459380343.25,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 25905,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['payments',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 78394369307.4411,
#    'total_supply': 82008978873.83017,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'cmc_rank': 4,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.0003414199151444,
#      'volume_24h': 63519454907.42146,
#      'volume_change_24h': 1.8562,
#      'percent_change_1h': -0.00400463,
#      'percent_change_24h': 0.00648299,
#      'percent_change_7d': 0.02503164,
#      'percent_change_30d': -0.03937018,
#      'percent_change_60d': 0.01166612,
#      'percent_change_90d': 0.12022868,
#      'market_cap': 78421134706.35785,
#      'market_cap_dominance': 3.8673,
#      'fully_diluted_market_cap': 82036978372.44,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 230,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'k300-ventures-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 313379591.06839514,
#    'total_supply': 511616946.142289,
#    'platform': None,
#    'cmc_rank': 5,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 146.92870891275413,
#      'volume_24h': 2195552644.256326,
#      'volume_change_24h': -2.2777,
#      'percent_change_1h': -0.11359136,
#      'percent_change_24h': -3.28385825,
#      'percent_change_7d': -1.70750349,
#      'percent_change_30d': -9.56942879,
#      'percent_change_60d': -39.02934469,
#      'percent_change_90d': -8.58367003,
#      'market_cap': 46044458715.286156,
#      'market_cap_dominance': 2.2707,
#      'fully_diluted_market_cap': 75171217354.57,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3408,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 2712,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain',
#     'fantom-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 44990134364.3109,
#    'total_supply': 44990134364.3109,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'cmc_rank': 6,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.9993521643143158,
#      'volume_24h': 3524932103.9169087,
#      'volume_change_24h': 2.3463,
#      'percent_change_1h': 0.00101539,
#      'percent_change_24h': -0.08442648,
#      'percent_change_7d': -0.02537614,
#      'percent_change_30d': -0.06747519,
#      'percent_change_60d': 0.03354794,
#      'percent_change_90d': 0.00273095,
#      'market_cap': 44960988149.76597,
#      'market_cap_dominance': 2.2172,
#      'fully_diluted_market_cap': 44960988149.77,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 354,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['mineable',
#     'dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'binance-smart-chain',
#     'cardano-ecosystem'],
#    'max_supply': 45000000000,
#    'circulating_supply': 33513219990.714,
#    'total_supply': 33968614580.749,
#    'platform': None,
#    'cmc_rank': 7,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.2371048886462936,
#      'volume_24h': 1988036726.179527,
#      'volume_change_24h': 18.3465,
#      'percent_change_1h': -0.29442449,
#      'percent_change_24h': -6.24124148,
#      'percent_change_7d': -2.92862416,
#      'percent_change_30d': -2.53173745,
#      'percent_change_60d': -39.98514192,
#      'percent_change_90d': -44.52880638,
#      'market_cap': 41459368284.790985,
#      'market_cap_dominance': 2.0446,
#      'fully_diluted_market_cap': 55669719989.08,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 673,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'binance-chain',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 100000000000,
#    'circulating_supply': 47615126275,
#    'total_supply': 99989829709,
#    'platform': None,
#    'cmc_rank': 8,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.7697948322777478,
#      'volume_24h': 1582038995.5631213,
#      'volume_change_24h': -19.098,
#      'percent_change_1h': -0.05414415,
#      'percent_change_24h': -3.57506776,
#      'percent_change_7d': -0.87332321,
#      'percent_change_30d': -5.07917226,
#      'percent_change_60d': -35.75605659,
#      'percent_change_90d': -32.66197679,
#      'market_cap': 36653878144.747406,
#      'market_cap_dominance': 1.8076,
#      'fully_diluted_market_cap': 76979483227.77,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4172,
#    'name': 'Terra',
#    'symbol': 'LUNA',
#    'slug': 'terra-luna',
#    'num_market_pairs': 128,
#    'date_added': '2019-07-26T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'store-of-value',
#     'defi',
#     'payments',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'pantera-capital-portfolio',
#     'terra-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 356591830.0904593,
#    'total_supply': 828014972.214518,
#    'platform': None,
#    'cmc_rank': 9,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 78.74770886630616,
#      'volume_24h': 2467842133.3792186,
#      'volume_change_24h': -3.1039,
#      'percent_change_1h': 0.24938852,
#      'percent_change_24h': -3.54915295,
#      'percent_change_7d': 0.98726737,
#      'percent_change_30d': 29.95173627,
#      'percent_change_60d': 53.04673975,
#      'percent_change_90d': 112.71839899,
#      'market_cap': 28080789620.0668,
#      'market_cap_dominance': 1.3848,
#      'fully_diluted_market_cap': 65204281968.89,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 294,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'binance-chain',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group'],
#    'max_supply': None,
#    'circulating_supply': 987579314.957085,
#    'total_supply': 1103303471.382273,
#    'platform': None,
#    'cmc_rank': 10,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 25.867541858775024,
#      'volume_24h': 1401115132.6774719,
#      'volume_change_24h': -1.3844,
#      'percent_change_1h': -0.60643081,
#      'percent_change_24h': -6.04318854,
#      'percent_change_7d': -2.55300601,
#      'percent_change_30d': -1.62469404,
#      'percent_change_60d': -45.03381851,
#      'percent_change_90d': -41.13685197,
#      'market_cap': 25546249268.51276,
#      'market_cap_dominance': 1.2598,
#      'fully_diluted_market_cap': 28539748728.91,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 442,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'binance-smart-chain',
#     'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 132670764299.89409,
#    'total_supply': 132670764299.89409,
#    'platform': None,
#    'cmc_rank': 11,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.17527139928031182,
#      'volume_24h': 2396862639.757897,
#      'volume_change_24h': 168.9414,
#      'percent_change_1h': 0.9287015,
#      'percent_change_24h': 8.42465797,
#      'percent_change_7d': 10.10445991,
#      'percent_change_30d': -6.27363493,
#      'percent_change_60d': -33.68618142,
#      'percent_change_90d': -27.85069644,
#      'market_cap': 23253390502.430878,
#      'market_cap_dominance': 1.1467,
#      'fully_diluted_market_cap': 23253390502.43,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 156,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'smart-contracts',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 244354897.0677541,
#    'total_supply': 395891289.9134107,
#    'platform': None,
#    'cmc_rank': 12,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 89.72376718394646,
#      'volume_24h': 759176851.0687491,
#      'volume_change_24h': -21.0083,
#      'percent_change_1h': -0.41359083,
#      'percent_change_24h': -6.40060453,
#      'percent_change_7d': -5.44252368,
#      'percent_change_30d': 1.26365667,
#      'percent_change_60d': -6.6040213,
#      'percent_change_90d': 59.02330823,
#      'market_cap': 21924441894.76437,
#      'market_cap_dominance': 1.0812,
#      'fully_diluted_market_cap': 35520857926.34,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'num_market_pairs': 310,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'state-channel',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 7312892503.27,
#    'total_supply': 10000000000,
#    'platform': None,
#    'cmc_rank': 13,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.2646686461466525,
#      'volume_24h': 1511108875.1445932,
#      'volume_change_24h': -20.9508,
#      'percent_change_1h': -1.01234359,
#      'percent_change_24h': -6.57935758,
#      'percent_change_7d': 1.76579479,
#      'percent_change_30d': 14.68545852,
#      'percent_change_60d': 30.44124454,
#      'percent_change_90d': 47.60952954,
#      'market_cap': 16561278364.796476,
#      'market_cap_dominance': 0.8167,
#      'fully_diluted_market_cap': 22646686461.47,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 5994,
#    'name': 'Shiba Inu',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 294,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes', 'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 549063278876301.94,
#    'total_supply': 589735030408322.8,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'cmc_rank': 14,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.9654450730502256e-05,
#      'volume_24h': 1430558309.1456907,
#      'volume_change_24h': -8.9226,
#      'percent_change_1h': -0.75662944,
#      'percent_change_24h': -7.12088834,
#      'percent_change_7d': -3.67135383,
#      'percent_change_30d': -13.04367387,
#      'percent_change_60d': -43.80208329,
#      'percent_change_90d': 15.22331155,
#      'market_cap': 16282169951.365316,
#      'market_cap_dominance': 0.8029,
#      'fully_diluted_market_cap': 17488268403.29,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4687,
#    'name': 'Binance USD',
#    'symbol': 'BUSD',
#    'slug': 'binance-usd',
#    'num_market_pairs': 2690,
#    'date_added': '2019-09-20T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'binance-chain',
#     'binance-smart-chain',
#     'harmony-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 14248528863.969255,
#    'total_supply': 14248528863.969255,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'BUSD-BD1'},
#    'cmc_rank': 15,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.000240340199687,
#      'volume_24h': 4206980283.9682164,
#      'volume_change_24h': -1.5029,
#      'percent_change_1h': -0.04205364,
#      'percent_change_24h': -0.03365262,
#      'percent_change_7d': 0.05804525,
#      'percent_change_30d': 0.023187,
#      'percent_change_60d': 0.00186139,
#      'percent_change_90d': 0.09115075,
#      'market_cap': 14251953358.241669,
#      'market_cap_dominance': 0.7028,
#      'fully_diluted_market_cap': 14251953358.24,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6535,
#    'name': 'NEAR Protocol',
#    'symbol': 'NEAR',
#    'slug': 'near-protocol',
#    'num_market_pairs': 87,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['platform',
#     'staking',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'k300-ventures-portfolio'],
#    'max_supply': 1000000000,
#    'circulating_supply': 608389619,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 16,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 20.176374909686,
#      'volume_24h': 1744082123.2758503,
#      'volume_change_24h': 47.0942,
#      'percent_change_1h': 3.3841326,
#      'percent_change_24h': 16.36324071,
#      'percent_change_7d': 27.67895509,
#      'percent_change_30d': 115.40665254,
#      'percent_change_60d': 71.89305271,
#      'percent_change_90d': 154.42485409,
#      'market_cap': 12275097044.105024,
#      'market_cap_dominance': 0.6053,
#      'fully_diluted_market_cap': 20176374909.69,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 568,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 467009550.4397637,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'cmc_rank': 17,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 25.067837953645714,
#      'volume_24h': 1556184963.534812,
#      'volume_change_24h': -21.144,
#      'percent_change_1h': 0.07347712,
#      'percent_change_24h': -5.27295472,
#      'percent_change_7d': 1.24230407,
#      'percent_change_30d': 35.21823883,
#      'percent_change_60d': -27.03512867,
#      'percent_change_90d': -8.34210891,
#      'market_cap': 11706919733.228931,
#      'market_cap_dominance': 0.5773,
#      'fully_diluted_market_cap': 25067837953.65,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3635,
#    'name': 'Crypto.com Coin',
#    'symbol': 'CRO',
#    'slug': 'crypto-com-coin',
#    'num_market_pairs': 123,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments'],
#    'max_supply': 30263013692,
#    'circulating_supply': 25263013692,
#    'total_supply': 30263013692,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'cmc_rank': 18,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.4564769912754534,
#      'volume_24h': 151174465.9211202,
#      'volume_change_24h': -15.2413,
#      'percent_change_1h': -0.4344321,
#      'percent_change_24h': -6.18902706,
#      'percent_change_7d': -8.60155648,
#      'percent_change_30d': -16.66177514,
#      'percent_change_60d': 0.45305521,
#      'percent_change_90d': 139.5112659,
#      'market_cap': 11531984480.674744,
#      'market_cap_dominance': 0.5687,
#      'fully_diluted_market_cap': 13814369437.05,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3717,
#    'name': 'Wrapped Bitcoin',
#    'symbol': 'WBTC',
#    'slug': 'wrapped-bitcoin',
#    'num_market_pairs': 314,
#    'date_added': '2019-01-30T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'defi',
#     'wrapped-tokens',
#     'fantom-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 266880.73402772,
#    'total_supply': 266880.73402772,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#    'cmc_rank': 19,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 42652.47937423112,
#      'volume_24h': 190388057.94342092,
#      'volume_change_24h': -5.0516,
#      'percent_change_1h': -0.1343726,
#      'percent_change_24h': -2.75664734,
#      'percent_change_7d': -0.70227153,
#      'percent_change_30d': -11.12724491,
#      'percent_change_60d': -34.46022929,
#      'percent_change_90d': -30.67345012,
#      'market_cap': 11383125003.49699,
#      'market_cap_dominance': 0.5614,
#      'fully_diluted_market_cap': 11383125003.5,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 7129,
#    'name': 'TerraUSD',
#    'symbol': 'UST',
#    'slug': 'terrausd',
#    'num_market_pairs': 246,
#    'date_added': '2020-09-21T00:00:00.000Z',
#    'tags': ['stablecoin', 'binance-smart-chain', 'terra-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 10592707055.583405,
#    'total_supply': 10592707055.583405,
#    'platform': None,
#    'cmc_rank': 20,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.0010663970177425,
#      'volume_24h': 219239584.5546335,
#      'volume_change_24h': -1.5318,
#      'percent_change_1h': 0.21736712,
#      'percent_change_24h': 0.34587711,
#      'percent_change_7d': 0.20565136,
#      'percent_change_30d': -0.02088591,
#      'percent_change_60d': -0.59066041,
#      'percent_change_90d': -0.00921431,
#      'market_cap': 10604003086.797298,
#      'market_cap_dominance': 0.5229,
#      'fully_diluted_market_cap': 10604003086.8,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 326,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 627292763.9836428,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'cmc_rank': 21,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 15.499867875419488,
#      'volume_24h': 236773012.54270607,
#      'volume_change_24h': 8.7191,
#      'percent_change_1h': -0.31232355,
#      'percent_change_24h': -4.56890854,
#      'percent_change_7d': -8.62395738,
#      'percent_change_30d': 2.90753334,
#      'percent_change_60d': -37.52380518,
#      'percent_change_90d': -40.4269377,
#      'market_cap': 9722954960.953165,
#      'market_cap_dominance': 0.4795,
#      'fully_diluted_market_cap': 15499867875.42,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 724,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': 84000000,
#    'circulating_supply': 69407894.4948378,
#    'total_supply': 84000000,
#    'platform': None,
#    'cmc_rank': 22,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 137.10229187663754,
#      'volume_24h': 892800738.0694944,
#      'volume_change_24h': 1.2144,
#      'percent_change_1h': 0.00598389,
#      'percent_change_24h': -2.92080819,
#      'percent_change_7d': 0.74515289,
#      'percent_change_30d': -9.42521307,
#      'percent_change_60d': -50.32960174,
#      'percent_change_90d': -28.04193346,
#      'market_cap': 9515981409.574116,
#      'market_cap_dominance': 0.4693,
#      'fully_diluted_market_cap': 11516592517.64,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 700,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi',
#     'stablecoin',
#     'ethereum-ecosystem',
#     'binance-smart-chain',
#     'avalanche-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 9475025853.622076,
#    'total_supply': 9475025853.622076,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'cmc_rank': 23,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.9990888045409372,
#      'volume_24h': 461322483.1333583,
#      'volume_change_24h': 17.2858,
#      'percent_change_1h': -0.05449006,
#      'percent_change_24h': -0.16129342,
#      'percent_change_7d': -0.00959075,
#      'percent_change_30d': -0.3009631,
#      'percent_change_60d': -0.30417158,
#      'percent_change_90d': -0.07916133,
#      'market_cap': 9466392253.089752,
#      'market_cap_dominance': 0.4668,
#      'fully_diluted_market_cap': 9466392253.09,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4030,
#    'name': 'Algorand',
#    'symbol': 'ALGO',
#    'slug': 'algorand',
#    'num_market_pairs': 172,
#    'date_added': '2019-06-20T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'arrington-xrp-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 10000000000,
#    'circulating_supply': 6464479852.867192,
#    'total_supply': 6908302131.039248,
#    'platform': None,
#    'cmc_rank': 24,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 1.3615032872514103,
#      'volume_24h': 557578525.2308326,
#      'volume_change_24h': 24.7772,
#      'percent_change_1h': -0.1461109,
#      'percent_change_24h': -8.45725173,
#      'percent_change_7d': -11.64065286,
#      'percent_change_30d': -1.57383217,
#      'percent_change_60d': -31.91782835,
#      'percent_change_90d': -22.72272762,
#      'market_cap': 8801410570.049196,
#      'market_cap_dominance': 0.434,
#      'fully_diluted_market_cap': 13615032872.51,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 221,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 226226027.647699,
#    'total_supply': 284010630.647699,
#    'platform': None,
#    'cmc_rank': 25,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 37.41934119527285,
#      'volume_24h': 1768594256.8875446,
#      'volume_change_24h': -19.2611,
#      'percent_change_1h': -2.66724368,
#      'percent_change_24h': -7.86337603,
#      'percent_change_7d': -6.04810524,
#      'percent_change_30d': 69.76560532,
#      'percent_change_60d': 14.3550647,
#      'percent_change_90d': 12.00470625,
#      'market_cap': 8465228915.800478,
#      'market_cap_dominance': 0.4175,
#      'fully_diluted_market_cap': 10627490691.29,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3513,
#    'name': 'Fantom',
#    'symbol': 'FTM',
#    'slug': 'fantom',
#    'num_market_pairs': 207,
#    'date_added': '2018-10-29T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'defi',
#     'research',
#     'scaling',
#     'smart-contracts',
#     'binance-smart-chain',
#     'fantom-ecosystem'],
#    'max_supply': 3175000000,
#    'circulating_supply': 2545006273,
#    'total_supply': 2545006273,
#    'platform': None,
#    'cmc_rank': 26,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.9836316748756886,
#      'volume_24h': 3033215058.8580527,
#      'volume_change_24h': 25.1027,
#      'percent_change_1h': -1.87328465,
#      'percent_change_24h': 2.72179608,
#      'percent_change_7d': 5.49028591,
#      'percent_change_30d': 126.1431418,
#      'percent_change_60d': 14.33352873,
#      'percent_change_90d': 53.52481073,
#      'market_cap': 7593361328.880124,
#      'market_cap_dominance': 0.3745,
#      'fully_diluted_market_cap': 9473030567.73,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 564,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': 21000000,
#    'circulating_supply': 18954656.25,
#    'total_supply': 18954656.25,
#    'platform': None,
#    'cmc_rank': 27,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 378.0950444134853,
#      'volume_24h': 4809956365.002938,
#      'volume_change_24h': -0.984,
#      'percent_change_1h': -0.16600079,
#      'percent_change_24h': -1.56764284,
#      'percent_change_7d': -5.52125426,
#      'percent_change_30d': -13.65829527,
#      'percent_change_60d': -44.69368796,
#      'percent_change_90d': -40.14023694,
#      'market_cap': 7166661596.686097,
#      'market_cap_dominance': 0.3534,
#      'fully_diluted_market_cap': 7939995932.68,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 558,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media', 'payments', 'tron-ecosystem', 'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 101833925429.87419,
#    'total_supply': 101833916884.59915,
#    'platform': None,
#    'cmc_rank': 28,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.06629577308213107,
#      'volume_24h': 1084047494.1086102,
#      'volume_change_24h': 36.3326,
#      'percent_change_1h': -0.36395166,
#      'percent_change_24h': -2.86836823,
#      'percent_change_7d': -6.57007903,
#      'percent_change_30d': -24.12818561,
#      'percent_change_60d': -43.51640773,
#      'percent_change_90d': -33.21534948,
#      'market_cap': 6751158812.361596,
#      'market_cap_dominance': 0.3329,
#      'fully_diluted_market_cap': 6751158245.85,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 395,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange',
#     'smart-contracts',
#     'hashkey-capital-portfolio'],
#    'max_supply': 50001806812,
#    'circulating_supply': 24775907928.27119,
#    'total_supply': 50001802340.071266,
#    'platform': None,
#    'cmc_rank': 29,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.2692606822219346,
#      'volume_24h': 474355454.65212154,
#      'volume_change_24h': -19.6089,
#      'percent_change_1h': -0.89733477,
#      'percent_change_24h': -5.76007976,
#      'percent_change_7d': 1.18075933,
#      'percent_change_30d': 0.40668659,
#      'percent_change_60d': -29.52513231,
#      'percent_change_90d': -26.38513486,
#      'market_cap': 6671177871.434139,
#      'market_cap_dominance': 0.329,
#      'fully_diluted_market_cap': 13463520614.53,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 8916,
#    'name': 'Internet Computer',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'num_market_pairs': 93,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'tags': ['platform',
#     'distributed-computing',
#     'polychain-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 198389896.57,
#    'total_supply': 476220780.90761125,
#    'platform': None,
#    'cmc_rank': 30,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 31.692705481085955,
#      'volume_24h': 440146223.30864817,
#      'volume_change_24h': -22.3988,
#      'percent_change_1h': 0.3293114,
#      'percent_change_24h': -8.60376456,
#      'percent_change_7d': 5.69805616,
#      'percent_change_30d': 22.97414077,
#      'percent_change_60d': -34.76138566,
#      'percent_change_90d': -27.76351215,
#      'market_cap': 6287512562.416115,
#      'market_cap_dominance': 0.3101,
#      'fully_diluted_market_cap': 15092724953.28,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4195,
#    'name': 'FTX Token',
#    'symbol': 'FTT',
#    'slug': 'ftx-token',
#    'num_market_pairs': 107,
#    'date_added': '2019-07-31T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'derivatives',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 352170015,
#    'circulating_supply': 138569137.91874373,
#    'total_supply': 334438473.9859715,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'FTT-F11'},
#    'cmc_rank': 31,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 41.00476704653611,
#      'volume_24h': 159127182.132871,
#      'volume_change_24h': 3.4746,
#      'percent_change_1h': -0.22198138,
#      'percent_change_24h': -1.08980335,
#      'percent_change_7d': 6.8832193,
#      'percent_change_30d': 5.0613853,
#      'percent_change_60d': -27.2272373,
#      'percent_change_90d': -28.1549329,
#      'market_cap': 5681995220.19742,
#      'market_cap_dominance': 0.2802,
#      'fully_diluted_market_cap': 14440649425.85,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1966,
#    'name': 'Decentraland',
#    'symbol': 'MANA',
#    'slug': 'decentraland',
#    'num_market_pairs': 225,
#    'date_added': '2017-09-17T00:00:00.000Z',
#    'tags': ['platform',
#     'collectibles-nfts',
#     'gaming',
#     'payments',
#     'metaverse',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'polygon-ecosystem',
#     'play-to-earn'],
#    'max_supply': None,
#    'circulating_supply': 1824524634.8740842,
#    'total_supply': 2193889627.320146,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#    'cmc_rank': 32,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.9031761438094676,
#      'volume_24h': 505198499.145862,
#      'volume_change_24h': -11.5523,
#      'percent_change_1h': -0.36082623,
#      'percent_change_24h': -5.84803803,
#      'percent_change_7d': -12.12744733,
#      'percent_change_30d': -9.40953515,
#      'percent_change_60d': -9.10719793,
#      'percent_change_90d': 280.39784133,
#      'market_cap': 5296916393.759121,
#      'market_cap_dominance': 0.2612,
#      'fully_diluted_market_cap': 6369248028.19,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4642,
#    'name': 'Hedera',
#    'symbol': 'HBAR',
#    'slug': 'hedera',
#    'num_market_pairs': 81,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'payments',
#     'dcg-portfolio'],
#    'max_supply': 50000000000,
#    'circulating_supply': 18092792421.137627,
#    'total_supply': 50000000000,
#    'platform': None,
#    'cmc_rank': 33,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.27883140164465203,
#      'volume_24h': 108099113.10629706,
#      'volume_change_24h': -5.5235,
#      'percent_change_1h': -0.37445472,
#      'percent_change_24h': -5.40360737,
#      'percent_change_7d': -4.11037052,
#      'percent_change_30d': 18.76081761,
#      'percent_change_60d': -36.02922834,
#      'percent_change_90d': -24.05373188,
#      'market_cap': 5044838670.451542,
#      'market_cap_dominance': 0.2488,
#      'fully_diluted_market_cap': 13941570082.23,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3077,
#    'name': 'VeChain',
#    'symbol': 'VET',
#    'slug': 'vechain',
#    'num_market_pairs': 161,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'tags': ['logistics',
#     'data-provenance',
#     'iot',
#     'smart-contracts',
#     'fenbushi-capital-portfolio'],
#    'max_supply': 86712634466,
#    'circulating_supply': 64315576989,
#    'total_supply': 86712634466,
#    'platform': None,
#    'cmc_rank': 34,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.07778174933213128,
#      'volume_24h': 314144146.65775836,
#      'volume_change_24h': 10.2758,
#      'percent_change_1h': -0.95305222,
#      'percent_change_24h': -5.4449934,
#      'percent_change_7d': -4.78103034,
#      'percent_change_30d': -2.92855185,
#      'percent_change_60d': -52.81780108,
#      'percent_change_90d': -35.42433201,
#      'market_cap': 5002578087.5097885,
#      'market_cap_dominance': 0.2467,
#      'fully_diluted_market_cap': 6744660397.96,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6783,
#    'name': 'Axie Infinity',
#    'symbol': 'AXS',
#    'slug': 'axie-infinity',
#    'num_market_pairs': 177,
#    'date_added': '2020-08-31T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'gaming',
#     'binance-launchpad',
#     'metaverse',
#     'defiance-capital-portfolio',
#     'play-to-earn',
#     'animoca-brands-portfolio'],
#    'max_supply': 270000000,
#    'circulating_supply': 60907500,
#    'total_supply': 270000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#    'cmc_rank': 35,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 73.24785201222336,
#      'volume_24h': 225329534.8504949,
#      'volume_change_24h': -16.9985,
#      'percent_change_1h': -0.47796824,
#      'percent_change_24h': -6.42251808,
#      'percent_change_7d': -6.12749991,
#      'percent_change_30d': -24.30925309,
#      'percent_change_60d': -49.09464808,
#      'percent_change_90d': -42.51545913,
#      'market_cap': 4461343546.434494,
#      'market_cap_dominance': 0.22,
#      'fully_diluted_market_cap': 19776920043.3,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4023,
#    'name': 'Bitcoin BEP2',
#    'symbol': 'BTCB',
#    'slug': 'bitcoin-bep2',
#    'num_market_pairs': 99,
#    'date_added': '2019-06-18T00:00:00.000Z',
#    'tags': ['binance-chain', 'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 105113.59183121,
#    'total_supply': 112501,
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'BTCB-1DE'},
#    'cmc_rank': 36,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 42425.587069124624,
#      'volume_24h': 32161625.00353852,
#      'volume_change_24h': 2.7277,
#      'percent_change_1h': -0.37567231,
#      'percent_change_24h': -3.25314942,
#      'percent_change_7d': -1.18284411,
#      'percent_change_30d': -12.52168364,
#      'percent_change_60d': -35.81774787,
#      'percent_change_90d': -31.0267832,
#      'market_cap': 4459505842.383427,
#      'market_cap_dominance': 0.2199,
#      'fully_diluted_market_cap': 4772920970.86,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6210,
#    'name': 'The Sandbox',
#    'symbol': 'SAND',
#    'slug': 'the-sandbox',
#    'num_market_pairs': 177,
#    'date_added': '2020-08-05T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'content-creation',
#     'gaming',
#     'ethereum-ecosystem',
#     'binance-launchpad',
#     'metaverse',
#     'play-to-earn',
#     'animoca-brands-portfolio'],
#    'max_supply': 3000000000,
#    'circulating_supply': 920948319.2233225,
#    'total_supply': 3000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#    'cmc_rank': 37,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 4.834903141730544,
#      'volume_24h': 995916037.7571236,
#      'volume_change_24h': -10.5637,
#      'percent_change_1h': -0.2951861,
#      'percent_change_24h': -6.05732772,
#      'percent_change_7d': -5.30457899,
#      'percent_change_30d': 0.00491827,
#      'percent_change_60d': 70.98304585,
#      'percent_change_90d': 544.12097763,
#      'market_cap': 4452695921.984306,
#      'market_cap_dominance': 0.2196,
#      'fully_diluted_market_cap': 14504709425.19,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2280,
#    'name': 'Filecoin',
#    'symbol': 'FIL',
#    'slug': 'filecoin',
#    'num_market_pairs': 166,
#    'date_added': '2017-12-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'distributed-computing',
#     'filesharing',
#     'storage',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital-portfolio',
#     'pantera-capital-portfolio',
#     'web3'],
#    'max_supply': None,
#    'circulating_supply': 147799573,
#    'total_supply': 147799573,
#    'platform': None,
#    'cmc_rank': 38,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 28.63957957474591,
#      'volume_24h': 457161217.30846506,
#      'volume_change_24h': 3.1678,
#      'percent_change_1h': -0.40803432,
#      'percent_change_24h': -6.32870583,
#      'percent_change_7d': -12.7851547,
#      'percent_change_30d': -22.47047622,
#      'percent_change_60d': -54.60608117,
#      'percent_change_90d': -57.86016633,
#      'market_cap': 4232917632.046967,
#      'market_cap_dominance': 0.2087,
#      'fully_diluted_market_cap': 4232917632.05,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3945,
#    'name': 'Harmony',
#    'symbol': 'ONE',
#    'slug': 'harmony',
#    'num_market_pairs': 76,
#    'date_added': '2019-06-01T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'smart-contracts',
#     'binance-smart-chain',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'hashkey-capital-portfolio',
#     'harmony-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 11586369910.10067,
#    'total_supply': 13315002910.10068,
#    'platform': None,
#    'cmc_rank': 39,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.35336160062149546,
#      'volume_24h': 616139433.4442235,
#      'volume_change_24h': 19.5173,
#      'percent_change_1h': 0.81498859,
#      'percent_change_24h': 1.53180644,
#      'percent_change_7d': 17.22190596,
#      'percent_change_30d': 103.89172659,
#      'percent_change_60d': 27.9654194,
#      'percent_change_90d': 61.89997233,
#      'market_cap': 4094178216.8259053,
#      'market_cap_dominance': 0.2019,
#      'fully_diluted_market_cap': 4705010740.59,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'num_market_pairs': 166,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'medium-of-exchange',
#     'privacy',
#     'ringct',
#     'boostvc-portfolio',
#     'electric-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 18062446.62571494,
#    'total_supply': 18062446.62571494,
#    'platform': None,
#    'cmc_rank': 40,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 222.75830696227243,
#      'volume_24h': 394553707.21976465,
#      'volume_change_24h': 204.7036,
#      'percent_change_1h': -0.6473911,
#      'percent_change_24h': 11.40617926,
#      'percent_change_7d': 9.52406247,
#      'percent_change_30d': 17.6723373,
#      'percent_change_60d': -19.40037726,
#      'percent_change_90d': -18.31412713,
#      'market_cap': 4023560029.94067,
#      'market_cap_dominance': 0.1984,
#      'fully_diluted_market_cap': 4023560029.94,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 283,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'binance-smart-chain',
#     'dcg-portfolio'],
#    'max_supply': 210700000,
#    'circulating_supply': 132269082.19909954,
#    'total_supply': 210700000,
#    'platform': None,
#    'cmc_rank': 41,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 30.345142485868596,
#      'volume_24h': 348228859.98802197,
#      'volume_change_24h': 3.9027,
#      'percent_change_1h': -0.27108916,
#      'percent_change_24h': -2.54988769,
#      'percent_change_7d': -4.01416941,
#      'percent_change_30d': -14.80374463,
#      'percent_change_60d': -46.38271136,
#      'percent_change_90d': -44.54411538,
# ...
#    'total_supply': 37705012698.75,
#    'platform': None,
#    'cmc_rank': 86,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.09071986600122918,
#      'volume_24h': 9850518.47989556,
#      'volume_change_24h': 37.2832,
#      'percent_change_1h': 0.04071028,
#      'percent_change_24h': -0.57137243,
#      'percent_change_7d': -1.68086942,
#      'percent_change_30d': 29.62949366,
#      'percent_change_60d': -5.74432879,
#      'percent_change_90d': -19.79029063,
#      'market_cap': 1116309103.1740234,
#      'market_cap_dominance': 0.0551,
#      'fully_diluted_market_cap': 3420593699.61,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2682,
#    'name': 'Holo',
#    'symbol': 'HOT',
#    'slug': 'holo',
#    'num_market_pairs': 99,
#    'date_added': '2018-04-29T00:00:00.000Z',
#    'tags': ['platform', 'distributed-computing', 'filesharing', 'storage'],
#    'max_supply': None,
#    'circulating_supply': 173113683516.86862,
#    'total_supply': 177619433541.14133,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#    'cmc_rank': 87,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.006129023008042921,
#      'volume_24h': 77221172.6010041,
#      'volume_change_24h': -7.3809,
#      'percent_change_1h': -0.24752471,
#      'percent_change_24h': -5.90804904,
#      'percent_change_7d': -7.45808633,
#      'percent_change_30d': -23.89435979,
#      'percent_change_60d': -54.54577758,
#      'percent_change_90d': -33.3418639,
#      'market_cap': 1061017749.2819484,
#      'market_cap_dominance': 0.0523,
#      'fully_diluted_market_cap': 1088633594.85,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 873,
#    'name': 'NEM',
#    'symbol': 'XEM',
#    'slug': 'nem',
#    'num_market_pairs': 118,
#    'date_added': '2015-04-01T00:00:00.000Z',
#    'tags': ['poi',
#     'medium-of-exchange',
#     'payments',
#     'smart-contracts',
#     'fantom-ecosystem'],
#    'max_supply': 8999999999,
#    'circulating_supply': 8999999999,
#    'total_supply': 8999999999,
#    'platform': None,
#    'cmc_rank': 88,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.11492627021057997,
#      'volume_24h': 19530245.65651531,
#      'volume_change_24h': 5.1262,
#      'percent_change_1h': -0.27321088,
#      'percent_change_24h': -3.24638843,
#      'percent_change_7d': -6.2325839,
#      'percent_change_30d': -10.48409544,
#      'percent_change_60d': -40.43215145,
#      'percent_change_90d': -33.59083013,
#      'market_cap': 1034336431.7802935,
#      'market_cap_dominance': 0.051,
#      'fully_diluted_market_cap': 1034336431.78,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 8104,
#    'name': '1inch Network',
#    'symbol': '1INCH',
#    'slug': '1inch',
#    'num_market_pairs': 199,
#    'date_added': '2020-12-25T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'amm',
#     'binance-smart-chain',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'alameda-research-portfolio',
#     'parafi-capital',
#     'spartan-group'],
#    'max_supply': None,
#    'circulating_supply': 441305330.4348687,
#    'total_supply': 1500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x111111111117dc0aa78b770fa6a738034120c302'},
#    'cmc_rank': 89,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 2.340546474160036,
#      'volume_24h': 415754488.41769093,
#      'volume_change_24h': 469.4218,
#      'percent_change_1h': -1.42233307,
#      'percent_change_24h': 4.39892444,
#      'percent_change_7d': 0.30284712,
#      'percent_change_30d': -8.07279896,
#      'percent_change_60d': -45.51063394,
#      'percent_change_90d': -28.05590022,
#      'market_cap': 1032895635.1773615,
#      'market_cap_dominance': 0.0509,
#      'fully_diluted_market_cap': 3510819711.24,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2577,
#    'name': 'Ravencoin',
#    'symbol': 'RVN',
#    'slug': 'ravencoin',
#    'num_market_pairs': 91,
#    'date_added': '2018-03-10T00:00:00.000Z',
#    'tags': ['mineable', 'pow', 'platform', 'crowdfunding'],
#    'max_supply': 21000000000,
#    'circulating_supply': 10473290000,
#    'total_supply': 10473290000,
#    'platform': None,
#    'cmc_rank': 90,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.0950870692964907,
#      'volume_24h': 80919039.14817274,
#      'volume_change_24h': -24.067,
#      'percent_change_1h': -0.62176462,
#      'percent_change_24h': -6.83754757,
#      'percent_change_7d': -22.15061839,
#      'percent_change_30d': 12.41065813,
#      'percent_change_60d': -26.9536072,
#      'percent_change_90d': -12.95375899,
#      'market_cap': 995874451.9922432,
#      'market_cap_dominance': 0.0491,
#      'fully_diluted_market_cap': 1996828455.23,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2777,
#    'name': 'IoTeX',
#    'symbol': 'IOTX',
#    'slug': 'iotex',
#    'num_market_pairs': 68,
#    'date_added': '2018-05-25T00:00:00.000Z',
#    'tags': ['platform',
#     'iot',
#     'binance-smart-chain',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'iotex-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 9540779324.30788,
#    'total_supply': 9626124332.32,
#    'platform': None,
#    'cmc_rank': 91,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.1001943631520893,
#      'volume_24h': 26157183.35535938,
#      'volume_change_24h': -24.6293,
#      'percent_change_1h': -0.48458946,
#      'percent_change_24h': -5.61487983,
#      'percent_change_7d': -8.77192163,
#      'percent_change_30d': -10.99879162,
#      'percent_change_60d': -55.75372929,
#      'percent_change_90d': 45.41065429,
#      'market_cap': 955932308.3736489,
#      'market_cap_dominance': 0.0471,
#      'fully_diluted_market_cap': 1001943631.52,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3330,
#    'name': 'Pax Dollar',
#    'symbol': 'USDP',
#    'slug': 'paxos-standard',
#    'num_market_pairs': 34,
#    'date_added': '2018-09-27T00:00:00.000Z',
#    'tags': ['store-of-value',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 945642940.11,
#    'total_supply': 945642940.11,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#    'cmc_rank': 92,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.999759519500035,
#      'volume_24h': 7298785.06454039,
#      'volume_change_24h': -42.9506,
#      'percent_change_1h': -0.00724199,
#      'percent_change_24h': 0.00366916,
#      'percent_change_7d': -0.09532239,
#      'percent_change_30d': -0.03958014,
#      'percent_change_60d': -0.02111768,
#      'percent_change_90d': 0.01808586,
#      'market_cap': 945415531.422974,
#      'market_cap_dominance': 0.0466,
#      'fully_diluted_market_cap': 945415531.42,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 3822,
#    'name': 'Theta Fuel',
#    'symbol': 'TFUEL',
#    'slug': 'theta-fuel',
#    'num_market_pairs': 26,
#    'date_added': '2019-03-28T00:00:00.000Z',
#    'tags': ['media', 'content-creation', 'payments'],
#    'max_supply': None,
#    'circulating_supply': 5301214400,
#    'total_supply': 5301214400,
#    'platform': None,
#    'cmc_rank': 93,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.16912381599779372,
#      'volume_24h': 34205979.40703573,
#      'volume_change_24h': 40.5583,
#      'percent_change_1h': -0.65201495,
#      'percent_change_24h': -4.6849018,
#      'percent_change_7d': -4.45713416,
#      'percent_change_30d': -15.69439097,
#      'percent_change_60d': -49.71648587,
#      'percent_change_90d': -41.14286723,
#      'market_cap': 896561608.7504544,
#      'market_cap_dominance': 0.0442,
#      'fully_diluted_market_cap': 896561608.75,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 6758,
#    'name': 'SushiSwap',
#    'symbol': 'SUSHI',
#    'slug': 'sushiswap',
#    'num_market_pairs': 282,
#    'date_added': '2020-08-28T00:00:00.000Z',
#    'tags': ['collectibles-nfts',
#     'decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'yearn-partnerships',
#     'governance',
#     'avalanche-ecosystem',
#     'metaverse',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'harmony-ecosystem'],
#    'max_supply': 250000000,
#    'circulating_supply': 127244443,
#    'total_supply': 239449799.99188623,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b3595068778dd592e39a122f4f5a5cf09c90fe2'},
#    'cmc_rank': 94,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 7.02741784148334,
#      'volume_24h': 391078299.8722022,
#      'volume_change_24h': 21.2648,
#      'percent_change_1h': -0.40902872,
#      'percent_change_24h': -0.81052943,
#      'percent_change_7d': -4.17960321,
#      'percent_change_30d': 20.71502558,
#      'percent_change_60d': -36.84213531,
#      'percent_change_90d': -36.71654419,
#      'market_cap': 894199868.9678098,
#      'market_cap_dominance': 0.0441,
#      'fully_diluted_market_cap': 1756854460.37,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 7501,
#    'name': 'WOO Network',
#    'symbol': 'WOO',
#    'slug': 'wootrade',
#    'num_market_pairs': 79,
#    'date_added': '2020-10-23T00:00:00.000Z',
#    'tags': ['centralized-exchange',
#     'binance-smart-chain',
#     'exnetwork-capital-portfolio',
#     'polygon-ecosystem',
#     'mvb',
#     'vbc-ventures-portfolio'],
#    'max_supply': 3000000000,
#    'circulating_supply': 884078589.0001837,
#    'total_supply': 2990413143.711403,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#    'cmc_rank': 95,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.9547432536876855,
#      'volume_24h': 31274916.09095238,
#      'volume_change_24h': -3.2877,
#      'percent_change_1h': -1.30727185,
#      'percent_change_24h': -7.8411418,
#      'percent_change_7d': -6.04405781,
#      'percent_change_30d': 23.3561151,
#      'percent_change_60d': -38.92798069,
#      'percent_change_90d': -7.28121129,
#      'market_cap': 844068068.5776534,
#      'market_cap_dominance': 0.0416,
#      'fully_diluted_market_cap': 2864229761.06,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1808,
#    'name': 'OMG Network',
#    'symbol': 'OMG',
#    'slug': 'omg',
#    'num_market_pairs': 256,
#    'date_added': '2017-07-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'payments',
#     'scaling',
#     'state-channel',
#     'pantera-capital-portfolio'],
#    'max_supply': 140245399,
#    'circulating_supply': 140245398.24513277,
#    'total_supply': 140245398.24513277,
#    'platform': None,
#    'cmc_rank': 96,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 5.914466275775133,
#      'volume_24h': 551981525.5416362,
#      'volume_change_24h': 32.0811,
#      'percent_change_1h': -1.56565492,
#      'percent_change_24h': 0.48351625,
#      'percent_change_7d': 5.18515463,
#      'percent_change_30d': -1.37312707,
#      'percent_change_60d': -49.46936283,
#      'percent_change_90d': -58.06085889,
#      'market_cap': 829476678.2534909,
#      'market_cap_dominance': 0.0409,
#      'fully_diluted_market_cap': 829476682.72,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 4747,
#    'name': 'Velas',
#    'symbol': 'VLX',
#    'slug': 'velas',
#    'num_market_pairs': 46,
#    'date_added': '2019-10-03T00:00:00.000Z',
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 2248438277.883389,
#    'total_supply': 2248438277.883389,
#    'platform': None,
#    'cmc_rank': 97,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 0.3686915688490903,
#      'volume_24h': 24120276.18111217,
#      'volume_change_24h': 4.602,
#      'percent_change_1h': 0.25433908,
#      'percent_change_24h': -0.31594174,
#      'percent_change_7d': -14.96354795,
#      'percent_change_30d': 20.66326467,
#      'percent_change_60d': -6.40962111,
#      'percent_change_90d': 145.84507672,
#      'market_cap': 828980236.1331736,
#      'market_cap_dominance': 0.0409,
#      'fully_diluted_market_cap': 828980236.13,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1727,
#    'name': 'Bancor',
#    'symbol': 'BNT',
#    'slug': 'bancor',
#    'num_market_pairs': 250,
#    'date_added': '2017-06-18T00:00:00.000Z',
#    'tags': ['marketplace',
#     'decentralized-exchange',
#     'defi',
#     'payments',
#     'scaling',
#     'amm',
#     'kenetic-capital-portfolio',
#     'arbitrum-ecosytem'],
#    'max_supply': None,
#    'circulating_supply': 258480308.70921257,
#    'total_supply': 258480308.70921257,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c'},
#    'cmc_rank': 98,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 3.142925071061962,
#      'volume_24h': 24906585.05195478,
#      'volume_change_24h': -6.4209,
#      'percent_change_1h': -0.53514322,
#      'percent_change_24h': -4.04635747,
#      'percent_change_7d': -1.80776081,
#      'percent_change_30d': -2.72398285,
#      'percent_change_60d': -31.07260216,
#      'percent_change_90d': -23.83916531,
#      'market_cap': 812384242.6180198,
#      'market_cap_dominance': 0.0401,
#      'fully_diluted_market_cap': 812384242.62,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 2700,
#    'name': 'Celsius',
#    'symbol': 'CEL',
#    'slug': 'celsius',
#    'num_market_pairs': 54,
#    'date_added': '2018-05-18T00:00:00.000Z',
#    'tags': ['lending-borowing', 'exnetwork-capital-portfolio'],
#    'max_supply': 695658160,
#    'circulating_supply': 238863519.826,
#    'total_supply': 695658160,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xaaaebe6fe48e54f431b0c390cfaf0b017d09d42d'},
#    'cmc_rank': 99,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 3.3717748811107153,
#      'volume_24h': 5762877.51652774,
#      'volume_change_24h': 47.6601,
#      'percent_change_1h': -0.51813083,
#      'percent_change_24h': 2.48898,
#      'percent_change_7d': -3.41387601,
#      'percent_change_30d': -11.56064215,
#      'percent_change_60d': -29.02788706,
#      'percent_change_90d': -41.84775771,
#      'market_cap': 805394016.1629982,
#      'market_cap_dominance': 0.0397,
#      'fully_diluted_market_cap': 2345602709.73,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}},
#   {'id': 1168,
#    'name': 'Decred',
#    'symbol': 'DCR',
#    'slug': 'decred',
#    'num_market_pairs': 56,
#    'date_added': '2016-02-10T00:00:00.000Z',
#    'tags': ['mineable',
#     'hybrid-pow-pos',
#     'blake256',
#     'medium-of-exchange',
#     'store-of-value',
#     'privacy',
#     'dao',
#     'placeholder-ventures-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 13674348.15535159,
#    'total_supply': 13674348.15535159,
#    'platform': None,
#    'cmc_rank': 100,
#    'last_updated': '2022-01-14T00:26:00.000Z',
#    'quote': {'USD': {'price': 58.11658650412743,
#      'volume_24h': 3282529.29305708,
#      'volume_change_24h': 1.5871,
#      'percent_change_1h': -0.37173323,
#      'percent_change_24h': -6.65886148,
#      'percent_change_7d': -8.37118937,
#      'percent_change_30d': -8.72130027,
#      'percent_change_60d': -51.57046478,
#      'percent_change_90d': -51.97521554,
#      'market_cap': 794706437.4580461,
#      'market_cap_dominance': 0.0392,
#      'fully_diluted_market_cap': 1220448316.59,
#      'last_updated': '2022-01-14T00:26:00.000Z'}}}]}

# %%
cryptodata = data_retrieved['data']

# %%
cryptodata
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 9035,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channel',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'galaxy-digital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio'],
#   'max_supply': 21000000,
#   'circulating_supply': 18928468,
#   'total_supply': 18928468,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 42626.79624953153,
#     'volume_24h': 47438485012.929756,
#     'volume_change_24h': 30.5631,
#     'percent_change_1h': -0.14520685,
#     'percent_change_24h': -2.87714894,
#     'percent_change_7d': -0.75550566,
#     'percent_change_30d': -12.29577946,
#     'percent_change_60d': -35.42143291,
#     'percent_change_90d': -30.78929348,
#     'market_cap': 806859948751.7776,
#     'market_cap_dominance': 39.791,
#     'fully_diluted_market_cap': 895162721240.16,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 5408,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'smart-contracts',
#    'ethereum-ecosystem',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'hashkey-capital-portfolio',
#    'kenetic-capital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 119149215.0615,
#   'total_supply': 119149215.0615,
#   'platform': None,
#   'cmc_rank': 2,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 3248.279973225764,
#     'volume_24h': 15344356934.90106,
#     'volume_change_24h': -7.8008,
#     'percent_change_1h': -0.34621863,
#     'percent_change_24h': -3.73433427,
#     'percent_change_7d': -4.52623157,
#     'percent_change_30d': -16.52782971,
#     'percent_change_60d': -30.46993757,
#     'percent_change_90d': -15.82272023,
#     'market_cap': 387030009109.84,
#     'market_cap_dominance': 19.0867,
#     'fully_diluted_market_cap': 387030009109.84,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1839,
#   'name': 'BNB',
#   'symbol': 'BNB',
#   'slug': 'bnb',
#   'num_market_pairs': 620,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'payments',
#    'smart-contracts',
#    'binance-smart-chain',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio',
#    'moonriver-ecosystem'],
#   'max_supply': 166801148,
#   'circulating_supply': 166801148,
#   'total_supply': 166801148,
#   'platform': None,
#   'cmc_rank': 3,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 476.37190328721164,
#     'volume_24h': 4158155454.9011,
#     'volume_change_24h': 0.2961,
#     'percent_change_1h': -0.17177635,
#     'percent_change_24h': -2.24996642,
#     'percent_change_7d': 1.16071968,
#     'percent_change_30d': -10.36076125,
#     'percent_change_60d': -27.34234774,
#     'percent_change_90d': 0.05591968,
#     'market_cap': 79459380343.25188,
#     'market_cap_dominance': 3.9185,
#     'fully_diluted_market_cap': 79459380343.25,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 825,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'num_market_pairs': 25905,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'tags': ['payments',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'binance-smart-chain',
#    'avalanche-ecosystem',
#    'solana-ecosystem',
#    'moonriver-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 78394369307.4411,
#   'total_supply': 82008978873.83017,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#   'cmc_rank': 4,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 1.0003414199151444,
#     'volume_24h': 63519454907.42146,
#     'volume_change_24h': 1.8562,
#     'percent_change_1h': -0.00400463,
#     'percent_change_24h': 0.00648299,
#     'percent_change_7d': 0.02503164,
#     'percent_change_30d': -0.03937018,
#     'percent_change_60d': 0.01166612,
#     'percent_change_90d': 0.12022868,
#     'market_cap': 78421134706.35785,
#     'market_cap_dominance': 3.8673,
#     'fully_diluted_market_cap': 82036978372.44,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 5426,
#   'name': 'Solana',
#   'symbol': 'SOL',
#   'slug': 'solana',
#   'num_market_pairs': 230,
#   'date_added': '2020-04-10T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'solana-ecosystem',
#    'cms-holdings-portfolio',
#    'kenetic-capital-portfolio',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio',
#    'k300-ventures-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 313379591.06839514,
#   'total_supply': 511616946.142289,
#   'platform': None,
#   'cmc_rank': 5,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 146.92870891275413,
#     'volume_24h': 2195552644.256326,
#     'volume_change_24h': -2.2777,
#     'percent_change_1h': -0.11359136,
#     'percent_change_24h': -3.28385825,
#     'percent_change_7d': -1.70750349,
#     'percent_change_30d': -9.56942879,
#     'percent_change_60d': -39.02934469,
#     'percent_change_90d': -8.58367003,
#     'market_cap': 46044458715.286156,
#     'market_cap_dominance': 2.2707,
#     'fully_diluted_market_cap': 75171217354.57,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3408,
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'num_market_pairs': 2712,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'binance-smart-chain',
#    'fantom-ecosystem',
#    'moonriver-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 44990134364.3109,
#   'total_supply': 44990134364.3109,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'cmc_rank': 6,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.9993521643143158,
#     'volume_24h': 3524932103.9169087,
#     'volume_change_24h': 2.3463,
#     'percent_change_1h': 0.00101539,
#     'percent_change_24h': -0.08442648,
#     'percent_change_7d': -0.02537614,
#     'percent_change_30d': -0.06747519,
#     'percent_change_60d': 0.03354794,
#     'percent_change_90d': 0.00273095,
#     'market_cap': 44960988149.76597,
#     'market_cap_dominance': 2.2172,
#     'fully_diluted_market_cap': 44960988149.77,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'num_market_pairs': 354,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'tags': ['mineable',
#    'dpos',
#    'pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'staking',
#    'binance-smart-chain',
#    'cardano-ecosystem'],
#   'max_supply': 45000000000,
#   'circulating_supply': 33513219990.714,
#   'total_supply': 33968614580.749,
#   'platform': None,
#   'cmc_rank': 7,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 1.2371048886462936,
#     'volume_24h': 1988036726.179527,
#     'volume_change_24h': 18.3465,
#     'percent_change_1h': -0.29442449,
#     'percent_change_24h': -6.24124148,
#     'percent_change_7d': -2.92862416,
#     'percent_change_30d': -2.53173745,
#     'percent_change_60d': -39.98514192,
#     'percent_change_90d': -44.52880638,
#     'market_cap': 41459368284.790985,
#     'market_cap_dominance': 2.0446,
#     'fully_diluted_market_cap': 55669719989.08,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'num_market_pairs': 673,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'binance-chain',
#    'arrington-xrp-capital-portfolio',
#    'galaxy-digital-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio'],
#   'max_supply': 100000000000,
#   'circulating_supply': 47615126275,
#   'total_supply': 99989829709,
#   'platform': None,
#   'cmc_rank': 8,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.7697948322777478,
#     'volume_24h': 1582038995.5631213,
#     'volume_change_24h': -19.098,
#     'percent_change_1h': -0.05414415,
#     'percent_change_24h': -3.57506776,
#     'percent_change_7d': -0.87332321,
#     'percent_change_30d': -5.07917226,
#     'percent_change_60d': -35.75605659,
#     'percent_change_90d': -32.66197679,
#     'market_cap': 36653878144.747406,
#     'market_cap_dominance': 1.8076,
#     'fully_diluted_market_cap': 76979483227.77,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4172,
#   'name': 'Terra',
#   'symbol': 'LUNA',
#   'slug': 'terra-luna',
#   'num_market_pairs': 128,
#   'date_added': '2019-07-26T00:00:00.000Z',
#   'tags': ['cosmos-ecosystem',
#    'store-of-value',
#    'defi',
#    'payments',
#    'coinbase-ventures-portfolio',
#    'binance-labs-portfolio',
#    'solana-ecosystem',
#    'arrington-xrp-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kenetic-capital-portfolio',
#    'huobi-capital-portfolio',
#    'pantera-capital-portfolio',
#    'terra-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 356591830.0904593,
#   'total_supply': 828014972.214518,
#   'platform': None,
#   'cmc_rank': 9,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 78.74770886630616,
#     'volume_24h': 2467842133.3792186,
#     'volume_change_24h': -3.1039,
#     'percent_change_1h': 0.24938852,
#     'percent_change_24h': -3.54915295,
#     'percent_change_7d': 0.98726737,
#     'percent_change_30d': 29.95173627,
#     'percent_change_60d': 53.04673975,
#     'percent_change_90d': 112.71839899,
#     'market_cap': 28080789620.0668,
#     'market_cap_dominance': 1.3848,
#     'fully_diluted_market_cap': 65204281968.89,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 6636,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'slug': 'polkadot-new',
#   'num_market_pairs': 294,
#   'date_added': '2020-08-19T00:00:00.000Z',
#   'tags': ['substrate',
#    'polkadot',
#    'binance-chain',
#    'binance-smart-chain',
#    'polkadot-ecosystem',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'arrington-xrp-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'coinfund-portfolio',
#    'fabric-ventures-portfolio',
#    'fenbushi-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kenetic-capital-portfolio',
#    '1confirmation-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio',
#    'web3',
#    'spartan-group'],
#   'max_supply': None,
#   'circulating_supply': 987579314.957085,
#   'total_supply': 1103303471.382273,
#   'platform': None,
#   'cmc_rank': 10,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 25.867541858775024,
#     'volume_24h': 1401115132.6774719,
#     'volume_change_24h': -1.3844,
#     'percent_change_1h': -0.60643081,
#     'percent_change_24h': -6.04318854,
#     'percent_change_7d': -2.55300601,
#     'percent_change_30d': -1.62469404,
#     'percent_change_60d': -45.03381851,
#     'percent_change_90d': -41.13685197,
#     'market_cap': 25546249268.51276,
#     'market_cap_dominance': 1.2598,
#     'fully_diluted_market_cap': 28539748728.91,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'num_market_pairs': 442,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'memes',
#    'payments',
#    'binance-smart-chain',
#    'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 132670764299.89409,
#   'total_supply': 132670764299.89409,
#   'platform': None,
#   'cmc_rank': 11,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.17527139928031182,
#     'volume_24h': 2396862639.757897,
#     'volume_change_24h': 168.9414,
#     'percent_change_1h': 0.9287015,
#     'percent_change_24h': 8.42465797,
#     'percent_change_7d': 10.10445991,
#     'percent_change_30d': -6.27363493,
#     'percent_change_60d': -33.68618142,
#     'percent_change_90d': -27.85069644,
#     'market_cap': 23253390502.430878,
#     'market_cap_dominance': 1.1467,
#     'fully_diluted_market_cap': 23253390502.43,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 5805,
#   'name': 'Avalanche',
#   'symbol': 'AVAX',
#   'slug': 'avalanche',
#   'num_market_pairs': 156,
#   'date_added': '2020-07-13T00:00:00.000Z',
#   'tags': ['defi',
#    'smart-contracts',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'avalanche-ecosystem',
#    'cms-holdings-portfolio',
#    'dragonfly-capital-portfolio',
#    'moonriver-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 244354897.0677541,
#   'total_supply': 395891289.9134107,
#   'platform': None,
#   'cmc_rank': 12,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 89.72376718394646,
#     'volume_24h': 759176851.0687491,
#     'volume_change_24h': -21.0083,
#     'percent_change_1h': -0.41359083,
#     'percent_change_24h': -6.40060453,
#     'percent_change_7d': -5.44252368,
#     'percent_change_30d': 1.26365667,
#     'percent_change_60d': -6.6040213,
#     'percent_change_90d': 59.02330823,
#     'market_cap': 21924441894.76437,
#     'market_cap_dominance': 1.0812,
#     'fully_diluted_market_cap': 35520857926.34,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3890,
#   'name': 'Polygon',
#   'symbol': 'MATIC',
#   'slug': 'polygon',
#   'num_market_pairs': 310,
#   'date_added': '2019-04-28T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'scaling',
#    'state-channel',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'polygon-ecosystem',
#    'moonriver-ecosystem'],
#   'max_supply': 10000000000,
#   'circulating_supply': 7312892503.27,
#   'total_supply': 10000000000,
#   'platform': None,
#   'cmc_rank': 13,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 2.2646686461466525,
#     'volume_24h': 1511108875.1445932,
#     'volume_change_24h': -20.9508,
#     'percent_change_1h': -1.01234359,
#     'percent_change_24h': -6.57935758,
#     'percent_change_7d': 1.76579479,
#     'percent_change_30d': 14.68545852,
#     'percent_change_60d': 30.44124454,
#     'percent_change_90d': 47.60952954,
#     'market_cap': 16561278364.796476,
#     'market_cap_dominance': 0.8167,
#     'fully_diluted_market_cap': 22646686461.47,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 5994,
#   'name': 'Shiba Inu',
#   'symbol': 'SHIB',
#   'slug': 'shiba-inu',
#   'num_market_pairs': 294,
#   'date_added': '2020-08-01T00:00:00.000Z',
#   'tags': ['memes', 'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 549063278876301.94,
#   'total_supply': 589735030408322.8,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   'cmc_rank': 14,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 2.9654450730502256e-05,
#     'volume_24h': 1430558309.1456907,
#     'volume_change_24h': -8.9226,
#     'percent_change_1h': -0.75662944,
#     'percent_change_24h': -7.12088834,
#     'percent_change_7d': -3.67135383,
#     'percent_change_30d': -13.04367387,
#     'percent_change_60d': -43.80208329,
#     'percent_change_90d': 15.22331155,
#     'market_cap': 16282169951.365316,
#     'market_cap_dominance': 0.8029,
#     'fully_diluted_market_cap': 17488268403.29,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4687,
#   'name': 'Binance USD',
#   'symbol': 'BUSD',
#   'slug': 'binance-usd',
#   'num_market_pairs': 2690,
#   'date_added': '2019-09-20T00:00:00.000Z',
#   'tags': ['stablecoin',
#    'asset-backed-stablecoin',
#    'binance-chain',
#    'binance-smart-chain',
#    'harmony-ecosystem',
#    'moonriver-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 14248528863.969255,
#   'total_supply': 14248528863.969255,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'token_address': 'BUSD-BD1'},
#   'cmc_rank': 15,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 1.000240340199687,
#     'volume_24h': 4206980283.9682164,
#     'volume_change_24h': -1.5029,
#     'percent_change_1h': -0.04205364,
#     'percent_change_24h': -0.03365262,
#     'percent_change_7d': 0.05804525,
#     'percent_change_30d': 0.023187,
#     'percent_change_60d': 0.00186139,
#     'percent_change_90d': 0.09115075,
#     'market_cap': 14251953358.241669,
#     'market_cap_dominance': 0.7028,
#     'fully_diluted_market_cap': 14251953358.24,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 6535,
#   'name': 'NEAR Protocol',
#   'symbol': 'NEAR',
#   'slug': 'near-protocol',
#   'num_market_pairs': 87,
#   'date_added': '2020-08-11T00:00:00.000Z',
#   'tags': ['platform',
#    'staking',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'arrington-xrp-capital-portfolio',
#    'coinfund-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'kenetic-capital-portfolio',
#    'near-protocol-ecosystem',
#    'k300-ventures-portfolio'],
#   'max_supply': 1000000000,
#   'circulating_supply': 608389619,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 16,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 20.176374909686,
#     'volume_24h': 1744082123.2758503,
#     'volume_change_24h': 47.0942,
#     'percent_change_1h': 3.3841326,
#     'percent_change_24h': 16.36324071,
#     'percent_change_7d': 27.67895509,
#     'percent_change_30d': 115.40665254,
#     'percent_change_60d': 71.89305271,
#     'percent_change_90d': 154.42485409,
#     'market_cap': 12275097044.105024,
#     'market_cap_dominance': 0.6053,
#     'fully_diluted_market_cap': 20176374909.69,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'slug': 'chainlink',
#   'num_market_pairs': 568,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'tags': ['platform',
#    'defi',
#    'oracles',
#    'smart-contracts',
#    'substrate',
#    'polkadot',
#    'binance-smart-chain',
#    'polkadot-ecosystem',
#    'avalanche-ecosystem',
#    'solana-ecosystem',
#    'framework-ventures-portfolio',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'cardano-ecosystem',
#    'web3',
#    'near-protocol-ecosystem'],
#   'max_supply': 1000000000,
#   'circulating_supply': 467009550.4397637,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'cmc_rank': 17,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 25.067837953645714,
#     'volume_24h': 1556184963.534812,
#     'volume_change_24h': -21.144,
#     'percent_change_1h': 0.07347712,
#     'percent_change_24h': -5.27295472,
#     'percent_change_7d': 1.24230407,
#     'percent_change_30d': 35.21823883,
#     'percent_change_60d': -27.03512867,
#     'percent_change_90d': -8.34210891,
#     'market_cap': 11706919733.228931,
#     'market_cap_dominance': 0.5773,
#     'fully_diluted_market_cap': 25067837953.65,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3635,
#   'name': 'Crypto.com Coin',
#   'symbol': 'CRO',
#   'slug': 'crypto-com-coin',
#   'num_market_pairs': 123,
#   'date_added': '2018-12-14T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'cosmos-ecosystem',
#    'centralized-exchange',
#    'mobile',
#    'payments'],
#   'max_supply': 30263013692,
#   'circulating_supply': 25263013692,
#   'total_supply': 30263013692,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   'cmc_rank': 18,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.4564769912754534,
#     'volume_24h': 151174465.9211202,
#     'volume_change_24h': -15.2413,
#     'percent_change_1h': -0.4344321,
#     'percent_change_24h': -6.18902706,
#     'percent_change_7d': -8.60155648,
#     'percent_change_30d': -16.66177514,
#     'percent_change_60d': 0.45305521,
#     'percent_change_90d': 139.5112659,
#     'market_cap': 11531984480.674744,
#     'market_cap_dominance': 0.5687,
#     'fully_diluted_market_cap': 13814369437.05,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3717,
#   'name': 'Wrapped Bitcoin',
#   'symbol': 'WBTC',
#   'slug': 'wrapped-bitcoin',
#   'num_market_pairs': 314,
#   'date_added': '2019-01-30T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'defi',
#    'wrapped-tokens',
#    'fantom-ecosystem',
#    'moonriver-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 266880.73402772,
#   'total_supply': 266880.73402772,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   'cmc_rank': 19,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 42652.47937423112,
#     'volume_24h': 190388057.94342092,
#     'volume_change_24h': -5.0516,
#     'percent_change_1h': -0.1343726,
#     'percent_change_24h': -2.75664734,
#     'percent_change_7d': -0.70227153,
#     'percent_change_30d': -11.12724491,
#     'percent_change_60d': -34.46022929,
#     'percent_change_90d': -30.67345012,
#     'market_cap': 11383125003.49699,
#     'market_cap_dominance': 0.5614,
#     'fully_diluted_market_cap': 11383125003.5,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 7129,
#   'name': 'TerraUSD',
#   'symbol': 'UST',
#   'slug': 'terrausd',
#   'num_market_pairs': 246,
#   'date_added': '2020-09-21T00:00:00.000Z',
#   'tags': ['stablecoin', 'binance-smart-chain', 'terra-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 10592707055.583405,
#   'total_supply': 10592707055.583405,
#   'platform': None,
#   'cmc_rank': 20,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 1.0010663970177425,
#     'volume_24h': 219239584.5546335,
#     'volume_change_24h': -1.5318,
#     'percent_change_1h': 0.21736712,
#     'percent_change_24h': 0.34587711,
#     'percent_change_7d': 0.20565136,
#     'percent_change_30d': -0.02088591,
#     'percent_change_60d': -0.59066041,
#     'percent_change_90d': -0.00921431,
#     'market_cap': 10604003086.797298,
#     'market_cap_dominance': 0.5229,
#     'fully_diluted_market_cap': 10604003086.8,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 7083,
#   'name': 'Uniswap',
#   'symbol': 'UNI',
#   'slug': 'uniswap',
#   'num_market_pairs': 326,
#   'date_added': '2020-09-17T00:00:00.000Z',
#   'tags': ['decentralized-exchange',
#    'defi',
#    'dao',
#    'yield-farming',
#    'amm',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'governance',
#    'blockchain-capital-portfolio',
#    'defiance-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio',
#    'parafi-capital',
#    'paradigm-portfolio',
#    'arbitrum-ecosytem'],
#   'max_supply': 1000000000,
#   'circulating_supply': 627292763.9836428,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   'cmc_rank': 21,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 15.499867875419488,
#     'volume_24h': 236773012.54270607,
#     'volume_change_24h': 8.7191,
#     'percent_change_1h': -0.31232355,
#     'percent_change_24h': -4.56890854,
#     'percent_change_7d': -8.62395738,
#     'percent_change_30d': 2.90753334,
#     'percent_change_60d': -37.52380518,
#     'percent_change_90d': -40.4269377,
#     'market_cap': 9722954960.953165,
#     'market_cap_dominance': 0.4795,
#     'fully_diluted_market_cap': 15499867875.42,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'slug': 'litecoin',
#   'num_market_pairs': 724,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': 84000000,
#   'circulating_supply': 69407894.4948378,
#   'total_supply': 84000000,
#   'platform': None,
#   'cmc_rank': 22,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 137.10229187663754,
#     'volume_24h': 892800738.0694944,
#     'volume_change_24h': 1.2144,
#     'percent_change_1h': 0.00598389,
#     'percent_change_24h': -2.92080819,
#     'percent_change_7d': 0.74515289,
#     'percent_change_30d': -9.42521307,
#     'percent_change_60d': -50.32960174,
#     'percent_change_90d': -28.04193346,
#     'market_cap': 9515981409.574116,
#     'market_cap_dominance': 0.4693,
#     'fully_diluted_market_cap': 11516592517.64,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4943,
#   'name': 'Dai',
#   'symbol': 'DAI',
#   'slug': 'multi-collateral-dai',
#   'num_market_pairs': 700,
#   'date_added': '2019-11-22T00:00:00.000Z',
#   'tags': ['defi',
#    'stablecoin',
#    'ethereum-ecosystem',
#    'binance-smart-chain',
#    'avalanche-ecosystem',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'harmony-ecosystem',
#    'moonriver-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 9475025853.622076,
#   'total_supply': 9475025853.622076,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#   'cmc_rank': 23,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.9990888045409372,
#     'volume_24h': 461322483.1333583,
#     'volume_change_24h': 17.2858,
#     'percent_change_1h': -0.05449006,
#     'percent_change_24h': -0.16129342,
#     'percent_change_7d': -0.00959075,
#     'percent_change_30d': -0.3009631,
#     'percent_change_60d': -0.30417158,
#     'percent_change_90d': -0.07916133,
#     'market_cap': 9466392253.089752,
#     'market_cap_dominance': 0.4668,
#     'fully_diluted_market_cap': 9466392253.09,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4030,
#   'name': 'Algorand',
#   'symbol': 'ALGO',
#   'slug': 'algorand',
#   'num_market_pairs': 172,
#   'date_added': '2019-06-20T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'arrington-xrp-capital-portfolio',
#    'kenetic-capital-portfolio',
#    'usv-portfolio',
#    'multicoin-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 10000000000,
#   'circulating_supply': 6464479852.867192,
#   'total_supply': 6908302131.039248,
#   'platform': None,
#   'cmc_rank': 24,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 1.3615032872514103,
#     'volume_24h': 557578525.2308326,
#     'volume_change_24h': 24.7772,
#     'percent_change_1h': -0.1461109,
#     'percent_change_24h': -8.45725173,
#     'percent_change_7d': -11.64065286,
#     'percent_change_30d': -1.57383217,
#     'percent_change_60d': -31.91782835,
#     'percent_change_90d': -22.72272762,
#     'market_cap': 8801410570.049196,
#     'market_cap_dominance': 0.434,
#     'fully_diluted_market_cap': 13615032872.51,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'slug': 'cosmos',
#   'num_market_pairs': 221,
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'tags': ['platform',
#    'cosmos-ecosystem',
#    'content-creation',
#    'interoperability',
#    'binance-chain',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'dragonfly-capital-portfolio',
#    'hashkey-capital-portfolio',
#    '1confirmation-portfolio',
#    'paradigm-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 226226027.647699,
#   'total_supply': 284010630.647699,
#   'platform': None,
#   'cmc_rank': 25,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 37.41934119527285,
#     'volume_24h': 1768594256.8875446,
#     'volume_change_24h': -19.2611,
#     'percent_change_1h': -2.66724368,
#     'percent_change_24h': -7.86337603,
#     'percent_change_7d': -6.04810524,
#     'percent_change_30d': 69.76560532,
#     'percent_change_60d': 14.3550647,
#     'percent_change_90d': 12.00470625,
#     'market_cap': 8465228915.800478,
#     'market_cap_dominance': 0.4175,
#     'fully_diluted_market_cap': 10627490691.29,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3513,
#   'name': 'Fantom',
#   'symbol': 'FTM',
#   'slug': 'fantom',
#   'num_market_pairs': 207,
#   'date_added': '2018-10-29T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'defi',
#    'research',
#    'scaling',
#    'smart-contracts',
#    'binance-smart-chain',
#    'fantom-ecosystem'],
#   'max_supply': 3175000000,
#   'circulating_supply': 2545006273,
#   'total_supply': 2545006273,
#   'platform': None,
#   'cmc_rank': 26,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 2.9836316748756886,
#     'volume_24h': 3033215058.8580527,
#     'volume_change_24h': 25.1027,
#     'percent_change_1h': -1.87328465,
#     'percent_change_24h': 2.72179608,
#     'percent_change_7d': 5.49028591,
#     'percent_change_30d': 126.1431418,
#     'percent_change_60d': 14.33352873,
#     'percent_change_90d': 53.52481073,
#     'market_cap': 7593361328.880124,
#     'market_cap_dominance': 0.3745,
#     'fully_diluted_market_cap': 9473030567.73,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'slug': 'bitcoin-cash',
#   'num_market_pairs': 564,
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'marketplace',
#    'medium-of-exchange',
#    'store-of-value',
#    'enterprise-solutions',
#    'payments',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': 21000000,
#   'circulating_supply': 18954656.25,
#   'total_supply': 18954656.25,
#   'platform': None,
#   'cmc_rank': 27,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 378.0950444134853,
#     'volume_24h': 4809956365.002938,
#     'volume_change_24h': -0.984,
#     'percent_change_1h': -0.16600079,
#     'percent_change_24h': -1.56764284,
#     'percent_change_7d': -5.52125426,
#     'percent_change_30d': -13.65829527,
#     'percent_change_60d': -44.69368796,
#     'percent_change_90d': -40.14023694,
#     'market_cap': 7166661596.686097,
#     'market_cap_dominance': 0.3534,
#     'fully_diluted_market_cap': 7939995932.68,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'slug': 'tron',
#   'num_market_pairs': 558,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'tags': ['media', 'payments', 'tron-ecosystem', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 101833925429.87419,
#   'total_supply': 101833916884.59915,
#   'platform': None,
#   'cmc_rank': 28,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.06629577308213107,
#     'volume_24h': 1084047494.1086102,
#     'volume_change_24h': 36.3326,
#     'percent_change_1h': -0.36395166,
#     'percent_change_24h': -2.86836823,
#     'percent_change_7d': -6.57007903,
#     'percent_change_30d': -24.12818561,
#     'percent_change_60d': -43.51640773,
#     'percent_change_90d': -33.21534948,
#     'market_cap': 6751158812.361596,
#     'market_cap_dominance': 0.3329,
#     'fully_diluted_market_cap': 6751158245.85,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'slug': 'stellar',
#   'num_market_pairs': 395,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'decentralized-exchange',
#    'smart-contracts',
#    'hashkey-capital-portfolio'],
#   'max_supply': 50001806812,
#   'circulating_supply': 24775907928.27119,
#   'total_supply': 50001802340.071266,
#   'platform': None,
#   'cmc_rank': 29,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.2692606822219346,
#     'volume_24h': 474355454.65212154,
#     'volume_change_24h': -19.6089,
#     'percent_change_1h': -0.89733477,
#     'percent_change_24h': -5.76007976,
#     'percent_change_7d': 1.18075933,
#     'percent_change_30d': 0.40668659,
#     'percent_change_60d': -29.52513231,
#     'percent_change_90d': -26.38513486,
#     'market_cap': 6671177871.434139,
#     'market_cap_dominance': 0.329,
#     'fully_diluted_market_cap': 13463520614.53,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 8916,
#   'name': 'Internet Computer',
#   'symbol': 'ICP',
#   'slug': 'internet-computer',
#   'num_market_pairs': 93,
#   'date_added': '2021-03-23T00:00:00.000Z',
#   'tags': ['platform',
#    'distributed-computing',
#    'polychain-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 198389896.57,
#   'total_supply': 476220780.90761125,
#   'platform': None,
#   'cmc_rank': 30,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 31.692705481085955,
#     'volume_24h': 440146223.30864817,
#     'volume_change_24h': -22.3988,
#     'percent_change_1h': 0.3293114,
#     'percent_change_24h': -8.60376456,
#     'percent_change_7d': 5.69805616,
#     'percent_change_30d': 22.97414077,
#     'percent_change_60d': -34.76138566,
#     'percent_change_90d': -27.76351215,
#     'market_cap': 6287512562.416115,
#     'market_cap_dominance': 0.3101,
#     'fully_diluted_market_cap': 15092724953.28,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4195,
#   'name': 'FTX Token',
#   'symbol': 'FTT',
#   'slug': 'ftx-token',
#   'num_market_pairs': 107,
#   'date_added': '2019-07-31T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'derivatives',
#    'cms-holdings-portfolio',
#    'kenetic-capital-portfolio',
#    'alameda-research-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 352170015,
#   'circulating_supply': 138569137.91874373,
#   'total_supply': 334438473.9859715,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'token_address': 'FTT-F11'},
#   'cmc_rank': 31,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 41.00476704653611,
#     'volume_24h': 159127182.132871,
#     'volume_change_24h': 3.4746,
#     'percent_change_1h': -0.22198138,
#     'percent_change_24h': -1.08980335,
#     'percent_change_7d': 6.8832193,
#     'percent_change_30d': 5.0613853,
#     'percent_change_60d': -27.2272373,
#     'percent_change_90d': -28.1549329,
#     'market_cap': 5681995220.19742,
#     'market_cap_dominance': 0.2802,
#     'fully_diluted_market_cap': 14440649425.85,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1966,
#   'name': 'Decentraland',
#   'symbol': 'MANA',
#   'slug': 'decentraland',
#   'num_market_pairs': 225,
#   'date_added': '2017-09-17T00:00:00.000Z',
#   'tags': ['platform',
#    'collectibles-nfts',
#    'gaming',
#    'payments',
#    'metaverse',
#    'boostvc-portfolio',
#    'dcg-portfolio',
#    'fabric-ventures-portfolio',
#    'kenetic-capital-portfolio',
#    'polygon-ecosystem',
#    'play-to-earn'],
#   'max_supply': None,
#   'circulating_supply': 1824524634.8740842,
#   'total_supply': 2193889627.320146,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#   'cmc_rank': 32,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 2.9031761438094676,
#     'volume_24h': 505198499.145862,
#     'volume_change_24h': -11.5523,
#     'percent_change_1h': -0.36082623,
#     'percent_change_24h': -5.84803803,
#     'percent_change_7d': -12.12744733,
#     'percent_change_30d': -9.40953515,
#     'percent_change_60d': -9.10719793,
#     'percent_change_90d': 280.39784133,
#     'market_cap': 5296916393.759121,
#     'market_cap_dominance': 0.2612,
#     'fully_diluted_market_cap': 6369248028.19,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4642,
#   'name': 'Hedera',
#   'symbol': 'HBAR',
#   'slug': 'hedera',
#   'num_market_pairs': 81,
#   'date_added': '2019-09-17T00:00:00.000Z',
#   'tags': ['dag',
#    'marketplace',
#    'enterprise-solutions',
#    'payments',
#    'dcg-portfolio'],
#   'max_supply': 50000000000,
#   'circulating_supply': 18092792421.137627,
#   'total_supply': 50000000000,
#   'platform': None,
#   'cmc_rank': 33,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.27883140164465203,
#     'volume_24h': 108099113.10629706,
#     'volume_change_24h': -5.5235,
#     'percent_change_1h': -0.37445472,
#     'percent_change_24h': -5.40360737,
#     'percent_change_7d': -4.11037052,
#     'percent_change_30d': 18.76081761,
#     'percent_change_60d': -36.02922834,
#     'percent_change_90d': -24.05373188,
#     'market_cap': 5044838670.451542,
#     'market_cap_dominance': 0.2488,
#     'fully_diluted_market_cap': 13941570082.23,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3077,
#   'name': 'VeChain',
#   'symbol': 'VET',
#   'slug': 'vechain',
#   'num_market_pairs': 161,
#   'date_added': '2017-08-22T00:00:00.000Z',
#   'tags': ['logistics',
#    'data-provenance',
#    'iot',
#    'smart-contracts',
#    'fenbushi-capital-portfolio'],
#   'max_supply': 86712634466,
#   'circulating_supply': 64315576989,
#   'total_supply': 86712634466,
#   'platform': None,
#   'cmc_rank': 34,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.07778174933213128,
#     'volume_24h': 314144146.65775836,
#     'volume_change_24h': 10.2758,
#     'percent_change_1h': -0.95305222,
#     'percent_change_24h': -5.4449934,
#     'percent_change_7d': -4.78103034,
#     'percent_change_30d': -2.92855185,
#     'percent_change_60d': -52.81780108,
#     'percent_change_90d': -35.42433201,
#     'market_cap': 5002578087.5097885,
#     'market_cap_dominance': 0.2467,
#     'fully_diluted_market_cap': 6744660397.96,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 6783,
#   'name': 'Axie Infinity',
#   'symbol': 'AXS',
#   'slug': 'axie-infinity',
#   'num_market_pairs': 177,
#   'date_added': '2020-08-31T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'gaming',
#    'binance-launchpad',
#    'metaverse',
#    'defiance-capital-portfolio',
#    'play-to-earn',
#    'animoca-brands-portfolio'],
#   'max_supply': 270000000,
#   'circulating_supply': 60907500,
#   'total_supply': 270000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#   'cmc_rank': 35,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 73.24785201222336,
#     'volume_24h': 225329534.8504949,
#     'volume_change_24h': -16.9985,
#     'percent_change_1h': -0.47796824,
#     'percent_change_24h': -6.42251808,
#     'percent_change_7d': -6.12749991,
#     'percent_change_30d': -24.30925309,
#     'percent_change_60d': -49.09464808,
#     'percent_change_90d': -42.51545913,
#     'market_cap': 4461343546.434494,
#     'market_cap_dominance': 0.22,
#     'fully_diluted_market_cap': 19776920043.3,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4023,
#   'name': 'Bitcoin BEP2',
#   'symbol': 'BTCB',
#   'slug': 'bitcoin-bep2',
#   'num_market_pairs': 99,
#   'date_added': '2019-06-18T00:00:00.000Z',
#   'tags': ['binance-chain', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 105113.59183121,
#   'total_supply': 112501,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'token_address': 'BTCB-1DE'},
#   'cmc_rank': 36,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 42425.587069124624,
#     'volume_24h': 32161625.00353852,
#     'volume_change_24h': 2.7277,
#     'percent_change_1h': -0.37567231,
#     'percent_change_24h': -3.25314942,
#     'percent_change_7d': -1.18284411,
#     'percent_change_30d': -12.52168364,
#     'percent_change_60d': -35.81774787,
#     'percent_change_90d': -31.0267832,
#     'market_cap': 4459505842.383427,
#     'market_cap_dominance': 0.2199,
#     'fully_diluted_market_cap': 4772920970.86,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 6210,
#   'name': 'The Sandbox',
#   'symbol': 'SAND',
#   'slug': 'the-sandbox',
#   'num_market_pairs': 177,
#   'date_added': '2020-08-05T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'content-creation',
#    'gaming',
#    'ethereum-ecosystem',
#    'binance-launchpad',
#    'metaverse',
#    'play-to-earn',
#    'animoca-brands-portfolio'],
#   'max_supply': 3000000000,
#   'circulating_supply': 920948319.2233225,
#   'total_supply': 3000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   'cmc_rank': 37,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 4.834903141730544,
#     'volume_24h': 995916037.7571236,
#     'volume_change_24h': -10.5637,
#     'percent_change_1h': -0.2951861,
#     'percent_change_24h': -6.05732772,
#     'percent_change_7d': -5.30457899,
#     'percent_change_30d': 0.00491827,
#     'percent_change_60d': 70.98304585,
#     'percent_change_90d': 544.12097763,
#     'market_cap': 4452695921.984306,
#     'market_cap_dominance': 0.2196,
#     'fully_diluted_market_cap': 14504709425.19,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2280,
#   'name': 'Filecoin',
#   'symbol': 'FIL',
#   'slug': 'filecoin',
#   'num_market_pairs': 166,
#   'date_added': '2017-12-13T00:00:00.000Z',
#   'tags': ['mineable',
#    'distributed-computing',
#    'filesharing',
#    'storage',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'dcg-portfolio',
#    'hashkey-capital-portfolio',
#    'a16z-portfolio',
#    'winklevoss-capital-portfolio',
#    'pantera-capital-portfolio',
#    'web3'],
#   'max_supply': None,
#   'circulating_supply': 147799573,
#   'total_supply': 147799573,
#   'platform': None,
#   'cmc_rank': 38,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 28.63957957474591,
#     'volume_24h': 457161217.30846506,
#     'volume_change_24h': 3.1678,
#     'percent_change_1h': -0.40803432,
#     'percent_change_24h': -6.32870583,
#     'percent_change_7d': -12.7851547,
#     'percent_change_30d': -22.47047622,
#     'percent_change_60d': -54.60608117,
#     'percent_change_90d': -57.86016633,
#     'market_cap': 4232917632.046967,
#     'market_cap_dominance': 0.2087,
#     'fully_diluted_market_cap': 4232917632.05,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3945,
#   'name': 'Harmony',
#   'symbol': 'ONE',
#   'slug': 'harmony',
#   'num_market_pairs': 76,
#   'date_added': '2019-06-01T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'scaling',
#    'smart-contracts',
#    'binance-smart-chain',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'hashkey-capital-portfolio',
#    'harmony-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 11586369910.10067,
#   'total_supply': 13315002910.10068,
#   'platform': None,
#   'cmc_rank': 39,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.35336160062149546,
#     'volume_24h': 616139433.4442235,
#     'volume_change_24h': 19.5173,
#     'percent_change_1h': 0.81498859,
#     'percent_change_24h': 1.53180644,
#     'percent_change_7d': 17.22190596,
#     'percent_change_30d': 103.89172659,
#     'percent_change_60d': 27.9654194,
#     'percent_change_90d': 61.89997233,
#     'market_cap': 4094178216.8259053,
#     'market_cap_dominance': 0.2019,
#     'fully_diluted_market_cap': 4705010740.59,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 328,
#   'name': 'Monero',
#   'symbol': 'XMR',
#   'slug': 'monero',
#   'num_market_pairs': 166,
#   'date_added': '2014-05-21T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'medium-of-exchange',
#    'privacy',
#    'ringct',
#    'boostvc-portfolio',
#    'electric-capital-portfolio',
#    'galaxy-digital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 18062446.62571494,
#   'total_supply': 18062446.62571494,
#   'platform': None,
#   'cmc_rank': 40,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 222.75830696227243,
#     'volume_24h': 394553707.21976465,
#     'volume_change_24h': 204.7036,
#     'percent_change_1h': -0.6473911,
#     'percent_change_24h': 11.40617926,
#     'percent_change_7d': 9.52406247,
#     'percent_change_30d': 17.6723373,
#     'percent_change_60d': -19.40037726,
#     'percent_change_90d': -18.31412713,
#     'market_cap': 4023560029.94067,
#     'market_cap_dominance': 0.1984,
#     'fully_diluted_market_cap': 4023560029.94,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'slug': 'ethereum-classic',
#   'num_market_pairs': 283,
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'ethash',
#    'platform',
#    'smart-contracts',
#    'binance-smart-chain',
#    'dcg-portfolio'],
#   'max_supply': 210700000,
#   'circulating_supply': 132269082.19909954,
#   'total_supply': 210700000,
#   'platform': None,
#   'cmc_rank': 41,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 30.345142485868596,
#     'volume_24h': 348228859.98802197,
#     'volume_change_24h': 3.9027,
#     'percent_change_1h': -0.27108916,
#     'percent_change_24h': -2.54988769,
#     'percent_change_7d': -4.01416941,
#     'percent_change_30d': -14.80374463,
#     'percent_change_60d': -46.38271136,
#     'percent_change_90d': -44.54411538,
#     'market_cap': 4013724145.806741,
#     'market_cap_dominance': 0.1979,
#     'fully_diluted_market_cap': 6393721521.77,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2416,
#   'name': 'Theta Network',
#   'symbol': 'THETA',
#   'slug': 'theta-network',
#   'num_market_pairs': 94,
#   'date_added': '2018-01-17T00:00:00.000Z',
#   'tags': ['media',
#    'collectibles-nfts',
#    'content-creation',
#    'video',
#    'metaverse',
#    'huobi-capital-portfolio',
#    'web3'],
#   'max_supply': 1000000000,
#   'circulating_supply': 1000000000,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 42,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 3.9864808958044153,
#     'volume_24h': 204913708.52272874,
#     'volume_change_24h': 15.4868,
#     'percent_change_1h': -0.59969277,
#     'percent_change_24h': -6.90246743,
#     'percent_change_7d': -8.42001153,
#     'percent_change_30d': -1.99407686,
#     'percent_change_60d': -43.84194979,
#     'percent_change_90d': -36.67825078,
#     'market_cap': 3986480895.804415,
#     'market_cap_dominance': 0.1966,
#     'fully_diluted_market_cap': 3986480895.8,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 6892,
#   'name': 'Elrond',
#   'symbol': 'EGLD',
#   'slug': 'elrond-egld',
#   'num_market_pairs': 70,
#   'date_added': '2020-09-04T00:00:00.000Z',
#   'tags': ['binance-smart-chain',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'electric-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 31415926,
#   'circulating_supply': 20014152.95643073,
#   'total_supply': 23016298,
#   'platform': None,
#   'cmc_rank': 43,
#   'last_updated': '2022-01-14T00:26:00.000Z',
# ...
#     'percent_change_60d': -3.49930466,
#     'percent_change_90d': 58.81092666,
#     'market_cap': 1139225202.6040063,
#     'market_cap_dominance': 0.0562,
#     'fully_diluted_market_cap': 1446048625.55,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2634,
#   'name': 'XDC Network',
#   'symbol': 'XDC',
#   'slug': 'xinfin',
#   'num_market_pairs': 50,
#   'date_added': '2018-04-12T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 12305012698.75,
#   'total_supply': 37705012698.75,
#   'platform': None,
#   'cmc_rank': 86,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.09071986600122918,
#     'volume_24h': 9850518.47989556,
#     'volume_change_24h': 37.2832,
#     'percent_change_1h': 0.04071028,
#     'percent_change_24h': -0.57137243,
#     'percent_change_7d': -1.68086942,
#     'percent_change_30d': 29.62949366,
#     'percent_change_60d': -5.74432879,
#     'percent_change_90d': -19.79029063,
#     'market_cap': 1116309103.1740234,
#     'market_cap_dominance': 0.0551,
#     'fully_diluted_market_cap': 3420593699.61,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2682,
#   'name': 'Holo',
#   'symbol': 'HOT',
#   'slug': 'holo',
#   'num_market_pairs': 99,
#   'date_added': '2018-04-29T00:00:00.000Z',
#   'tags': ['platform', 'distributed-computing', 'filesharing', 'storage'],
#   'max_supply': None,
#   'circulating_supply': 173113683516.86862,
#   'total_supply': 177619433541.14133,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#   'cmc_rank': 87,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.006129023008042921,
#     'volume_24h': 77221172.6010041,
#     'volume_change_24h': -7.3809,
#     'percent_change_1h': -0.24752471,
#     'percent_change_24h': -5.90804904,
#     'percent_change_7d': -7.45808633,
#     'percent_change_30d': -23.89435979,
#     'percent_change_60d': -54.54577758,
#     'percent_change_90d': -33.3418639,
#     'market_cap': 1061017749.2819484,
#     'market_cap_dominance': 0.0523,
#     'fully_diluted_market_cap': 1088633594.85,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 873,
#   'name': 'NEM',
#   'symbol': 'XEM',
#   'slug': 'nem',
#   'num_market_pairs': 118,
#   'date_added': '2015-04-01T00:00:00.000Z',
#   'tags': ['poi',
#    'medium-of-exchange',
#    'payments',
#    'smart-contracts',
#    'fantom-ecosystem'],
#   'max_supply': 8999999999,
#   'circulating_supply': 8999999999,
#   'total_supply': 8999999999,
#   'platform': None,
#   'cmc_rank': 88,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.11492627021057997,
#     'volume_24h': 19530245.65651531,
#     'volume_change_24h': 5.1262,
#     'percent_change_1h': -0.27321088,
#     'percent_change_24h': -3.24638843,
#     'percent_change_7d': -6.2325839,
#     'percent_change_30d': -10.48409544,
#     'percent_change_60d': -40.43215145,
#     'percent_change_90d': -33.59083013,
#     'market_cap': 1034336431.7802935,
#     'market_cap_dominance': 0.051,
#     'fully_diluted_market_cap': 1034336431.78,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 8104,
#   'name': '1inch Network',
#   'symbol': '1INCH',
#   'slug': '1inch',
#   'num_market_pairs': 199,
#   'date_added': '2020-12-25T00:00:00.000Z',
#   'tags': ['decentralized-exchange',
#    'defi',
#    'amm',
#    'binance-smart-chain',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'dragonfly-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'alameda-research-portfolio',
#    'parafi-capital',
#    'spartan-group'],
#   'max_supply': None,
#   'circulating_supply': 441305330.4348687,
#   'total_supply': 1500000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x111111111117dc0aa78b770fa6a738034120c302'},
#   'cmc_rank': 89,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 2.340546474160036,
#     'volume_24h': 415754488.41769093,
#     'volume_change_24h': 469.4218,
#     'percent_change_1h': -1.42233307,
#     'percent_change_24h': 4.39892444,
#     'percent_change_7d': 0.30284712,
#     'percent_change_30d': -8.07279896,
#     'percent_change_60d': -45.51063394,
#     'percent_change_90d': -28.05590022,
#     'market_cap': 1032895635.1773615,
#     'market_cap_dominance': 0.0509,
#     'fully_diluted_market_cap': 3510819711.24,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2577,
#   'name': 'Ravencoin',
#   'symbol': 'RVN',
#   'slug': 'ravencoin',
#   'num_market_pairs': 91,
#   'date_added': '2018-03-10T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'platform', 'crowdfunding'],
#   'max_supply': 21000000000,
#   'circulating_supply': 10473290000,
#   'total_supply': 10473290000,
#   'platform': None,
#   'cmc_rank': 90,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.0950870692964907,
#     'volume_24h': 80919039.14817274,
#     'volume_change_24h': -24.067,
#     'percent_change_1h': -0.62176462,
#     'percent_change_24h': -6.83754757,
#     'percent_change_7d': -22.15061839,
#     'percent_change_30d': 12.41065813,
#     'percent_change_60d': -26.9536072,
#     'percent_change_90d': -12.95375899,
#     'market_cap': 995874451.9922432,
#     'market_cap_dominance': 0.0491,
#     'fully_diluted_market_cap': 1996828455.23,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2777,
#   'name': 'IoTeX',
#   'symbol': 'IOTX',
#   'slug': 'iotex',
#   'num_market_pairs': 68,
#   'date_added': '2018-05-25T00:00:00.000Z',
#   'tags': ['platform',
#    'iot',
#    'binance-smart-chain',
#    'hashkey-capital-portfolio',
#    'kenetic-capital-portfolio',
#    'iotex-ecosystem'],
#   'max_supply': 10000000000,
#   'circulating_supply': 9540779324.30788,
#   'total_supply': 9626124332.32,
#   'platform': None,
#   'cmc_rank': 91,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.1001943631520893,
#     'volume_24h': 26157183.35535938,
#     'volume_change_24h': -24.6293,
#     'percent_change_1h': -0.48458946,
#     'percent_change_24h': -5.61487983,
#     'percent_change_7d': -8.77192163,
#     'percent_change_30d': -10.99879162,
#     'percent_change_60d': -55.75372929,
#     'percent_change_90d': 45.41065429,
#     'market_cap': 955932308.3736489,
#     'market_cap_dominance': 0.0471,
#     'fully_diluted_market_cap': 1001943631.52,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3330,
#   'name': 'Pax Dollar',
#   'symbol': 'USDP',
#   'slug': 'paxos-standard',
#   'num_market_pairs': 34,
#   'date_added': '2018-09-27T00:00:00.000Z',
#   'tags': ['store-of-value',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 945642940.11,
#   'total_supply': 945642940.11,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x8e870d67f660d95d5be530380d0ec0bd388289e1'},
#   'cmc_rank': 92,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.999759519500035,
#     'volume_24h': 7298785.06454039,
#     'volume_change_24h': -42.9506,
#     'percent_change_1h': -0.00724199,
#     'percent_change_24h': 0.00366916,
#     'percent_change_7d': -0.09532239,
#     'percent_change_30d': -0.03958014,
#     'percent_change_60d': -0.02111768,
#     'percent_change_90d': 0.01808586,
#     'market_cap': 945415531.422974,
#     'market_cap_dominance': 0.0466,
#     'fully_diluted_market_cap': 945415531.42,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 3822,
#   'name': 'Theta Fuel',
#   'symbol': 'TFUEL',
#   'slug': 'theta-fuel',
#   'num_market_pairs': 26,
#   'date_added': '2019-03-28T00:00:00.000Z',
#   'tags': ['media', 'content-creation', 'payments'],
#   'max_supply': None,
#   'circulating_supply': 5301214400,
#   'total_supply': 5301214400,
#   'platform': None,
#   'cmc_rank': 93,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.16912381599779372,
#     'volume_24h': 34205979.40703573,
#     'volume_change_24h': 40.5583,
#     'percent_change_1h': -0.65201495,
#     'percent_change_24h': -4.6849018,
#     'percent_change_7d': -4.45713416,
#     'percent_change_30d': -15.69439097,
#     'percent_change_60d': -49.71648587,
#     'percent_change_90d': -41.14286723,
#     'market_cap': 896561608.7504544,
#     'market_cap_dominance': 0.0442,
#     'fully_diluted_market_cap': 896561608.75,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 6758,
#   'name': 'SushiSwap',
#   'symbol': 'SUSHI',
#   'slug': 'sushiswap',
#   'num_market_pairs': 282,
#   'date_added': '2020-08-28T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'decentralized-exchange',
#    'defi',
#    'dao',
#    'yield-farming',
#    'amm',
#    'binance-smart-chain',
#    'yearn-partnerships',
#    'governance',
#    'avalanche-ecosystem',
#    'metaverse',
#    'blockchain-capital-portfolio',
#    'defiance-capital-portfolio',
#    'alameda-research-portfolio',
#    'pantera-capital-portfolio',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'harmony-ecosystem'],
#   'max_supply': 250000000,
#   'circulating_supply': 127244443,
#   'total_supply': 239449799.99188623,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6b3595068778dd592e39a122f4f5a5cf09c90fe2'},
#   'cmc_rank': 94,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 7.02741784148334,
#     'volume_24h': 391078299.8722022,
#     'volume_change_24h': 21.2648,
#     'percent_change_1h': -0.40902872,
#     'percent_change_24h': -0.81052943,
#     'percent_change_7d': -4.17960321,
#     'percent_change_30d': 20.71502558,
#     'percent_change_60d': -36.84213531,
#     'percent_change_90d': -36.71654419,
#     'market_cap': 894199868.9678098,
#     'market_cap_dominance': 0.0441,
#     'fully_diluted_market_cap': 1756854460.37,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 7501,
#   'name': 'WOO Network',
#   'symbol': 'WOO',
#   'slug': 'wootrade',
#   'num_market_pairs': 79,
#   'date_added': '2020-10-23T00:00:00.000Z',
#   'tags': ['centralized-exchange',
#    'binance-smart-chain',
#    'exnetwork-capital-portfolio',
#    'polygon-ecosystem',
#    'mvb',
#    'vbc-ventures-portfolio'],
#   'max_supply': 3000000000,
#   'circulating_supply': 884078589.0001837,
#   'total_supply': 2990413143.711403,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   'cmc_rank': 95,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.9547432536876855,
#     'volume_24h': 31274916.09095238,
#     'volume_change_24h': -3.2877,
#     'percent_change_1h': -1.30727185,
#     'percent_change_24h': -7.8411418,
#     'percent_change_7d': -6.04405781,
#     'percent_change_30d': 23.3561151,
#     'percent_change_60d': -38.92798069,
#     'percent_change_90d': -7.28121129,
#     'market_cap': 844068068.5776534,
#     'market_cap_dominance': 0.0416,
#     'fully_diluted_market_cap': 2864229761.06,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1808,
#   'name': 'OMG Network',
#   'symbol': 'OMG',
#   'slug': 'omg',
#   'num_market_pairs': 256,
#   'date_added': '2017-07-14T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'payments',
#    'scaling',
#    'state-channel',
#    'pantera-capital-portfolio'],
#   'max_supply': 140245399,
#   'circulating_supply': 140245398.24513277,
#   'total_supply': 140245398.24513277,
#   'platform': None,
#   'cmc_rank': 96,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 5.914466275775133,
#     'volume_24h': 551981525.5416362,
#     'volume_change_24h': 32.0811,
#     'percent_change_1h': -1.56565492,
#     'percent_change_24h': 0.48351625,
#     'percent_change_7d': 5.18515463,
#     'percent_change_30d': -1.37312707,
#     'percent_change_60d': -49.46936283,
#     'percent_change_90d': -58.06085889,
#     'market_cap': 829476678.2534909,
#     'market_cap_dominance': 0.0409,
#     'fully_diluted_market_cap': 829476682.72,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 4747,
#   'name': 'Velas',
#   'symbol': 'VLX',
#   'slug': 'velas',
#   'num_market_pairs': 46,
#   'date_added': '2019-10-03T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 2248438277.883389,
#   'total_supply': 2248438277.883389,
#   'platform': None,
#   'cmc_rank': 97,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 0.3686915688490903,
#     'volume_24h': 24120276.18111217,
#     'volume_change_24h': 4.602,
#     'percent_change_1h': 0.25433908,
#     'percent_change_24h': -0.31594174,
#     'percent_change_7d': -14.96354795,
#     'percent_change_30d': 20.66326467,
#     'percent_change_60d': -6.40962111,
#     'percent_change_90d': 145.84507672,
#     'market_cap': 828980236.1331736,
#     'market_cap_dominance': 0.0409,
#     'fully_diluted_market_cap': 828980236.13,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1727,
#   'name': 'Bancor',
#   'symbol': 'BNT',
#   'slug': 'bancor',
#   'num_market_pairs': 250,
#   'date_added': '2017-06-18T00:00:00.000Z',
#   'tags': ['marketplace',
#    'decentralized-exchange',
#    'defi',
#    'payments',
#    'scaling',
#    'amm',
#    'kenetic-capital-portfolio',
#    'arbitrum-ecosytem'],
#   'max_supply': None,
#   'circulating_supply': 258480308.70921257,
#   'total_supply': 258480308.70921257,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c'},
#   'cmc_rank': 98,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 3.142925071061962,
#     'volume_24h': 24906585.05195478,
#     'volume_change_24h': -6.4209,
#     'percent_change_1h': -0.53514322,
#     'percent_change_24h': -4.04635747,
#     'percent_change_7d': -1.80776081,
#     'percent_change_30d': -2.72398285,
#     'percent_change_60d': -31.07260216,
#     'percent_change_90d': -23.83916531,
#     'market_cap': 812384242.6180198,
#     'market_cap_dominance': 0.0401,
#     'fully_diluted_market_cap': 812384242.62,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 2700,
#   'name': 'Celsius',
#   'symbol': 'CEL',
#   'slug': 'celsius',
#   'num_market_pairs': 54,
#   'date_added': '2018-05-18T00:00:00.000Z',
#   'tags': ['lending-borowing', 'exnetwork-capital-portfolio'],
#   'max_supply': 695658160,
#   'circulating_supply': 238863519.826,
#   'total_supply': 695658160,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xaaaebe6fe48e54f431b0c390cfaf0b017d09d42d'},
#   'cmc_rank': 99,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 3.3717748811107153,
#     'volume_24h': 5762877.51652774,
#     'volume_change_24h': 47.6601,
#     'percent_change_1h': -0.51813083,
#     'percent_change_24h': 2.48898,
#     'percent_change_7d': -3.41387601,
#     'percent_change_30d': -11.56064215,
#     'percent_change_60d': -29.02788706,
#     'percent_change_90d': -41.84775771,
#     'market_cap': 805394016.1629982,
#     'market_cap_dominance': 0.0397,
#     'fully_diluted_market_cap': 2345602709.73,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}},
#  {'id': 1168,
#   'name': 'Decred',
#   'symbol': 'DCR',
#   'slug': 'decred',
#   'num_market_pairs': 56,
#   'date_added': '2016-02-10T00:00:00.000Z',
#   'tags': ['mineable',
#    'hybrid-pow-pos',
#    'blake256',
#    'medium-of-exchange',
#    'store-of-value',
#    'privacy',
#    'dao',
#    'placeholder-ventures-portfolio'],
#   'max_supply': 21000000,
#   'circulating_supply': 13674348.15535159,
#   'total_supply': 13674348.15535159,
#   'platform': None,
#   'cmc_rank': 100,
#   'last_updated': '2022-01-14T00:26:00.000Z',
#   'quote': {'USD': {'price': 58.11658650412743,
#     'volume_24h': 3282529.29305708,
#     'volume_change_24h': 1.5871,
#     'percent_change_1h': -0.37173323,
#     'percent_change_24h': -6.65886148,
#     'percent_change_7d': -8.37118937,
#     'percent_change_30d': -8.72130027,
#     'percent_change_60d': -51.57046478,
#     'percent_change_90d': -51.97521554,
#     'market_cap': 794706437.4580461,
#     'market_cap_dominance': 0.0392,
#     'fully_diluted_market_cap': 1220448316.59,
#     'last_updated': '2022-01-14T00:26:00.000Z'}}}]

# %% [markdown]
# # Converting the json data into a Dataframe

# %%
crypto_data_df = pd.json_normalize(data_retrieved, record_path =['data'])
crypto_data_df
# Out:
#       id         name symbol      slug  num_market_pairs  \
# 0      1      Bitcoin    BTC   bitcoin              9035
# 1   1027     Ethereum    ETH  ethereum              5408
# 2   1839          BNB    BNB       bnb               620
# 3    825       Tether   USDT    tether             25905
# 4   5426       Solana    SOL    solana               230
# ..   ...          ...    ...       ...               ...
# 95  1808  OMG Network    OMG       omg               256
# 96  4747        Velas    VLX     velas                46
# 97  1727       Bancor    BNT    bancor               250
# 98  2700      Celsius    CEL   celsius                54
# 99  1168       Decred    DCR    decred                56
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2017-07-25T00:00:00.000Z
# 3   2015-02-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ..                       ...
# 95  2017-07-14T00:00:00.000Z
# 96  2019-10-03T00:00:00.000Z
# 97  2017-06-18T00:00:00.000Z
# 98  2018-05-18T00:00:00.000Z
# 99  2016-02-10T00:00:00.000Z
#
#                                                  tags   max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1   [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2   [marketplace, centralized-exchange, payments, ...  166801148.0
# 3   [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...          NaN
# ..                                                ...          ...
# 95  [medium-of-exchange, payments, scaling, state-...  140245399.0
# 96                                                 []          NaN
# 97  [marketplace, decentralized-exchange, defi, pa...          NaN
# 98    [lending-borowing, exnetwork-capital-portfolio]  695658160.0
# 99  [mineable, hybrid-pow-pos, blake256, medium-of...   21000000.0
#
#     circulating_supply  total_supply  ...  quote.USD.percent_change_90d  \
# 0         1.892847e+07  1.892847e+07  ...                    -30.789293
# 1         1.191492e+08  1.191492e+08  ...                    -15.822720
# 2         1.668011e+08  1.668011e+08  ...                      0.055920
# 3         7.839437e+10  8.200898e+10  ...                      0.120229
# 4         3.133796e+08  5.116169e+08  ...                     -8.583670
# ..                 ...           ...  ...                           ...
# 95        1.402454e+08  1.402454e+08  ...                    -58.060859
# 96        2.248438e+09  2.248438e+09  ...                    145.845077
# 97        2.584803e+08  2.584803e+08  ...                    -23.839165
# 98        2.388635e+08  6.956582e+08  ...                    -41.847758
# 99        1.367435e+07  1.367435e+07  ...                    -51.975216
#
#     quote.USD.market_cap quote.USD.market_cap_dominance  \
# 0           8.068599e+11                        39.7910
# 1           3.870300e+11                        19.0867
# 2           7.945938e+10                         3.9185
# 3           7.842113e+10                         3.8673
# 4           4.604446e+10                         2.2707
# ..                   ...                            ...
# 95          8.294767e+08                         0.0409
# 96          8.289802e+08                         0.0409
# 97          8.123842e+08                         0.0401
# 98          8.053940e+08                         0.0397
# 99          7.947064e+08                         0.0392
#
#     quote.USD.fully_diluted_market_cap    quote.USD.last_updated  platform.id  \
# 0                         8.951627e+11  2022-01-14T00:26:00.000Z          NaN
# 1                         3.870300e+11  2022-01-14T00:26:00.000Z          NaN
# 2                         7.945938e+10  2022-01-14T00:26:00.000Z          NaN
# 3                         8.203698e+10  2022-01-14T00:26:00.000Z       1027.0
# 4                         7.517122e+10  2022-01-14T00:26:00.000Z          NaN
# ..                                 ...                       ...          ...
# 95                        8.294767e+08  2022-01-14T00:26:00.000Z          NaN
# 96                        8.289802e+08  2022-01-14T00:26:00.000Z          NaN
# 97                        8.123842e+08  2022-01-14T00:26:00.000Z       1027.0
# 98                        2.345603e+09  2022-01-14T00:26:00.000Z       1027.0
# 99                        1.220448e+09  2022-01-14T00:26:00.000Z          NaN
#
#     platform.name  platform.symbol  platform.slug  \
# 0             NaN              NaN            NaN
# 1             NaN              NaN            NaN
# 2             NaN              NaN            NaN
# 3        Ethereum              ETH       ethereum
# 4             NaN              NaN            NaN
# ..            ...              ...            ...
# 95            NaN              NaN            NaN
# 96            NaN              NaN            NaN
# 97       Ethereum              ETH       ethereum
# 98       Ethereum              ETH       ethereum
# 99            NaN              NaN            NaN
#
#                         platform.token_address
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3   0xdac17f958d2ee523a2206206994597c13d831ec7
# 4                                          NaN
# ..                                         ...
# 95                                         NaN
# 96                                         NaN
# 97  0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c
# 98  0xaaaebe6fe48e54f431b0c390cfaf0b017d09d42d
# 99                                         NaN
#
# [100 rows x 31 columns]

# %%
# Replace NaN as '0'
crypto_data_df.isnull().sum().sum()
crypto_data_df.isna().sum()
# Out:
# id                                      0
# name                                    0
# symbol                                  0
# slug                                    0
# num_market_pairs                        0
# date_added                              0
# tags                                    0
# max_supply                             42
# circulating_supply                      0
# total_supply                            0
# platform                              100
# cmc_rank                                0
# last_updated                            0
# quote.USD.price                         0
# quote.USD.volume_24h                    0
# quote.USD.volume_change_24h             0
# quote.USD.percent_change_1h             0
# quote.USD.percent_change_24h            0
# quote.USD.percent_change_7d             0
# quote.USD.percent_change_30d            0
# quote.USD.percent_change_60d            0
# quote.USD.percent_change_90d            0
# quote.USD.market_cap                    0
# quote.USD.market_cap_dominance          0
# quote.USD.fully_diluted_market_cap      0
# quote.USD.last_updated                  0
# platform.id                            57
# platform.name                          57
# platform.symbol                        57
# platform.slug                          57
# platform.token_address                 57
# dtype: int64

# %%
# Drop columns that have null values as those columns are irrelevant
final_crypto_data_df = crypto_data_df.dropna(axis=1)
final_crypto_data_df
# Out:
#       id         name symbol      slug  num_market_pairs  \
# 0      1      Bitcoin    BTC   bitcoin              9035
# 1   1027     Ethereum    ETH  ethereum              5408
# 2   1839          BNB    BNB       bnb               620
# 3    825       Tether   USDT    tether             25905
# 4   5426       Solana    SOL    solana               230
# ..   ...          ...    ...       ...               ...
# 95  1808  OMG Network    OMG       omg               256
# 96  4747        Velas    VLX     velas                46
# 97  1727       Bancor    BNT    bancor               250
# 98  2700      Celsius    CEL   celsius                54
# 99  1168       Decred    DCR    decred                56
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2017-07-25T00:00:00.000Z
# 3   2015-02-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ..                       ...
# 95  2017-07-14T00:00:00.000Z
# 96  2019-10-03T00:00:00.000Z
# 97  2017-06-18T00:00:00.000Z
# 98  2018-05-18T00:00:00.000Z
# 99  2016-02-10T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...        1.892847e+07
# 1   [mineable, pow, smart-contracts, ethereum-ecos...        1.191492e+08
# 2   [marketplace, centralized-exchange, payments, ...        1.668011e+08
# 3   [payments, stablecoin, asset-backed-stablecoin...        7.839437e+10
# 4   [pos, platform, solana-ecosystem, cms-holdings...        3.133796e+08
# ..                                                ...                 ...
# 95  [medium-of-exchange, payments, scaling, state-...        1.402454e+08
# 96                                                 []        2.248438e+09
# 97  [marketplace, decentralized-exchange, defi, pa...        2.584803e+08
# 98    [lending-borowing, exnetwork-capital-portfolio]        2.388635e+08
# 99  [mineable, hybrid-pow-pos, blake256, medium-of...        1.367435e+07
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 0   1.892847e+07         1  ...                   -0.145207
# 1   1.191492e+08         2  ...                   -0.346219
# 2   1.668011e+08         3  ...                   -0.171776
# 3   8.200898e+10         4  ...                   -0.004005
# 4   5.116169e+08         5  ...                   -0.113591
# ..           ...       ...  ...                         ...
# 95  1.402454e+08        96  ...                   -1.565655
# 96  2.248438e+09        97  ...                    0.254339
# 97  2.584803e+08        98  ...                   -0.535143
# 98  6.956582e+08        99  ...                   -0.518131
# 99  1.367435e+07       100  ...                   -0.371733
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -2.877149                    -0.755506
# 1                      -3.734334                    -4.526232
# 2                      -2.249966                     1.160720
# 3                       0.006483                     0.025032
# 4                      -3.283858                    -1.707503
# ..                           ...                          ...
# 95                      0.483516                     5.185155
# 96                     -0.315942                   -14.963548
# 97                     -4.046357                    -1.807761
# 98                      2.488980                    -3.413876
# 99                     -6.658861                    -8.371189
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -12.295779                    -35.421433
# 1                     -16.527830                    -30.469938
# 2                     -10.360761                    -27.342348
# 3                      -0.039370                      0.011666
# 4                      -9.569429                    -39.029345
# ..                           ...                           ...
# 95                     -1.373127                    -49.469363
# 96                     20.663265                     -6.409621
# 97                     -2.723983                    -31.072602
# 98                    -11.560642                    -29.027887
# 99                     -8.721300                    -51.570465
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -30.789293          8.068599e+11
# 1                     -15.822720          3.870300e+11
# 2                       0.055920          7.945938e+10
# 3                       0.120229          7.842113e+10
# 4                      -8.583670          4.604446e+10
# ..                           ...                   ...
# 95                    -58.060859          8.294767e+08
# 96                    145.845077          8.289802e+08
# 97                    -23.839165          8.123842e+08
# 98                    -41.847758          8.053940e+08
# 99                    -51.975216          7.947064e+08
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          39.7910                        8.951627e+11
# 1                          19.0867                        3.870300e+11
# 2                           3.9185                        7.945938e+10
# 3                           3.8673                        8.203698e+10
# 4                           2.2707                        7.517122e+10
# ..                             ...                                 ...
# 95                          0.0409                        8.294767e+08
# 96                          0.0409                        8.289802e+08
# 97                          0.0401                        8.123842e+08
# 98                          0.0397                        2.345603e+09
# 99                          0.0392                        1.220448e+09
#
#       quote.USD.last_updated
# 0   2022-01-14T00:26:00.000Z
# 1   2022-01-14T00:26:00.000Z
# 2   2022-01-14T00:26:00.000Z
# 3   2022-01-14T00:26:00.000Z
# 4   2022-01-14T00:26:00.000Z
# ..                       ...
# 95  2022-01-14T00:26:00.000Z
# 96  2022-01-14T00:26:00.000Z
# 97  2022-01-14T00:26:00.000Z
# 98  2022-01-14T00:26:00.000Z
# 99  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %% [markdown]
# # Analyzing Top 10 currencies based on Market cap, total supply, circulating supply, Percentage change 90d, 60d, 30d, 7d, 24h and 1hr

# %%
# Top 10 currencies based on market cap
Top_market_cap_currencies_df = final_crypto_data_df.sort_values(by = ["quote.USD.market_cap"], ascending = False)
Top_market_cap_currencies_df.head(20)
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin              9035
# 1   1027         Ethereum    ETH         ethereum              5408
# 2   1839              BNB    BNB              bnb               620
# 3    825           Tether   USDT           tether             25905
# 4   5426           Solana    SOL           solana               230
# 5   3408         USD Coin   USDC         usd-coin              2712
# 6   2010          Cardano    ADA          cardano               354
# 7     52              XRP    XRP              xrp               673
# 8   4172            Terra   LUNA       terra-luna               128
# 9   6636         Polkadot    DOT     polkadot-new               294
# 10    74         Dogecoin   DOGE         dogecoin               442
# 11  5805        Avalanche   AVAX        avalanche               156
# 12  3890          Polygon  MATIC          polygon               310
# 13  5994        Shiba Inu   SHIB        shiba-inu               294
# 14  4687      Binance USD   BUSD      binance-usd              2690
# 15  6535    NEAR Protocol   NEAR    near-protocol                87
# 16  1975        Chainlink   LINK        chainlink               568
# 17  3635  Crypto.com Coin    CRO  crypto-com-coin               123
# 18  3717  Wrapped Bitcoin   WBTC  wrapped-bitcoin               314
# 19  7129         TerraUSD    UST         terrausd               246
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2017-07-25T00:00:00.000Z
# 3   2015-02-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-08-04T00:00:00.000Z
# 8   2019-07-26T00:00:00.000Z
# 9   2020-08-19T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2019-09-20T00:00:00.000Z
# 15  2020-08-11T00:00:00.000Z
# 16  2017-09-20T00:00:00.000Z
# 17  2018-12-14T00:00:00.000Z
# 18  2019-01-30T00:00:00.000Z
# 19  2020-09-21T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...        1.892847e+07
# 1   [mineable, pow, smart-contracts, ethereum-ecos...        1.191492e+08
# 2   [marketplace, centralized-exchange, payments, ...        1.668011e+08
# 3   [payments, stablecoin, asset-backed-stablecoin...        7.839437e+10
# 4   [pos, platform, solana-ecosystem, cms-holdings...        3.133796e+08
# 5   [medium-of-exchange, stablecoin, asset-backed-...        4.499013e+10
# 6   [mineable, dpos, pos, platform, research, smar...        3.351322e+10
# 7   [medium-of-exchange, enterprise-solutions, bin...        4.761513e+10
# 8   [cosmos-ecosystem, store-of-value, defi, payme...        3.565918e+08
# 9   [substrate, polkadot, binance-chain, binance-s...        9.875793e+08
# 10  [mineable, pow, scrypt, medium-of-exchange, me...        1.326708e+11
# 11  [defi, smart-contracts, binance-smart-chain, p...        2.443549e+08
# 12  [platform, enterprise-solutions, scaling, stat...        7.312893e+09
# 13                          [memes, doggone-doggerel]        5.490633e+14
# 14  [stablecoin, asset-backed-stablecoin, binance-...        1.424853e+10
# 15  [platform, staking, binance-smart-chain, coinb...        6.083896e+08
# 16  [platform, defi, oracles, smart-contracts, sub...        4.670096e+08
# 17  [medium-of-exchange, cosmos-ecosystem, central...        2.526301e+10
# 18  [medium-of-exchange, defi, wrapped-tokens, fan...        2.668807e+05
# 19  [stablecoin, binance-smart-chain, terra-ecosys...        1.059271e+10
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 0   1.892847e+07         1  ...                   -0.145207
# 1   1.191492e+08         2  ...                   -0.346219
# 2   1.668011e+08         3  ...                   -0.171776
# 3   8.200898e+10         4  ...                   -0.004005
# 4   5.116169e+08         5  ...                   -0.113591
# 5   4.499013e+10         6  ...                    0.001015
# 6   3.396861e+10         7  ...                   -0.294424
# 7   9.998983e+10         8  ...                   -0.054144
# 8   8.280150e+08         9  ...                    0.249389
# 9   1.103303e+09        10  ...                   -0.606431
# 10  1.326708e+11        11  ...                    0.928701
# 11  3.958913e+08        12  ...                   -0.413591
# 12  1.000000e+10        13  ...                   -1.012344
# 13  5.897350e+14        14  ...                   -0.756629
# 14  1.424853e+10        15  ...                   -0.042054
# 15  1.000000e+09        16  ...                    3.384133
# 16  1.000000e+09        17  ...                    0.073477
# 17  3.026301e+10        18  ...                   -0.434432
# 18  2.668807e+05        19  ...                   -0.134373
# 19  1.059271e+10        20  ...                    0.217367
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -2.877149                    -0.755506
# 1                      -3.734334                    -4.526232
# 2                      -2.249966                     1.160720
# 3                       0.006483                     0.025032
# 4                      -3.283858                    -1.707503
# 5                      -0.084426                    -0.025376
# 6                      -6.241241                    -2.928624
# 7                      -3.575068                    -0.873323
# 8                      -3.549153                     0.987267
# 9                      -6.043189                    -2.553006
# 10                      8.424658                    10.104460
# 11                     -6.400605                    -5.442524
# 12                     -6.579358                     1.765795
# 13                     -7.120888                    -3.671354
# 14                     -0.033653                     0.058045
# 15                     16.363241                    27.678955
# 16                     -5.272955                     1.242304
# 17                     -6.189027                    -8.601556
# 18                     -2.756647                    -0.702272
# 19                      0.345877                     0.205651
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -12.295779                    -35.421433
# 1                     -16.527830                    -30.469938
# 2                     -10.360761                    -27.342348
# 3                      -0.039370                      0.011666
# 4                      -9.569429                    -39.029345
# 5                      -0.067475                      0.033548
# 6                      -2.531737                    -39.985142
# 7                      -5.079172                    -35.756057
# 8                      29.951736                     53.046740
# 9                      -1.624694                    -45.033819
# 10                     -6.273635                    -33.686181
# 11                      1.263657                     -6.604021
# 12                     14.685459                     30.441245
# 13                    -13.043674                    -43.802083
# 14                      0.023187                      0.001861
# 15                    115.406653                     71.893053
# 16                     35.218239                    -27.035129
# 17                    -16.661775                      0.453055
# 18                    -11.127245                    -34.460229
# 19                     -0.020886                     -0.590660
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -30.789293          8.068599e+11
# 1                     -15.822720          3.870300e+11
# 2                       0.055920          7.945938e+10
# 3                       0.120229          7.842113e+10
# 4                      -8.583670          4.604446e+10
# 5                       0.002731          4.496099e+10
# 6                     -44.528806          4.145937e+10
# 7                     -32.661977          3.665388e+10
# 8                     112.718399          2.808079e+10
# 9                     -41.136852          2.554625e+10
# 10                    -27.850696          2.325339e+10
# 11                     59.023308          2.192444e+10
# 12                     47.609530          1.656128e+10
# 13                     15.223312          1.628217e+10
# 14                      0.091151          1.425195e+10
# 15                    154.424854          1.227510e+10
# 16                     -8.342109          1.170692e+10
# 17                    139.511266          1.153198e+10
# 18                    -30.673450          1.138313e+10
# 19                     -0.009214          1.060400e+10
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          39.7910                        8.951627e+11
# 1                          19.0867                        3.870300e+11
# 2                           3.9185                        7.945938e+10
# 3                           3.8673                        8.203698e+10
# 4                           2.2707                        7.517122e+10
# 5                           2.2172                        4.496099e+10
# 6                           2.0446                        5.566972e+10
# 7                           1.8076                        7.697948e+10
# 8                           1.3848                        6.520428e+10
# 9                           1.2598                        2.853975e+10
# 10                          1.1467                        2.325339e+10
# 11                          1.0812                        3.552086e+10
# 12                          0.8167                        2.264669e+10
# 13                          0.8029                        1.748827e+10
# 14                          0.7028                        1.425195e+10
# 15                          0.6053                        2.017637e+10
# 16                          0.5773                        2.506784e+10
# 17                          0.5687                        1.381437e+10
# 18                          0.5614                        1.138313e+10
# 19                          0.5229                        1.060400e+10
#
#       quote.USD.last_updated
# 0   2022-01-14T00:26:00.000Z
# 1   2022-01-14T00:26:00.000Z
# 2   2022-01-14T00:26:00.000Z
# 3   2022-01-14T00:26:00.000Z
# 4   2022-01-14T00:26:00.000Z
# 5   2022-01-14T00:26:00.000Z
# 6   2022-01-14T00:26:00.000Z
# 7   2022-01-14T00:26:00.000Z
# 8   2022-01-14T00:26:00.000Z
# 9   2022-01-14T00:26:00.000Z
# 10  2022-01-14T00:26:00.000Z
# 11  2022-01-14T00:26:00.000Z
# 12  2022-01-14T00:26:00.000Z
# 13  2022-01-14T00:26:00.000Z
# 14  2022-01-14T00:26:00.000Z
# 15  2022-01-14T00:26:00.000Z
# 16  2022-01-14T00:26:00.000Z
# 17  2022-01-14T00:26:00.000Z
# 18  2022-01-14T00:26:00.000Z
# 19  2022-01-14T00:26:00.000Z
#
# [20 rows x 24 columns]

# %%
# Top 10 currencies based on max supply
Top_total_supply_currencies_df = final_crypto_data_df.sort_values(by = ["total_supply"], ascending = False)
Top_total_supply_currencies_df
# Out:
#        id             name symbol             slug  num_market_pairs  \
# 13   5994        Shiba Inu   SHIB        shiba-inu               294
# 66  10791            eCash    XEC            ecash                46
# 53   3718       BitTorrent    BTT       bittorrent               164
# 86   2682             Holo    HOT             holo                99
# 10     74         Dogecoin   DOGE         dogecoin               442
# ..    ...              ...    ...              ...               ...
# 57   5034           Kusama    KSM           kusama               117
# 60   1518            Maker    MKR            maker               229
# 18   3717  Wrapped Bitcoin   WBTC  wrapped-bitcoin               314
# 35   4023     Bitcoin BEP2   BTCB     bitcoin-bep2                99
# 82   5864    yearn.finance    YFI    yearn-finance               246
#
#                   date_added  \
# 13  2020-08-01T00:00:00.000Z
# 66  2021-07-08T00:00:00.000Z
# 53  2019-01-31T00:00:00.000Z
# 86  2018-04-29T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# ..                       ...
# 57  2019-12-12T00:00:00.000Z
# 60  2017-01-29T00:00:00.000Z
# 18  2019-01-30T00:00:00.000Z
# 35  2019-06-18T00:00:00.000Z
# 82  2020-07-18T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 13                          [memes, doggone-doggerel]        5.490633e+14
# 66                                                 []        1.895064e+13
# 53  [platform, distributed-computing, filesharing,...        9.900000e+11
# 86  [platform, distributed-computing, filesharing,...        1.731137e+11
# 10  [mineable, pow, scrypt, medium-of-exchange, me...        1.326708e+11
# ..                                                ...                 ...
# 57  [substrate, polkadot-ecosystem, cms-holdings-p...        8.470098e+06
# 60  [store-of-value, defi, dao, binance-smart-chai...        9.851288e+05
# 18  [medium-of-exchange, defi, wrapped-tokens, fan...        2.668807e+05
# 35               [binance-chain, binance-smart-chain]        1.051136e+05
# 82  [defi, yield-farming, binance-smart-chain, yie...        3.663772e+04
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 13  5.897350e+14        14  ...                   -0.756629
# 66  1.889970e+13        67  ...                   -1.073816
# 53  9.900000e+11        54  ...                   -0.279264
# 86  1.776194e+11        87  ...                   -0.247525
# 10  1.326708e+11        11  ...                    0.928701
# ..           ...       ...  ...                         ...
# 57  9.651217e+06        58  ...                   -0.819762
# 60  9.851288e+05        61  ...                   -0.282977
# 18  2.668807e+05        19  ...                   -0.134373
# 35  1.125010e+05        36  ...                   -0.375672
# 82  3.666600e+04        83  ...                   -0.196236
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 13                     -7.120888                    -3.671354
# 66                     -3.147196                    -7.440758
# 53                     -3.838313                    -9.553834
# 86                     -5.908049                    -7.458086
# 10                      8.424658                    10.104460
# ..                           ...                          ...
# 57                     -3.240132                    -2.286783
# 60                     -3.096524                    -6.138339
# 18                     -2.756647                    -0.702272
# 35                     -3.253149                    -1.182844
# 82                     -6.252474                   -10.445312
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 13                    -13.043674                    -43.802083
# 66                    -16.444172                    -54.029845
# 53                    -11.742468                    -34.341598
# 86                    -23.894360                    -54.545778
# 10                     -6.273635                    -33.686181
# ..                           ...                           ...
# 57                     -5.025903                    -38.452536
# 60                     -9.037736                    -31.321781
# 18                    -11.127245                    -34.460229
# 35                    -12.521684                    -35.817748
# 82                     56.289400                     -6.917433
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 13                     15.223312          1.628217e+10
# 66                    -53.961913          1.799910e+09
# 53                    -31.766110          2.480334e+09
# 86                    -33.341864          1.061018e+09
# 10                    -27.850696          2.325339e+10
# ..                           ...                   ...
# 57                    -24.341676          2.253657e+09
# 60                    -18.393581          2.071441e+09
# 18                    -30.673450          1.138313e+10
# 35                    -31.026783          4.459506e+09
# 82                    -12.428598          1.157137e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 13                          0.8029                        1.748827e+10
# 66                          0.0888                        1.994556e+09
# 53                          0.1223                        2.480334e+09
# 86                          0.0523                        1.088634e+09
# 10                          1.1467                        2.325339e+10
# ..                             ...                                 ...
# 57                          0.1111                        2.567920e+09
# 60                          0.1022                        2.114438e+09
# 18                          0.5614                        1.138313e+10
# 35                          0.2199                        4.772921e+09
# 82                          0.0571                        1.158030e+09
#
#       quote.USD.last_updated
# 13  2022-01-14T00:26:00.000Z
# 66  2022-01-14T00:26:00.000Z
# 53  2022-01-14T00:26:00.000Z
# 86  2022-01-14T00:26:00.000Z
# 10  2022-01-14T00:26:00.000Z
# ..                       ...
# 57  2022-01-14T00:26:00.000Z
# 60  2022-01-14T00:26:00.000Z
# 18  2022-01-14T00:26:00.000Z
# 35  2022-01-14T00:26:00.000Z
# 82  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
# Top 10 currencies based on # circulating supply
Top_circulating_supply_currencies_df = final_crypto_data_df.sort_values(by = ["circulating_supply"], ascending = False)
Top_circulating_supply_currencies_df
# Out:
#        id             name symbol             slug  num_market_pairs  \
# 13   5994        Shiba Inu   SHIB        shiba-inu               294
# 66  10791            eCash    XEC            ecash                46
# 53   3718       BitTorrent    BTT       bittorrent               164
# 86   2682             Holo    HOT             holo                99
# 10     74         Dogecoin   DOGE         dogecoin               442
# ..    ...              ...    ...              ...               ...
# 81   5692         Compound   COMP         compound               238
# 60   1518            Maker    MKR            maker               229
# 18   3717  Wrapped Bitcoin   WBTC  wrapped-bitcoin               314
# 35   4023     Bitcoin BEP2   BTCB     bitcoin-bep2                99
# 82   5864    yearn.finance    YFI    yearn-finance               246
#
#                   date_added  \
# 13  2020-08-01T00:00:00.000Z
# 66  2021-07-08T00:00:00.000Z
# 53  2019-01-31T00:00:00.000Z
# 86  2018-04-29T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# ..                       ...
# 81  2020-06-16T00:00:00.000Z
# 60  2017-01-29T00:00:00.000Z
# 18  2019-01-30T00:00:00.000Z
# 35  2019-06-18T00:00:00.000Z
# 82  2020-07-18T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 13                          [memes, doggone-doggerel]        5.490633e+14
# 66                                                 []        1.895064e+13
# 53  [platform, distributed-computing, filesharing,...        9.900000e+11
# 86  [platform, distributed-computing, filesharing,...        1.731137e+11
# 10  [mineable, pow, scrypt, medium-of-exchange, me...        1.326708e+11
# ..                                                ...                 ...
# 81  [defi, dao, yield-farming, binance-smart-chain...        6.327199e+06
# 60  [store-of-value, defi, dao, binance-smart-chai...        9.851288e+05
# 18  [medium-of-exchange, defi, wrapped-tokens, fan...        2.668807e+05
# 35               [binance-chain, binance-smart-chain]        1.051136e+05
# 82  [defi, yield-farming, binance-smart-chain, yie...        3.663772e+04
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 13  5.897350e+14        14  ...                   -0.756629
# 66  1.889970e+13        67  ...                   -1.073816
# 53  9.900000e+11        54  ...                   -0.279264
# 86  1.776194e+11        87  ...                   -0.247525
# 10  1.326708e+11        11  ...                    0.928701
# ..           ...       ...  ...                         ...
# 81  1.000000e+07        82  ...                   -0.711605
# 60  9.851288e+05        61  ...                   -0.282977
# 18  2.668807e+05        19  ...                   -0.134373
# 35  1.125010e+05        36  ...                   -0.375672
# 82  3.666600e+04        83  ...                   -0.196236
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 13                     -7.120888                    -3.671354
# 66                     -3.147196                    -7.440758
# 53                     -3.838313                    -9.553834
# 86                     -5.908049                    -7.458086
# 10                      8.424658                    10.104460
# ..                           ...                          ...
# 81                     -5.459740                    -7.492052
# 60                     -3.096524                    -6.138339
# 18                     -2.756647                    -0.702272
# 35                     -3.253149                    -1.182844
# 82                     -6.252474                   -10.445312
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 13                    -13.043674                    -43.802083
# 66                    -16.444172                    -54.029845
# 53                    -11.742468                    -34.341598
# 86                    -23.894360                    -54.545778
# 10                     -6.273635                    -33.686181
# ..                           ...                           ...
# 81                      0.037598                    -46.077945
# 60                     -9.037736                    -31.321781
# 18                    -11.127245                    -34.460229
# 35                    -12.521684                    -35.817748
# 82                     56.289400                     -6.917433
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 13                     15.223312          1.628217e+10
# 66                    -53.961913          1.799910e+09
# 53                    -31.766110          2.480334e+09
# 86                    -33.341864          1.061018e+09
# 10                    -27.850696          2.325339e+10
# ..                           ...                   ...
# 81                    -41.621810          1.184504e+09
# 60                    -18.393581          2.071441e+09
# 18                    -30.673450          1.138313e+10
# 35                    -31.026783          4.459506e+09
# 82                    -12.428598          1.157137e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 13                          0.8029                        1.748827e+10
# 66                          0.0888                        1.994556e+09
# 53                          0.1223                        2.480334e+09
# 86                          0.0523                        1.088634e+09
# 10                          1.1467                        2.325339e+10
# ..                             ...                                 ...
# 81                          0.0584                        1.872083e+09
# 60                          0.1022                        2.114438e+09
# 18                          0.5614                        1.138313e+10
# 35                          0.2199                        4.772921e+09
# 82                          0.0571                        1.158030e+09
#
#       quote.USD.last_updated
# 13  2022-01-14T00:26:00.000Z
# 66  2022-01-14T00:26:00.000Z
# 53  2022-01-14T00:26:00.000Z
# 86  2022-01-14T00:26:00.000Z
# 10  2022-01-14T00:26:00.000Z
# ..                       ...
# 81  2022-01-14T00:26:00.000Z
# 60  2022-01-14T00:26:00.000Z
# 18  2022-01-14T00:26:00.000Z
# 35  2022-01-14T00:26:00.000Z
# 82  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
# Highest percentage change in 90 days
Top_Percent_90d_df = final_crypto_data_df.sort_values(by = ["quote.USD.percent_change_90d"], ascending = False)
Top_Percent_90d_df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 36   6210   The Sandbox   SAND   the-sandbox               177
# 71   5647        Kadena    KDA        kadena                16
# 31   1966  Decentraland   MANA  decentraland               225
# 55   7080          Gala   GALA          gala               105
# 63   1934      Loopring    LRC      loopring               166
# ..    ...           ...    ...           ...               ...
# 77   1274         Waves  WAVES         waves               154
# 66  10791         eCash    XEC         ecash                46
# 54   4558          Flow   FLOW          flow                55
# 37   2280      Filecoin    FIL      filecoin               166
# 95   1808   OMG Network    OMG           omg               256
#
#                   date_added  \
# 36  2020-08-05T00:00:00.000Z
# 71  2020-05-31T00:00:00.000Z
# 31  2017-09-17T00:00:00.000Z
# 55  2020-09-16T00:00:00.000Z
# 63  2017-08-30T00:00:00.000Z
# ..                       ...
# 77  2016-06-02T00:00:00.000Z
# 66  2021-07-08T00:00:00.000Z
# 54  2021-01-27T00:00:00.000Z
# 37  2017-12-13T00:00:00.000Z
# 95  2017-07-14T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 36  [collectibles-nfts, content-creation, gaming, ...        9.209483e+08
# 71  [mineable, pow, blake2s, platform, cosmos-ecos...        1.669481e+08
# 31  [platform, collectibles-nfts, gaming, payments...        1.824525e+09
# 55  [collectibles-nfts, gaming, polygon-ecosystem,...        6.977205e+09
# 63  [marketplace, decentralized-exchange, defi, sc...        1.328716e+09
# ..                                                ...                 ...
# 77                  [lpos, platform, smart-contracts]        1.072176e+08
# 66                                                 []        1.895064e+13
# 54  [collectibles-nfts, coinbase-ventures-portfoli...        3.180824e+08
# 37  [mineable, distributed-computing, filesharing,...        1.477996e+08
# 95  [medium-of-exchange, payments, scaling, state-...        1.402454e+08
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 36  3.000000e+09        37  ...                   -0.295186
# 71  1.000000e+09        72  ...                   -1.079516
# 31  2.193890e+09        32  ...                   -0.360826
# 55  3.524011e+10        56  ...                   -0.505214
# 63  1.373873e+09        64  ...                   -1.063004
# ..           ...       ...  ...                         ...
# 77  1.072176e+08        78  ...                   -0.511441
# 66  1.889970e+13        67  ...                   -1.073816
# 54  1.378212e+09        55  ...                   -0.894104
# 37  1.477996e+08        38  ...                   -0.408034
# 95  1.402454e+08        96  ...                   -1.565655
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 36                     -6.057328                    -5.304579
# 71                     -5.967215                    -8.198499
# 31                     -5.848038                   -12.127447
# 55                     -8.994661                   -12.374522
# 63                     -9.437739                   -18.109195
# ..                           ...                          ...
# 77                     -4.908859                    -1.383586
# 66                     -3.147196                    -7.440758
# 54                     -2.558287                    -6.379451
# 37                     -6.328706                   -12.785155
# 95                      0.483516                     5.185155
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 36                      0.004918                     70.983046
# 71                     -3.575605                    -57.473924
# 31                     -9.409535                     -9.107198
# 55                    -35.363431                    242.831040
# 63                    -32.041779                    -51.736682
# ..                           ...                           ...
# 77                     -7.517911                    -40.414442
# 66                    -16.444172                    -54.029845
# 54                    -11.410176                    -40.794921
# 37                    -22.470476                    -54.606081
# 95                     -1.373127                    -49.469363
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 36                    544.120978          4.452696e+09
# 71                    335.815285          1.594179e+09
# 31                    280.397841          5.296916e+09
# 55                    265.305591          2.280831e+09
# 63                    257.694908          1.989962e+09
# ..                           ...                   ...
# 77                    -53.713327          1.499339e+09
# 66                    -53.961913          1.799910e+09
# 54                    -55.980093          2.454246e+09
# 37                    -57.860166          4.232918e+09
# 95                    -58.060859          8.294767e+08
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 36                          0.2196                        1.450471e+10
# 71                          0.0786                        9.548954e+09
# 31                          0.2612                        6.369248e+09
# 55                          0.1125                        1.151991e+10
# 63                          0.0981                        2.058552e+09
# ..                             ...                                 ...
# 77                          0.0739                        1.499339e+09
# 66                          0.0888                        1.994556e+09
# 54                          0.1210                        1.063395e+10
# 37                          0.2087                        4.232918e+09
# 95                          0.0409                        8.294767e+08
#
#       quote.USD.last_updated
# 36  2022-01-14T00:26:00.000Z
# 71  2022-01-14T00:26:00.000Z
# 31  2022-01-14T00:26:00.000Z
# 55  2022-01-14T00:26:00.000Z
# 63  2022-01-14T00:26:00.000Z
# ..                       ...
# 77  2022-01-14T00:26:00.000Z
# 66  2022-01-14T00:26:00.000Z
# 54  2022-01-14T00:26:00.000Z
# 37  2022-01-14T00:26:00.000Z
# 95  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
Top_Percent_60d_df = final_crypto_data_df.sort_values(by = ["quote.USD.percent_change_60d"], ascending = False)
Top_Percent_60d_df
# Out:
#        id           name symbol           slug  num_market_pairs  \
# 55   7080           Gala   GALA           gala               105
# 68   7653  Oasis Network   ROSE  oasis-network                36
# 15   6535  NEAR Protocol   NEAR  near-protocol                87
# 36   6210    The Sandbox   SAND    the-sandbox               177
# 8    4172          Terra   LUNA     terra-luna               128
# ..    ...            ...    ...            ...               ...
# 66  10791          eCash    XEC          ecash                46
# 86   2682           Holo    HOT           holo                99
# 37   2280       Filecoin    FIL       filecoin               166
# 90   2777          IoTeX   IOTX          iotex                68
# 71   5647         Kadena    KDA         kadena                16
#
#                   date_added  \
# 55  2020-09-16T00:00:00.000Z
# 68  2020-11-12T00:00:00.000Z
# 15  2020-08-11T00:00:00.000Z
# 36  2020-08-05T00:00:00.000Z
# 8   2019-07-26T00:00:00.000Z
# ..                       ...
# 66  2021-07-08T00:00:00.000Z
# 86  2018-04-29T00:00:00.000Z
# 37  2017-12-13T00:00:00.000Z
# 90  2018-05-25T00:00:00.000Z
# 71  2020-05-31T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 55  [collectibles-nfts, gaming, polygon-ecosystem,...        6.977205e+09
# 68  [collectibles-nfts, defi, privacy, scaling, sm...        3.493014e+09
# 15  [platform, staking, binance-smart-chain, coinb...        6.083896e+08
# 36  [collectibles-nfts, content-creation, gaming, ...        9.209483e+08
# 8   [cosmos-ecosystem, store-of-value, defi, payme...        3.565918e+08
# ..                                                ...                 ...
# 66                                                 []        1.895064e+13
# 86  [platform, distributed-computing, filesharing,...        1.731137e+11
# 37  [mineable, distributed-computing, filesharing,...        1.477996e+08
# 90  [platform, iot, binance-smart-chain, hashkey-c...        9.540779e+09
# 71  [mineable, pow, blake2s, platform, cosmos-ecos...        1.669481e+08
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 55  3.524011e+10        56  ...                   -0.505214
# 68  1.000000e+10        69  ...                   -0.891341
# 15  1.000000e+09        16  ...                    3.384133
# 36  3.000000e+09        37  ...                   -0.295186
# 8   8.280150e+08         9  ...                    0.249389
# ..           ...       ...  ...                         ...
# 66  1.889970e+13        67  ...                   -1.073816
# 86  1.776194e+11        87  ...                   -0.247525
# 37  1.477996e+08        38  ...                   -0.408034
# 90  9.626124e+09        91  ...                   -0.484589
# 71  1.000000e+09        72  ...                   -1.079516
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 55                     -8.994661                   -12.374522
# 68                     -5.752697                    27.974730
# 15                     16.363241                    27.678955
# 36                     -6.057328                    -5.304579
# 8                      -3.549153                     0.987267
# ..                           ...                          ...
# 66                     -3.147196                    -7.440758
# 86                     -5.908049                    -7.458086
# 37                     -6.328706                   -12.785155
# 90                     -5.614880                    -8.771922
# 71                     -5.967215                    -8.198499
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 55                    -35.363431                    242.831040
# 68                     77.798745                    118.364921
# 15                    115.406653                     71.893053
# 36                      0.004918                     70.983046
# 8                      29.951736                     53.046740
# ..                           ...                           ...
# 66                    -16.444172                    -54.029845
# 86                    -23.894360                    -54.545778
# 37                    -22.470476                    -54.606081
# 90                    -10.998792                    -55.753729
# 71                     -3.575605                    -57.473924
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 55                    265.305591          2.280831e+09
# 68                    138.309119          1.734897e+09
# 15                    154.424854          1.227510e+10
# 36                    544.120978          4.452696e+09
# 8                     112.718399          2.808079e+10
# ..                           ...                   ...
# 66                    -53.961913          1.799910e+09
# 86                    -33.341864          1.061018e+09
# 37                    -57.860166          4.232918e+09
# 90                     45.410654          9.559323e+08
# 71                    335.815285          1.594179e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 55                          0.1125                        1.151991e+10
# 68                          0.0856                        4.966763e+09
# 15                          0.6053                        2.017637e+10
# 36                          0.2196                        1.450471e+10
# 8                           1.3848                        6.520428e+10
# ..                             ...                                 ...
# 66                          0.0888                        1.994556e+09
# 86                          0.0523                        1.088634e+09
# 37                          0.2087                        4.232918e+09
# 90                          0.0471                        1.001944e+09
# 71                          0.0786                        9.548954e+09
#
#       quote.USD.last_updated
# 55  2022-01-14T00:26:00.000Z
# 68  2022-01-14T00:26:00.000Z
# 15  2022-01-14T00:26:00.000Z
# 36  2022-01-14T00:26:00.000Z
# 8   2022-01-14T00:26:00.000Z
# ..                       ...
# 66  2022-01-14T00:26:00.000Z
# 86  2022-01-14T00:26:00.000Z
# 37  2022-01-14T00:26:00.000Z
# 90  2022-01-14T00:26:00.000Z
# 71  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
# Highest percentage change in 30 days
Top_Percent_30d_df = final_crypto_data_df.sort_values(by = ["quote.USD.percent_change_30d"], ascending = False)
Top_Percent_30d_df
# Out:
#       id           name symbol           slug  num_market_pairs  \
# 25  3513         Fantom    FTM         fantom               207
# 15  6535  NEAR Protocol   NEAR  near-protocol                87
# 38  3945        Harmony    ONE        harmony                76
# 84  5604         Secret   SCRT         secret                24
# 68  7653  Oasis Network   ROSE  oasis-network                36
# ..   ...            ...    ...            ...               ...
# 86  2682           Holo    HOT           holo                99
# 27  1958           TRON    TRX           tron               558
# 34  6783  Axie Infinity    AXS  axie-infinity               177
# 63  1934       Loopring    LRC       loopring               166
# 55  7080           Gala   GALA           gala               105
#
#                   date_added  \
# 25  2018-10-29T00:00:00.000Z
# 15  2020-08-11T00:00:00.000Z
# 38  2019-06-01T00:00:00.000Z
# 84  2020-05-19T00:00:00.000Z
# 68  2020-11-12T00:00:00.000Z
# ..                       ...
# 86  2018-04-29T00:00:00.000Z
# 27  2017-09-13T00:00:00.000Z
# 34  2020-08-31T00:00:00.000Z
# 63  2017-08-30T00:00:00.000Z
# 55  2020-09-16T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 25  [platform, enterprise-solutions, defi, researc...        2.545006e+09
# 15  [platform, staking, binance-smart-chain, coinb...        6.083896e+08
# 38  [platform, enterprise-solutions, scaling, smar...        1.158637e+10
# 84                  [cosmos-ecosystem, defi, privacy]        1.498157e+08
# 68  [collectibles-nfts, defi, privacy, scaling, sm...        3.493014e+09
# ..                                                ...                 ...
# 86  [platform, distributed-computing, filesharing,...        1.731137e+11
# 27  [media, payments, tron-ecosystem, binance-smar...        1.018339e+11
# 34  [collectibles-nfts, gaming, binance-launchpad,...        6.090750e+07
# 63  [marketplace, decentralized-exchange, defi, sc...        1.328716e+09
# 55  [collectibles-nfts, gaming, polygon-ecosystem,...        6.977205e+09
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 25  2.545006e+09        26  ...                   -1.873285
# 15  1.000000e+09        16  ...                    3.384133
# 38  1.331500e+10        39  ...                    0.814989
# 84  1.901651e+08        85  ...                    3.920681
# 68  1.000000e+10        69  ...                   -0.891341
# ..           ...       ...  ...                         ...
# 86  1.776194e+11        87  ...                   -0.247525
# 27  1.018339e+11        28  ...                   -0.363952
# 34  2.700000e+08        35  ...                   -0.477968
# 63  1.373873e+09        64  ...                   -1.063004
# 55  3.524011e+10        56  ...                   -0.505214
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 25                      2.721796                     5.490286
# 15                     16.363241                    27.678955
# 38                      1.531806                    17.221906
# 84                     14.023433                    25.319648
# 68                     -5.752697                    27.974730
# ..                           ...                          ...
# 86                     -5.908049                    -7.458086
# 27                     -2.868368                    -6.570079
# 34                     -6.422518                    -6.127500
# 63                     -9.437739                   -18.109195
# 55                     -8.994661                   -12.374522
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 25                    126.143142                     14.333529
# 15                    115.406653                     71.893053
# 38                    103.891727                     27.965419
# 84                     88.833706                     -3.499305
# 68                     77.798745                    118.364921
# ..                           ...                           ...
# 86                    -23.894360                    -54.545778
# 27                    -24.128186                    -43.516408
# 34                    -24.309253                    -49.094648
# 63                    -32.041779                    -51.736682
# 55                    -35.363431                    242.831040
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 25                     53.524811          7.593361e+09
# 15                    154.424854          1.227510e+10
# 38                     61.899972          4.094178e+09
# 84                     58.810927          1.139225e+09
# 68                    138.309119          1.734897e+09
# ..                           ...                   ...
# 86                    -33.341864          1.061018e+09
# 27                    -33.215349          6.751159e+09
# 34                    -42.515459          4.461344e+09
# 63                    257.694908          1.989962e+09
# 55                    265.305591          2.280831e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 25                          0.3745                        9.473031e+09
# 15                          0.6053                        2.017637e+10
# 38                          0.2019                        4.705011e+09
# 84                          0.0562                        1.446049e+09
# 68                          0.0856                        4.966763e+09
# ..                             ...                                 ...
# 86                          0.0523                        1.088634e+09
# 27                          0.3329                        6.751158e+09
# 34                          0.2200                        1.977692e+10
# 63                          0.0981                        2.058552e+09
# 55                          0.1125                        1.151991e+10
#
#       quote.USD.last_updated
# 25  2022-01-14T00:26:00.000Z
# 15  2022-01-14T00:26:00.000Z
# 38  2022-01-14T00:26:00.000Z
# 84  2022-01-14T00:26:00.000Z
# 68  2022-01-14T00:26:00.000Z
# ..                       ...
# 86  2022-01-14T00:26:00.000Z
# 27  2022-01-14T00:26:00.000Z
# 34  2022-01-14T00:26:00.000Z
# 63  2022-01-14T00:26:00.000Z
# 55  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
# Highest percentage change in 7 days
Top_Percent_7d_df = final_crypto_data_df.sort_values(by = ["quote.USD.percent_change_7d"], ascending = False)
Top_Percent_7d_df
# Out:
#       id           name symbol           slug  num_market_pairs  \
# 68  7653  Oasis Network   ROSE  oasis-network                36
# 15  6535  NEAR Protocol   NEAR  near-protocol                87
# 84  5604         Secret   SCRT         secret                24
# 38  3945        Harmony    ONE        harmony                76
# 78   131           Dash   DASH           dash               325
# ..   ...            ...    ...            ...               ...
# 37  2280       Filecoin    FIL       filecoin               166
# 96  4747          Velas    VLX          velas                46
# 63  1934       Loopring    LRC       loopring               166
# 46  5665         Helium    HNT         helium                36
# 89  2577      Ravencoin    RVN      ravencoin                91
#
#                   date_added  \
# 68  2020-11-12T00:00:00.000Z
# 15  2020-08-11T00:00:00.000Z
# 84  2020-05-19T00:00:00.000Z
# 38  2019-06-01T00:00:00.000Z
# 78  2014-02-14T00:00:00.000Z
# ..                       ...
# 37  2017-12-13T00:00:00.000Z
# 96  2019-10-03T00:00:00.000Z
# 63  2017-08-30T00:00:00.000Z
# 46  2020-06-05T00:00:00.000Z
# 89  2018-03-10T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 68  [collectibles-nfts, defi, privacy, scaling, sm...        3.493014e+09
# 15  [platform, staking, binance-smart-chain, coinb...        6.083896e+08
# 84                  [cosmos-ecosystem, defi, privacy]        1.498157e+08
# 38  [platform, enterprise-solutions, scaling, smar...        1.158637e+10
# 78  [mineable, hybrid-pow-pos, x11, medium-of-exch...        1.052727e+07
# ..                                                ...                 ...
# 37  [mineable, distributed-computing, filesharing,...        1.477996e+08
# 96                                                 []        2.248438e+09
# 63  [marketplace, decentralized-exchange, defi, sc...        1.328716e+09
# 46  [mineable, enterprise-solutions, distributed-c...        1.062173e+08
# 89            [mineable, pow, platform, crowdfunding]        1.047329e+10
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 68  1.000000e+10        69  ...                   -0.891341
# 15  1.000000e+09        16  ...                    3.384133
# 84  1.901651e+08        85  ...                    3.920681
# 38  1.331500e+10        39  ...                    0.814989
# 78  1.052727e+07        79  ...                    0.211242
# ..           ...       ...  ...                         ...
# 37  1.477996e+08        38  ...                   -0.408034
# 96  2.248438e+09        97  ...                    0.254339
# 63  1.373873e+09        64  ...                   -1.063004
# 46  2.230000e+08        47  ...                   -1.058370
# 89  1.047329e+10        90  ...                   -0.621765
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 68                     -5.752697                    27.974730
# 15                     16.363241                    27.678955
# 84                     14.023433                    25.319648
# 38                      1.531806                    17.221906
# 78                     -1.132224                    14.413731
# ..                           ...                          ...
# 37                     -6.328706                   -12.785155
# 96                     -0.315942                   -14.963548
# 63                     -9.437739                   -18.109195
# 46                     -9.524284                   -18.852802
# 89                     -6.837548                   -22.150618
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 68                     77.798745                    118.364921
# 15                    115.406653                     71.893053
# 84                     88.833706                     -3.499305
# 38                    103.891727                     27.965419
# 78                      7.379301                    -38.423950
# ..                           ...                           ...
# 37                    -22.470476                    -54.606081
# 96                     20.663265                     -6.409621
# 63                    -32.041779                    -51.736682
# 46                     15.512669                    -38.422370
# 89                     12.410658                    -26.953607
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 68                    138.309119          1.734897e+09
# 15                    154.424854          1.227510e+10
# 84                     58.810927          1.139225e+09
# 38                     61.899972          4.094178e+09
# 78                    -27.812222          1.495975e+09
# ..                           ...                   ...
# 37                    -57.860166          4.232918e+09
# 96                    145.845077          8.289802e+08
# 63                    257.694908          1.989962e+09
# 46                     51.960727          3.428487e+09
# 89                    -12.953759          9.958745e+08
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 68                          0.0856                        4.966763e+09
# 15                          0.6053                        2.017637e+10
# 84                          0.0562                        1.446049e+09
# 38                          0.2019                        4.705011e+09
# 78                          0.0738                        2.685779e+09
# ..                             ...                                 ...
# 37                          0.2087                        4.232918e+09
# 96                          0.0409                        8.289802e+08
# 63                          0.0981                        2.058552e+09
# 46                          0.1691                        7.198003e+09
# 89                          0.0491                        1.996828e+09
#
#       quote.USD.last_updated
# 68  2022-01-14T00:26:00.000Z
# 15  2022-01-14T00:26:00.000Z
# 84  2022-01-14T00:26:00.000Z
# 38  2022-01-14T00:26:00.000Z
# 78  2022-01-14T00:26:00.000Z
# ..                       ...
# 37  2022-01-14T00:26:00.000Z
# 96  2022-01-14T00:26:00.000Z
# 63  2022-01-14T00:26:00.000Z
# 46  2022-01-14T00:26:00.000Z
# 89  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
# Highest percentage change in 24 hours
Top_Percent_24h_df = final_crypto_data_df.sort_values(by = ["quote.USD.percent_change_24h"], ascending = False)
Top_Percent_24h_df
# Out:
#       id           name symbol           slug  num_market_pairs  \
# 15  6535  NEAR Protocol   NEAR  near-protocol                87
# 84  5604         Secret   SCRT         secret                24
# 39   328         Monero    XMR         monero               166
# 10    74       Dogecoin   DOGE       dogecoin               442
# 88  8104  1inch Network  1INCH          1inch               199
# ..   ...            ...    ...            ...               ...
# 55  7080           Gala   GALA           gala               105
# 83  8646           Mina   MINA           mina                48
# 63  1934       Loopring    LRC       loopring               166
# 58  4157      THORChain   RUNE      thorchain                67
# 46  5665         Helium    HNT         helium                36
#
#                   date_added  \
# 15  2020-08-11T00:00:00.000Z
# 84  2020-05-19T00:00:00.000Z
# 39  2014-05-21T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# 88  2020-12-25T00:00:00.000Z
# ..                       ...
# 55  2020-09-16T00:00:00.000Z
# 83  2021-03-02T00:00:00.000Z
# 63  2017-08-30T00:00:00.000Z
# 58  2019-07-23T00:00:00.000Z
# 46  2020-06-05T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 15  [platform, staking, binance-smart-chain, coinb...        6.083896e+08
# 84                  [cosmos-ecosystem, defi, privacy]        1.498157e+08
# 39  [mineable, pow, medium-of-exchange, privacy, r...        1.806245e+07
# 10  [mineable, pow, scrypt, medium-of-exchange, me...        1.326708e+11
# 88  [decentralized-exchange, defi, amm, binance-sm...        4.413053e+08
# ..                                                ...                 ...
# 55  [collectibles-nfts, gaming, polygon-ecosystem,...        6.977205e+09
# 83  [pos, zero-knowledge-proofs, staking, coinbase...        3.484522e+08
# 63  [marketplace, decentralized-exchange, defi, sc...        1.328716e+09
# 58  [cosmos-ecosystem, decentralized-exchange, def...        3.306881e+08
# 46  [mineable, enterprise-solutions, distributed-c...        1.062173e+08
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 15  1.000000e+09        16  ...                    3.384133
# 84  1.901651e+08        85  ...                    3.920681
# 39  1.806245e+07        40  ...                   -0.647391
# 10  1.326708e+11        11  ...                    0.928701
# 88  1.500000e+09        89  ...                   -1.422333
# ..           ...       ...  ...                         ...
# 55  3.524011e+10        56  ...                   -0.505214
# 83  8.241050e+08        84  ...                   -0.464023
# 63  1.373873e+09        64  ...                   -1.063004
# 58  3.349380e+08        59  ...                   -0.402757
# 46  2.230000e+08        47  ...                   -1.058370
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 15                     16.363241                    27.678955
# 84                     14.023433                    25.319648
# 39                     11.406179                     9.524062
# 10                      8.424658                    10.104460
# 88                      4.398924                     0.302847
# ..                           ...                          ...
# 55                     -8.994661                   -12.374522
# 83                     -9.342415                    -9.969747
# 63                     -9.437739                   -18.109195
# 58                     -9.499068                    -9.052266
# 46                     -9.524284                   -18.852802
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 15                    115.406653                     71.893053
# 84                     88.833706                     -3.499305
# 39                     17.672337                    -19.400377
# 10                     -6.273635                    -33.686181
# 88                     -8.072799                    -45.510634
# ..                           ...                           ...
# 55                    -35.363431                    242.831040
# 83                      0.651475                    -38.008203
# 63                    -32.041779                    -51.736682
# 58                      0.426372                    -50.372046
# 46                     15.512669                    -38.422370
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 15                    154.424854          1.227510e+10
# 84                     58.810927          1.139225e+09
# 39                    -18.314127          4.023560e+09
# 10                    -27.850696          2.325339e+10
# 88                    -28.055900          1.032896e+09
# ..                           ...                   ...
# 55                    265.305591          2.280831e+09
# 83                    -22.995757          1.142897e+09
# 63                    257.694908          1.989962e+09
# 58                    -20.100834          2.097514e+09
# 46                     51.960727          3.428487e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 15                          0.6053                        2.017637e+10
# 84                          0.0562                        1.446049e+09
# 39                          0.1984                        4.023560e+09
# 10                          1.1467                        2.325339e+10
# 88                          0.0509                        3.510820e+09
# ..                             ...                                 ...
# 55                          0.1125                        1.151991e+10
# 83                          0.0564                        2.703001e+09
# 63                          0.0981                        2.058552e+09
# 58                          0.1034                        3.171439e+09
# 46                          0.1691                        7.198003e+09
#
#       quote.USD.last_updated
# 15  2022-01-14T00:26:00.000Z
# 84  2022-01-14T00:26:00.000Z
# 39  2022-01-14T00:26:00.000Z
# 10  2022-01-14T00:26:00.000Z
# 88  2022-01-14T00:26:00.000Z
# ..                       ...
# 55  2022-01-14T00:26:00.000Z
# 83  2022-01-14T00:26:00.000Z
# 63  2022-01-14T00:26:00.000Z
# 58  2022-01-14T00:26:00.000Z
# 46  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]

# %%
# Highest percentage change in 24 hours
Top_Percent_1h_df = final_crypto_data_df.sort_values(by = ["quote.USD.percent_change_1h"], ascending = False)
Top_Percent_1h_df
# Out:
#       id           name symbol           slug  num_market_pairs  \
# 84  5604         Secret   SCRT         secret                24
# 15  6535  NEAR Protocol   NEAR  near-protocol                87
# 67  6945            Amp    AMP            amp                63
# 10    74       Dogecoin   DOGE       dogecoin               442
# 38  3945        Harmony    ONE        harmony                76
# ..   ...            ...    ...            ...               ...
# 94  7501    WOO Network    WOO       wootrade                79
# 88  8104  1inch Network  1INCH          1inch               199
# 95  1808    OMG Network    OMG            omg               256
# 25  3513         Fantom    FTM         fantom               207
# 24  3794         Cosmos   ATOM         cosmos               221
#
#                   date_added  \
# 84  2020-05-19T00:00:00.000Z
# 15  2020-08-11T00:00:00.000Z
# 67  2020-09-08T00:00:00.000Z
# 10  2013-12-15T00:00:00.000Z
# 38  2019-06-01T00:00:00.000Z
# ..                       ...
# 94  2020-10-23T00:00:00.000Z
# 88  2020-12-25T00:00:00.000Z
# 95  2017-07-14T00:00:00.000Z
# 25  2018-10-29T00:00:00.000Z
# 24  2019-03-14T00:00:00.000Z
#
#                                                  tags  circulating_supply  \
# 84                  [cosmos-ecosystem, defi, privacy]        1.498157e+08
# 15  [platform, staking, binance-smart-chain, coinb...        6.083896e+08
# 67                                                 []        4.222770e+10
# 10  [mineable, pow, scrypt, medium-of-exchange, me...        1.326708e+11
# 38  [platform, enterprise-solutions, scaling, smar...        1.158637e+10
# ..                                                ...                 ...
# 94  [centralized-exchange, binance-smart-chain, ex...        8.840786e+08
# 88  [decentralized-exchange, defi, amm, binance-sm...        4.413053e+08
# 95  [medium-of-exchange, payments, scaling, state-...        1.402454e+08
# 25  [platform, enterprise-solutions, defi, researc...        2.545006e+09
# 24  [platform, cosmos-ecosystem, content-creation,...        2.262260e+08
#
#     total_supply  cmc_rank  ... quote.USD.percent_change_1h  \
# 84  1.901651e+08        85  ...                    3.920681
# 15  1.000000e+09        16  ...                    3.384133
# 67  9.921341e+10        68  ...                    0.972159
# 10  1.326708e+11        11  ...                    0.928701
# 38  1.331500e+10        39  ...                    0.814989
# ..           ...       ...  ...                         ...
# 94  2.990413e+09        95  ...                   -1.307272
# 88  1.500000e+09        89  ...                   -1.422333
# 95  1.402454e+08        96  ...                   -1.565655
# 25  2.545006e+09        26  ...                   -1.873285
# 24  2.840106e+08        25  ...                   -2.667244
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 84                     14.023433                    25.319648
# 15                     16.363241                    27.678955
# 67                     -3.083342                    -9.422009
# 10                      8.424658                    10.104460
# 38                      1.531806                    17.221906
# ..                           ...                          ...
# 94                     -7.841142                    -6.044058
# 88                      4.398924                     0.302847
# 95                      0.483516                     5.185155
# 25                      2.721796                     5.490286
# 24                     -7.863376                    -6.048105
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 84                     88.833706                     -3.499305
# 15                    115.406653                     71.893053
# 67                    -16.688663                    -28.337089
# 10                     -6.273635                    -33.686181
# 38                    103.891727                     27.965419
# ..                           ...                           ...
# 94                     23.356115                    -38.927981
# 88                     -8.072799                    -45.510634
# 95                     -1.373127                    -49.469363
# 25                    126.143142                     14.333529
# 24                     69.765605                     14.355065
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 84                     58.810927          1.139225e+09
# 15                    154.424854          1.227510e+10
# 67                    -17.780258          1.751945e+09
# 10                    -27.850696          2.325339e+10
# 38                     61.899972          4.094178e+09
# ..                           ...                   ...
# 94                     -7.281211          8.440681e+08
# 88                    -28.055900          1.032896e+09
# 95                    -58.060859          8.294767e+08
# 25                     53.524811          7.593361e+09
# 24                     12.004706          8.465229e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 84                          0.0562                        1.446049e+09
# 15                          0.6053                        2.017637e+10
# 67                          0.0864                        3.839622e+09
# 10                          1.1467                        2.325339e+10
# 38                          0.2019                        4.705011e+09
# ..                             ...                                 ...
# 94                          0.0416                        2.864230e+09
# 88                          0.0509                        3.510820e+09
# 95                          0.0409                        8.294767e+08
# 25                          0.3745                        9.473031e+09
# 24                          0.4175                        1.062749e+10
#
#       quote.USD.last_updated
# 84  2022-01-14T00:26:00.000Z
# 15  2022-01-14T00:26:00.000Z
# 67  2022-01-14T00:26:00.000Z
# 10  2022-01-14T00:26:00.000Z
# 38  2022-01-14T00:26:00.000Z
# ..                       ...
# 94  2022-01-14T00:26:00.000Z
# 88  2022-01-14T00:26:00.000Z
# 95  2022-01-14T00:26:00.000Z
# 25  2022-01-14T00:26:00.000Z
# 24  2022-01-14T00:26:00.000Z
#
# [100 rows x 24 columns]
