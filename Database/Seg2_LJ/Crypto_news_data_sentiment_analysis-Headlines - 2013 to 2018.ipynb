# %% [markdown]
# # Extracting Data from https://www.kaggle.com/kashnitsky/news-about-major-cryptocurrencies-20132018-40k/version/2/code and preprocessing and saving onto a MongoDB database

# %% [markdown]
# # Sentiment Analysis using Crypto News

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\lavin\anaconda3\envs\PythonData\python.exe

# %%
# import libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
import pymongo
from pymongo import MongoClient
import certifi
from mongo2_config import mongo_uri
from wordcloud import WordCloud, STOPWORDS
import datetime
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline
plt.style.use('fivethirtyeight')

from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
import nltk

# %%
# create a dataframe from the csv
path ="C:/UC_Berkeley\Analysis_Projects_Class_Folder/Module20_Final_Project\Data_Kaggle_Historical/crypto_news_parsed_2013-2018_40k.csv"
df = pd.read_csv(path)
df
# Out:
#                                                      url  \
# 0      https://www.ccn.com/paris-hiltons-hotel-mogul-...
# 1      https://www.ccn.com/buying-a-home-with-bitcoin...
# 2      https://www.ccn.com/sme-owners-in-the-uk-see-c...
# 3      https://www.ccn.com/bitcoin-boost-australian-s...
# 4      https://www.ccn.com/bitcoin-price-too-volatile...
# ...                                                  ...
# 39303  https://cointelegraph.com/news/senate_pressing...
# 39304  https://cointelegraph.com/news/on_the_state_of...
# 39305  https://cointelegraph.com/news/bitcoin_s_incre...
# 39306  https://cointelegraph.com/news/atlantis_shuts_...
# 39307  https://cointelegraph.com/news/the_bitcoin_uni...
#
#                                                    title  \
# 0      Paris Hilton’s Hotel Mogul Father to Sell $38 ...
# 1      Buying a Home With Bitcoin Makes Sense: Shark ...
# 2      UK SME Owners Anticipate Cryptocurrency Going ...
# 3      ‘Bitcoin Boost’: Australian State Government I...
# 4      Bitcoin Price Too Volatile for Merchants, Clai...
# ...                                                  ...
# 39303  Senate pressing regulators on Bitcoin risks an...
# 39304           On the State of New York’s ‘BitLicenses’
# 39305  Bitcoin’s increasing legitimacy sparks rally o...
# 39306  Atlantis shuts down, hindsight suggests it was...
# 39307  The Bitcoin universe: Scammers, criminals and ...
#
#                                                     text  \
# 0      A group of journalists who left The Denver Pos...
# 1      Millionaire investor and Shark Tank star Barba...
# 2      SME owners in the UK see cryptocurrency becomi...
# 3      The government of Queensland, Australia’s seco...
# 4      The bitcoin price is too volatile to make it a...
# ...                                                  ...
# 39303  A Senate homeland security committee seeks exp...
# 39304  In mid-November, the New York State Department...
# 39305  Bitcoin traders were waiting to hear just the ...
# 39306  After launching in June with a great deal of p...
# 39307  For enthusiasts and the merely interested, Bit...
#
#                                                     html  year  \
# 0      <p>A group of journalists who left The Denver ...  2018
# 1      <p>Millionaire investor and Shark Tank star <a...  2018
# 2      <p><span style="font-weight: 400;">SME owners ...  2018
# 3      <p>The government of Queensland, Australia’s s...  2018
# 4      <p>The bitcoin price is too volatile to make i...  2018
# ...                                                  ...   ...
# 39303  <p>A Senate homeland security committee seeks ...  2013
# 39304  <p>In mid-November, the New York State Departm...  2013
# 39305  <p>Bitcoin traders were waiting to hear just t...  2013
# 39306  <p>After launching in June with a great deal o...  2013
# 39307  <p>For enthusiasts and the merely interested, ...  2013
#
#                   author           source
# 0         Lester Coleman  accepts_bitcoin
# 1       Frisco d'Anconia  accepts_bitcoin
# 2      Paul de Havilland  accepts_bitcoin
# 3           Samburaj Das  accepts_bitcoin
# 4           Matt Jackson  accepts_bitcoin
# ...                  ...              ...
# 39303       Eric Barrier  regulation_news
# 39304    Darya Alyokhina  regulation_news
# 39305       Eric Barrier  regulation_news
# 39306       Eric Barrier        scam_news
# 39307       Eric Barrier        scam_news
#
# [39308 rows x 7 columns]

# %%
# checking for mull values
df.isnull().sum().sum()
df.isna().sum()
# Out:
# url          0
# title        1
# text         0
# html         0
# year         0
# author    1266
# source       0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# url       object
# title     object
# text      object
# html      object
# year       int64
# author    object
# source    object
# dtype: object

# %%
df['text'] = df['text'].astype('str')
df['title'] = df['title'].astype('str')
print(df.dtypes)
# Out:
# url       object
# title     object
# text      object
# html      object
# year       int64
# author    object
# source    object
# dtype: object

# %%
#Create function to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

#Create one new column called 'Polarity'
df['Polarity'] = df['title'].apply(getPolarity)

# show df with new column
df.head(5)
# Out:
#                                                  url  \
# 0  https://www.ccn.com/paris-hiltons-hotel-mogul-...
# 1  https://www.ccn.com/buying-a-home-with-bitcoin...
# 2  https://www.ccn.com/sme-owners-in-the-uk-see-c...
# 3  https://www.ccn.com/bitcoin-boost-australian-s...
# 4  https://www.ccn.com/bitcoin-price-too-volatile...
#
#                                                title  \
# 0  Paris Hilton’s Hotel Mogul Father to Sell $38 ...
# 1  Buying a Home With Bitcoin Makes Sense: Shark ...
# 2  UK SME Owners Anticipate Cryptocurrency Going ...
# 3  ‘Bitcoin Boost’: Australian State Government I...
# 4  Bitcoin Price Too Volatile for Merchants, Clai...
#
#                                                 text  \
# 0  A group of journalists who left The Denver Pos...
# 1  Millionaire investor and Shark Tank star Barba...
# 2  SME owners in the UK see cryptocurrency becomi...
# 3  The government of Queensland, Australia’s seco...
# 4  The bitcoin price is too volatile to make it a...
#
#                                                 html  year             author  \
# 0  <p>A group of journalists who left The Denver ...  2018     Lester Coleman
# 1  <p>Millionaire investor and Shark Tank star <a...  2018   Frisco d'Anconia
# 2  <p><span style="font-weight: 400;">SME owners ...  2018  Paul de Havilland
# 3  <p>The government of Queensland, Australia’s s...  2018       Samburaj Das
# 4  <p>The bitcoin price is too volatile to make i...  2018       Matt Jackson
#
#             source  Polarity
# 0  accepts_bitcoin       0.0
# 1  accepts_bitcoin       0.0
# 2  accepts_bitcoin       0.0
# 3  accepts_bitcoin       0.0
# 4  accepts_bitcoin       0.0

# %%
# Create a function to compute negative, neutral and positive sentiments
def getSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
# Create a new column to store the sentiment
df['Sentiment'] = df['Polarity'].apply(getSentiment)

#show the df
df
# Out:
#                                                      url  \
# 0      https://www.ccn.com/paris-hiltons-hotel-mogul-...
# 1      https://www.ccn.com/buying-a-home-with-bitcoin...
# 2      https://www.ccn.com/sme-owners-in-the-uk-see-c...
# 3      https://www.ccn.com/bitcoin-boost-australian-s...
# 4      https://www.ccn.com/bitcoin-price-too-volatile...
# ...                                                  ...
# 39303  https://cointelegraph.com/news/senate_pressing...
# 39304  https://cointelegraph.com/news/on_the_state_of...
# 39305  https://cointelegraph.com/news/bitcoin_s_incre...
# 39306  https://cointelegraph.com/news/atlantis_shuts_...
# 39307  https://cointelegraph.com/news/the_bitcoin_uni...
#
#                                                    title  \
# 0      Paris Hilton’s Hotel Mogul Father to Sell $38 ...
# 1      Buying a Home With Bitcoin Makes Sense: Shark ...
# 2      UK SME Owners Anticipate Cryptocurrency Going ...
# 3      ‘Bitcoin Boost’: Australian State Government I...
# 4      Bitcoin Price Too Volatile for Merchants, Clai...
# ...                                                  ...
# 39303  Senate pressing regulators on Bitcoin risks an...
# 39304           On the State of New York’s ‘BitLicenses’
# 39305  Bitcoin’s increasing legitimacy sparks rally o...
# 39306  Atlantis shuts down, hindsight suggests it was...
# 39307  The Bitcoin universe: Scammers, criminals and ...
#
#                                                     text  \
# 0      A group of journalists who left The Denver Pos...
# 1      Millionaire investor and Shark Tank star Barba...
# 2      SME owners in the UK see cryptocurrency becomi...
# 3      The government of Queensland, Australia’s seco...
# 4      The bitcoin price is too volatile to make it a...
# ...                                                  ...
# 39303  A Senate homeland security committee seeks exp...
# 39304  In mid-November, the New York State Department...
# 39305  Bitcoin traders were waiting to hear just the ...
# 39306  After launching in June with a great deal of p...
# 39307  For enthusiasts and the merely interested, Bit...
#
#                                                     html  year  \
# 0      <p>A group of journalists who left The Denver ...  2018
# 1      <p>Millionaire investor and Shark Tank star <a...  2018
# 2      <p><span style="font-weight: 400;">SME owners ...  2018
# 3      <p>The government of Queensland, Australia’s s...  2018
# 4      <p>The bitcoin price is too volatile to make i...  2018
# ...                                                  ...   ...
# 39303  <p>A Senate homeland security committee seeks ...  2013
# 39304  <p>In mid-November, the New York State Departm...  2013
# 39305  <p>Bitcoin traders were waiting to hear just t...  2013
# 39306  <p>After launching in June with a great deal o...  2013
# 39307  <p>For enthusiasts and the merely interested, ...  2013
#
#                   author           source  Polarity Sentiment
# 0         Lester Coleman  accepts_bitcoin  0.000000   Neutral
# 1       Frisco d'Anconia  accepts_bitcoin  0.000000   Neutral
# 2      Paul de Havilland  accepts_bitcoin  0.000000   Neutral
# 3           Samburaj Das  accepts_bitcoin  0.000000   Neutral
# 4           Matt Jackson  accepts_bitcoin  0.000000   Neutral
# ...                  ...              ...       ...       ...
# 39303       Eric Barrier  regulation_news  0.000000   Neutral
# 39304    Darya Alyokhina  regulation_news  0.136364  Positive
# 39305       Eric Barrier  regulation_news  0.000000   Neutral
# 39306       Eric Barrier        scam_news -0.155556  Negative
# 39307       Eric Barrier        scam_news  0.000000   Neutral
#
# [39308 rows x 9 columns]

# %%
# Plot and visualize sentiment count
plt.title('Sentiment Analysis(Based on News Headlines)')
df["Sentiment"].value_counts().plot(kind='bar')
plt.xlabel('Sentiments')
plt.ylabel('Counts')
plt.show()

# %%
# Plot the sum of the polrity for each year
plt.figure(figsize=(12.33, 4.5))
plt.title('Sentiment Sum over Time(Based on News Headlines)')
plt.xlabel('Year')
plt.ylabel('Polarity')
polarity = df.groupby(['year']).sum()['Polarity'] 
plt.plot(polarity.index, polarity)

# %%
# show the sum of the polarity for each year
polarity
# Out:
# year
# 2013     22.947175
# 2014    245.015726
# 2015    141.357692
# 2016    249.616311
# 2017    360.032574
# 2018    366.714197
# Name: Polarity, dtype: float64

# %%
# Get the count of each article per entry
polarity_count = df.groupby(['year']).count()['Polarity']
polarity_count
# Out:
# year
# 2013      699
# 2014     5353
# 2015     4713
# 2016     6725
# 2017    10579
# 2018    11239
# Name: Polarity, dtype: int64

# %%
# Show the average sentiment for each year
polarity_avg = polarity / polarity_count
polarity_avg
# Out:
# year
# 2013    0.032829
# 2014    0.045772
# 2015    0.029993
# 2016    0.037118
# 2017    0.034033
# 2018    0.032629
# Name: Polarity, dtype: float64

# %%
# Plot the average sentiment over time
plt.figure(figsize=(12.33, 4.5))
plt.title('Sentiment Average over Time(Based on News Headlines)')
plt.xlabel('Year')
plt.ylabel('Average Polarity')
plt.plot(polarity_avg.index, polarity_avg)
